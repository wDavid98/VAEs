# %%
## Uso de GPU
import os
import tensorflow as tf
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['TF_ENABLE_ONEDNN_OPTS'] =  "0"
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

## Librerías
import seaborn as sns
import sys
import cv2 as cv2
import glob
from PIL import Image
import tensorflow as tf
import sys
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import gc
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
import os


from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler

print(tf.__version__)
# Out:
# 2023-10-31 23:17:00.524124: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-31 23:17:00.524260: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-31 23:17:00.528391: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-31 23:17:00.805410: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 23:17:04.305591: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:04.351778: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:04.351913: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2.14.0

# %% [markdown]
# ## Datos

# %%
### Rutas de todas las imágenes

## Obtener todas las rutas de las imágenes en el dataset
ruta_dataset  = glob.glob('../../../Datasets/Humedas_Secas_procesadas/Recortadas/*/*/*/*.jpg')

## Capturar solo rutas secas 
rutas_imagenes_secas = []
rutas_imagenes_humedas = []

clases_secas= []
clases_humedas = []
for ruta in ruta_dataset:
    if ruta.split('/')[-2] == 'Secas' or ruta.split('/')[-2] == 'Seca':
        clases_secas.append(ruta.split('/')[-4])
        rutas_imagenes_secas.append(ruta)
    else:
        clases_humedas.append(ruta.split('/')[-4])
        rutas_imagenes_humedas.append(ruta)

## Construcción de datasets
data_secas = pd.DataFrame({'ruta':rutas_imagenes_secas,'clase':clases_secas})
data_humedas = pd.DataFrame({'ruta':rutas_imagenes_humedas,'clase':clases_humedas})

## reemplazo de etiquetas}
lables_generalization = {'CuNi1':'MF1','CuNi2':'MF2','CuNi3':'MF3'}
data_secas.replace(lables_generalization,inplace=True)
data_humedas.replace(lables_generalization,inplace=True)

## summary    
print('Imágenes secas:', np.shape(rutas_imagenes_secas)[0],' - Imágenes Húmedas: ',np.shape(rutas_imagenes_humedas)[0])
print('MF1:', '- secas: ', np.shape(data_secas[data_secas['clase']=='MF1'])[0], '- húmedas: ', np.shape(data_humedas[data_humedas['clase']=='MF1'])[0])
print('MF2:', '- secas: ', np.shape(data_secas[data_secas['clase']=='MF2'])[0], '- húmedas: ', np.shape(data_humedas[data_humedas['clase']=='MF2'])[0])
print('MF3:', '- secas: ', np.shape(data_secas[data_secas['clase']=='MF3'])[0], '- húmedas: ', np.shape(data_humedas[data_humedas['clase']=='MF3'])[0])
# Out:
# Imágenes secas: 931  - Imágenes Húmedas:  792
# MF1: - secas:  379 - húmedas:  265
# MF2: - secas:  289 - húmedas:  265
# MF3: - secas:  263 - húmedas:  262

# %%
## Crear Dataframe
df_secas = pd.DataFrame()
df_secas['routes'] = rutas_imagenes_secas
df_secas['label'] = clases_secas

char_to_num = {'CuNi1':'0','CuNi2':'1','CuNi3':'2'}

df_secas['label'].replace(char_to_num,inplace=True)

## Recolver dataframe
df_secas = df_secas.sample(frac=1,random_state=42).reset_index(drop=True)
df_secas
# Out:
#                                                 routes label
# 0    ../../../Datasets/Humedas_Secas_procesadas/Rec...     0
# 1    ../../../Datasets/Humedas_Secas_procesadas/Rec...     2
# 2    ../../../Datasets/Humedas_Secas_procesadas/Rec...     0
# 3    ../../../Datasets/Humedas_Secas_procesadas/Rec...     1
# 4    ../../../Datasets/Humedas_Secas_procesadas/Rec...     0
# ..                                                 ...   ...
# 926  ../../../Datasets/Humedas_Secas_procesadas/Rec...     2
# 927  ../../../Datasets/Humedas_Secas_procesadas/Rec...     1
# 928  ../../../Datasets/Humedas_Secas_procesadas/Rec...     0
# 929  ../../../Datasets/Humedas_Secas_procesadas/Rec...     1
# 930  ../../../Datasets/Humedas_Secas_procesadas/Rec...     2
#
# [931 rows x 2 columns]

# %%
## Establecer el porcentaje de separación
thold1 = int(np.ceil(0.8 * len(df_secas[df_secas.label=='0'])))
thold2 = int(np.ceil(0.8 * len(df_secas[df_secas.label=='1'])))
thold3 = int(np.ceil(0.8 * len(df_secas[df_secas.label=='2'])))

## Separar por clases para entrenamiento
train_cu1 = df_secas[df_secas.label == '0'][0:thold1]
train_cu2 = df_secas[df_secas.label == '1'][0:thold2]
train_cu3 = df_secas[df_secas.label == '2'][0:thold3]

## tomar las demás imágenes para test
test_cu1 = df_secas[df_secas.label == '0'][thold1:]
test_cu2 = df_secas[df_secas.label == '1'][thold2:]
test_cu3 = df_secas[df_secas.label == '2'][thold3:]


## Constuir un solo dataset de training
train_df =  pd.concat([pd.concat([train_cu1,train_cu2]),train_cu3]).sample(frac=1,random_state=42).reset_index(drop=True)

## Construir un solo dataset de test
test_df = pd.concat([pd.concat([test_cu1,test_cu2]),test_cu3]).sample(frac=1,random_state=42).reset_index(drop=True)

## Cantidad de muestras por clase
print('Clase MF1: train: ',len(train_cu1),', test: ',len(test_cu1))
print('Clase MF2: train: ',len(train_cu2),', test: ',len(test_cu2))
print('Clase MF3: train: ',len(train_cu3),', test: ',len(test_cu3))
# Out:
# Clase MF1: train:  304 , test:  75
# Clase MF2: train:  232 , test:  57
# Clase MF3: train:  211 , test:  52

# %%
def load_image(file_name):
  raw = tf.io.read_file(file_name)
  tensor = tf.io.decode_jpeg(raw,channels=1)
  tensor = tf.image.resize(tensor, [128,128])
  tensor = tf.cast(tensor, tf.float32) / 255.0
  print("Final shape: ", tensor.shape)
  return tensor

def create_dataset(file_names, labels):
  dataset = tf.data.Dataset.from_tensor_slices((file_names,labels))
  dataset.shuffle(buffer_size=16)
  dataset = dataset.map(lambda file_name, label: (load_image(file_name), label))
  
  return dataset

file_names = train_df['routes'].to_numpy()
labels = train_df['label'].to_numpy()
dataset = create_dataset(file_names, labels)
# Out:
# Final shape:  (128, 128, 1)
# 2023-10-31 23:17:05.961464: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:05.961660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:05.961800: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:06.274987: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:06.276043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:06.276157: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-31 23:17:06.276238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7474 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:08:00.0, compute capability: 8.6

# %%
cnt = 0
for i in dataset.batch(16):
    cnt += 1
    a = i[0]
    b = i[1]


print(a.shape)
print(b.shape)
plt.imshow(a[0,:,:,0],cmap='gray')
print(b)
print(cnt)
# Out:
# (11, 128, 128, 1)
# (11,)
# tf.Tensor([b'0' b'1' b'0' b'2' b'0' b'2' b'0' b'0' b'0' b'1' b'0'], shape=(11,), dtype=string)
# 47

# %% [markdown]
# ## Modelo

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        #https://github.com/is0383kk/Dirichlet-VAE
        gaus_z = z_mean + tf.exp(0.5 * z_log_var) * epsilon
        dir_z = tf.math.softmax(z_mean + tf.exp(0.5 * z_log_var) * epsilon, axis=1)
        return dir_z

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")        

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data[0])
            reconstruction = self.decoder(z)
            reconstruction /= tf.reduce_max(reconstruction)
            
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data[0], reconstruction), axis=(1, 2)
                )
            )
            
            '''
            reconstruction_loss =tf.reduce_mean(
                tf.reduce_sum( tf.keras.losses.MeanSquaredError()(data, reconstruction)
                             )
            )
            '''
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))            
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.reconstruction = reconstruction
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)       
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),            
        }

# %%
###_____________________________ENCODER________________________##
latent_dim = 32

nx, ny = 128, 128

encoder_inputs = keras.Input(shape=(nx, ny,1))

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E1')(encoder_inputs)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E2')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same',name='layer_E3')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same',name='layer_E4')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_E6')(x)
x = layers.Flatten()(x)



z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(inputs=encoder_inputs, outputs=[z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  layer_E1 (Conv2D)           (None, 128, 128, 1024)       10240     ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 1024)         0         ['layer_E1[0][0]']
#  D)
#
#  batch_normalization (Batch  (None, 64, 64, 1024)         4096      ['max_pooling2d[0][0]']
#  Normalization)
#
#  layer_E2 (Conv2D)           (None, 64, 64, 1024)         9438208   ['batch_normalization[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 1024)         0         ['layer_E2[0][0]']
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 32, 32, 1024)         4096      ['max_pooling2d_1[0][0]']
#  chNormalization)
#
#  layer_E3 (Conv2D)           (None, 32, 32, 512)          4719104   ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 512)          0         ['layer_E3[0][0]']
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 512)          2048      ['max_pooling2d_2[0][0]']
#  chNormalization)
#
#  layer_E4 (Conv2D)           (None, 16, 16, 256)          1179904   ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 256)            0         ['layer_E4[0][0]']
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 8, 8, 256)            1024      ['max_pooling2d_3[0][0]']
#  chNormalization)
#
#  layer_E6 (Conv2D)           (None, 8, 8, 128)            295040    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  flatten (Flatten)           (None, 8192)                 0         ['layer_E6[0][0]']
#
#  z_mean (Dense)              (None, 32)                   262176    ['flatten[0][0]']
#
#  z_log_var (Dense)           (None, 32)                   262176    ['flatten[0][0]']
#
#  sampling (Sampling)         (None, 32)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 16178112 (61.71 MB)
# Trainable params: 16172480 (61.69 MB)
# Non-trainable params: 5632 (22.00 KB)
# __________________________________________________________________________________________________

# %%
## Entrada Z
latent_inputs = keras.Input(shape=(latent_dim,))

##dimensiones
ndim = 16
nfilts = 128

## anti-flatten de la última capa convolucional
x = layers.Dense(ndim * ndim * nfilts, activation="relu")(latent_inputs)

## Reshape para reconstruir la última convolucional
x = layers.Reshape((ndim,ndim, nfilts))(x)

## Capas convolucionales
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D1')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D2')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_D4')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same',name='layer_D6')(x)

decoder_outputs = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='layer_D7')(x)

## Construcción del decoder
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 32768)             1081344
#
#  reshape (Reshape)           (None, 16, 16, 128)       0
#
#  layer_D1 (Conv2D)           (None, 16, 16, 128)       147584
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 128)       0
#  D)
#
#  batch_normalization_4 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  layer_D2 (Conv2D)           (None, 32, 32, 128)       147584
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 128)       0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 64, 64, 128)       512
#  chNormalization)
#
#  layer_D4 (Conv2D)           (None, 64, 64, 64)        73792
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 64)      0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  layer_D6 (Conv2D)           (None, 128, 128, 16)      9232
#
#  layer_D7 (Conv2D)           (None, 128, 128, 1)       145
#
# =================================================================
# Total params: 1460961 (5.57 MB)
# Trainable params: 1460321 (5.57 MB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
vae = VAE(encoder, decoder)
opt = tf.optimizers.Adam(learning_rate = 0.000001)
#nll = lambda x , rv_x: -rv_x.log_prob(x)
vae.compile(optimizer=opt)


vae.fit(dataset.batch(16), epochs=2000, 
                batch_size=16,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=100)])
# Out:
# Epoch 1/2000
# 2023-10-31 23:17:22.788758: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2023-10-31 23:17:27.095831: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fcb87940110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-31 23:17:27.095973: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2023-10-31 23:17:27.179719: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-31 23:17:27.556098: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-10-31 23:17:30.805002: W tensorflow/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2023-10-31 23:17:32.658846: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-31 23:17:32.658880: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 47/47 [==============================] - 35s 387ms/step - loss: 79516.7321 - reconstruction_loss: 80094.6797 - kl_loss: 0.0021
# 2023-10-31 23:17:55.422319: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Epoch 2/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 78817.5199 - reconstruction_loss: 79019.2969 - kl_loss: 0.0021
# Epoch 3/2000
# 47/47 [==============================] - 6s 120ms/step - loss: 78500.5739 - reconstruction_loss: 78115.8203 - kl_loss: 0.0023
# Epoch 4/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 76972.0465 - reconstruction_loss: 76715.9219 - kl_loss: 0.0026
# Epoch 5/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 75440.0109 - reconstruction_loss: 75382.9141 - kl_loss: 0.0030
# Epoch 6/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 74196.1533 - reconstruction_loss: 74274.8516 - kl_loss: 0.0035
# Epoch 7/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 72600.7100 - reconstruction_loss: 72310.1641 - kl_loss: 0.0041
# Epoch 8/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 71779.9814 - reconstruction_loss: 71421.8594 - kl_loss: 0.0051
# Epoch 9/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 70415.5252 - reconstruction_loss: 69790.2656 - kl_loss: 0.0067
# Epoch 10/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 68782.9067 - reconstruction_loss: 68479.7109 - kl_loss: 0.0096
# Epoch 11/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 67049.5584 - reconstruction_loss: 66700.6250 - kl_loss: 0.0134
# Epoch 12/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 64811.3493 - reconstruction_loss: 64448.7695 - kl_loss: 0.0186
# Epoch 13/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 63275.3158 - reconstruction_loss: 62943.5703 - kl_loss: 0.0254
# Epoch 14/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 61485.6789 - reconstruction_loss: 61414.0039 - kl_loss: 0.0353
# Epoch 15/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 60363.8492 - reconstruction_loss: 60091.1797 - kl_loss: 0.0499
# Epoch 16/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 59270.7279 - reconstruction_loss: 59071.8477 - kl_loss: 0.0753
# Epoch 17/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 58075.7296 - reconstruction_loss: 57866.8398 - kl_loss: 0.1250
# Epoch 18/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 56926.7631 - reconstruction_loss: 56778.3711 - kl_loss: 0.2070
# Epoch 19/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 56037.9115 - reconstruction_loss: 55895.0859 - kl_loss: 0.3743
# Epoch 20/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 54947.1427 - reconstruction_loss: 54647.8047 - kl_loss: 0.7619
# Epoch 21/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 53779.5690 - reconstruction_loss: 53435.6172 - kl_loss: 1.5846
# Epoch 22/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 51970.1330 - reconstruction_loss: 51495.3086 - kl_loss: 3.8984
# Epoch 23/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 49990.7610 - reconstruction_loss: 49448.0000 - kl_loss: 8.7017
# Epoch 24/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 47953.7927 - reconstruction_loss: 47649.0430 - kl_loss: 13.8404
# Epoch 25/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 46659.1191 - reconstruction_loss: 46436.0469 - kl_loss: 16.0498
# Epoch 26/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 45657.6852 - reconstruction_loss: 45476.4102 - kl_loss: 16.9741
# Epoch 27/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 44906.9612 - reconstruction_loss: 44714.8203 - kl_loss: 18.0994
# Epoch 28/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 44174.5259 - reconstruction_loss: 44018.0938 - kl_loss: 20.1648
# Epoch 29/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 43501.4544 - reconstruction_loss: 43357.9219 - kl_loss: 21.5406
# Epoch 30/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 42909.5955 - reconstruction_loss: 42777.2227 - kl_loss: 22.0837
# Epoch 31/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 42343.5352 - reconstruction_loss: 42222.7969 - kl_loss: 22.7713
# Epoch 32/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 41817.8235 - reconstruction_loss: 41703.9219 - kl_loss: 23.5249
# Epoch 33/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 41292.9622 - reconstruction_loss: 41185.2031 - kl_loss: 23.5686
# Epoch 34/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 40825.2354 - reconstruction_loss: 40713.6211 - kl_loss: 24.2965
# Epoch 35/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 40365.3936 - reconstruction_loss: 40246.2305 - kl_loss: 25.8474
# Epoch 36/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 39885.7505 - reconstruction_loss: 39778.9102 - kl_loss: 25.7115
# Epoch 37/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 39442.9351 - reconstruction_loss: 39338.7031 - kl_loss: 25.6812
# Epoch 38/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 39040.4432 - reconstruction_loss: 38999.0117 - kl_loss: 25.4086
# Epoch 39/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 38598.0918 - reconstruction_loss: 38508.0000 - kl_loss: 26.7956
# Epoch 40/2000
# 47/47 [==============================] - 6s 121ms/step - loss: 38203.6384 - reconstruction_loss: 38102.9609 - kl_loss: 27.5894
# Epoch 41/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 37789.8179 - reconstruction_loss: 37690.1133 - kl_loss: 27.3068
# Epoch 42/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 37383.5144 - reconstruction_loss: 37292.3945 - kl_loss: 25.8698
# Epoch 43/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 37009.3688 - reconstruction_loss: 36912.8047 - kl_loss: 25.7349
# Epoch 44/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 36638.9859 - reconstruction_loss: 36589.6523 - kl_loss: 25.8566
# Epoch 45/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 36262.7399 - reconstruction_loss: 36183.8359 - kl_loss: 29.3704
# Epoch 46/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 35872.6239 - reconstruction_loss: 35781.5039 - kl_loss: 30.9458
# Epoch 47/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 35512.3755 - reconstruction_loss: 35415.5469 - kl_loss: 30.0159
# Epoch 48/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 35143.9384 - reconstruction_loss: 35052.6445 - kl_loss: 28.8141
# Epoch 49/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 34791.5572 - reconstruction_loss: 34707.2578 - kl_loss: 28.7919
# Epoch 50/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 34433.5003 - reconstruction_loss: 34350.1992 - kl_loss: 30.1279
# Epoch 51/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 34070.1640 - reconstruction_loss: 33978.5117 - kl_loss: 30.9104
# Epoch 52/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 33710.7669 - reconstruction_loss: 33621.3281 - kl_loss: 30.1779
# Epoch 53/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 33351.8085 - reconstruction_loss: 33267.6641 - kl_loss: 29.8601
# Epoch 54/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 33003.0154 - reconstruction_loss: 32911.2656 - kl_loss: 30.3214
# Epoch 55/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 32658.1615 - reconstruction_loss: 32575.1387 - kl_loss: 30.0144
# Epoch 56/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 32324.6589 - reconstruction_loss: 32244.0645 - kl_loss: 30.6111
# Epoch 57/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 31973.4510 - reconstruction_loss: 31887.1934 - kl_loss: 31.6598
# Epoch 58/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 31650.9242 - reconstruction_loss: 31557.7012 - kl_loss: 31.4745
# Epoch 59/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 31314.3453 - reconstruction_loss: 31226.0859 - kl_loss: 30.9743
# Epoch 60/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 31032.8454 - reconstruction_loss: 30926.0195 - kl_loss: 33.1682
# Epoch 61/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 30657.2759 - reconstruction_loss: 30570.7266 - kl_loss: 34.1294
# Epoch 62/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 30332.4358 - reconstruction_loss: 30242.0078 - kl_loss: 32.8183
# Epoch 63/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 30019.5027 - reconstruction_loss: 29967.9922 - kl_loss: 32.2053
# Epoch 64/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 29736.1058 - reconstruction_loss: 29625.9199 - kl_loss: 37.0461
# Epoch 65/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 29382.5668 - reconstruction_loss: 29292.1191 - kl_loss: 37.0800
# Epoch 66/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 29080.8024 - reconstruction_loss: 28990.9336 - kl_loss: 35.6925
# Epoch 67/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 28764.7909 - reconstruction_loss: 28676.6758 - kl_loss: 34.7759
# Epoch 68/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 28476.8815 - reconstruction_loss: 28381.8672 - kl_loss: 34.0574
# Epoch 69/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 28151.9429 - reconstruction_loss: 28074.5156 - kl_loss: 33.9391
# Epoch 70/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 27862.3738 - reconstruction_loss: 27775.3691 - kl_loss: 34.1468
# Epoch 71/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 27548.0311 - reconstruction_loss: 27469.0586 - kl_loss: 34.5264
# Epoch 72/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 27244.1641 - reconstruction_loss: 27166.8398 - kl_loss: 34.7880
# Epoch 73/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 26949.3921 - reconstruction_loss: 26854.7480 - kl_loss: 35.7348
# Epoch 74/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 26657.7004 - reconstruction_loss: 26552.1641 - kl_loss: 36.4910
# Epoch 75/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 26298.2633 - reconstruction_loss: 26208.2344 - kl_loss: 38.2983
# Epoch 76/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 25974.2076 - reconstruction_loss: 25881.8594 - kl_loss: 41.1995
# Epoch 77/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 25657.1040 - reconstruction_loss: 25541.5977 - kl_loss: 44.5197
# Epoch 78/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 25330.2949 - reconstruction_loss: 25229.6172 - kl_loss: 47.0491
# Epoch 79/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 25020.4473 - reconstruction_loss: 24911.8457 - kl_loss: 49.6972
# Epoch 80/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 24711.4015 - reconstruction_loss: 24607.9199 - kl_loss: 50.7830
# Epoch 81/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 24413.8760 - reconstruction_loss: 24311.5762 - kl_loss: 51.2879
# Epoch 82/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 24124.6055 - reconstruction_loss: 24018.9395 - kl_loss: 52.0329
# Epoch 83/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 23829.9198 - reconstruction_loss: 23725.7988 - kl_loss: 52.0005
# Epoch 84/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 23545.1212 - reconstruction_loss: 23441.8770 - kl_loss: 51.2582
# Epoch 85/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 23260.7839 - reconstruction_loss: 23160.3105 - kl_loss: 50.5634
# Epoch 86/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 22981.0695 - reconstruction_loss: 22879.1777 - kl_loss: 50.0829
# Epoch 87/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 22705.1042 - reconstruction_loss: 22604.8516 - kl_loss: 49.4324
# Epoch 88/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 22432.0146 - reconstruction_loss: 22334.0449 - kl_loss: 49.2085
# Epoch 89/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 22161.0431 - reconstruction_loss: 22062.2695 - kl_loss: 49.1653
# Epoch 90/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 21894.2068 - reconstruction_loss: 21797.3613 - kl_loss: 48.8631
# Epoch 91/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 21627.9893 - reconstruction_loss: 21529.9609 - kl_loss: 49.0490
# Epoch 92/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 21366.2612 - reconstruction_loss: 21269.4102 - kl_loss: 48.5327
# Epoch 93/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 21108.2815 - reconstruction_loss: 21011.3945 - kl_loss: 48.5838
# Epoch 94/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 20849.8526 - reconstruction_loss: 20753.1113 - kl_loss: 48.6933
# Epoch 95/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 20594.8271 - reconstruction_loss: 20499.4238 - kl_loss: 48.4843
# Epoch 96/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 20343.7508 - reconstruction_loss: 20248.2852 - kl_loss: 48.9499
# Epoch 97/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 20094.1688 - reconstruction_loss: 19998.3926 - kl_loss: 49.3458
# Epoch 98/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 19846.8772 - reconstruction_loss: 19751.3066 - kl_loss: 49.3993
# Epoch 99/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 19602.6558 - reconstruction_loss: 19508.1660 - kl_loss: 49.2804
# Epoch 100/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 19360.7234 - reconstruction_loss: 19265.5254 - kl_loss: 49.5486
# Epoch 101/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 19119.7538 - reconstruction_loss: 19025.4141 - kl_loss: 49.2355
# Epoch 102/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 18883.2202 - reconstruction_loss: 18790.3027 - kl_loss: 48.9888
# Epoch 103/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 18649.1589 - reconstruction_loss: 18556.0195 - kl_loss: 49.3095
# Epoch 104/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 18416.3564 - reconstruction_loss: 18323.1855 - kl_loss: 49.3899
# Epoch 105/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 18188.2492 - reconstruction_loss: 18094.6855 - kl_loss: 49.5868
# Epoch 106/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 17959.2462 - reconstruction_loss: 17865.9961 - kl_loss: 49.7098
# Epoch 107/2000
# 47/47 [==============================] - 6s 122ms/step - loss: 17733.4308 - reconstruction_loss: 17641.3262 - kl_loss: 49.2599
# Epoch 108/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 17511.3094 - reconstruction_loss: 17419.7617 - kl_loss: 49.4634
# Epoch 109/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 17290.5109 - reconstruction_loss: 17199.1523 - kl_loss: 49.6704
# Epoch 110/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 17074.2316 - reconstruction_loss: 16982.3828 - kl_loss: 49.6571
# Epoch 111/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 16860.0235 - reconstruction_loss: 16770.0273 - kl_loss: 49.4613
# Epoch 112/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 16649.6172 - reconstruction_loss: 16559.0859 - kl_loss: 49.8436
# Epoch 113/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 16441.8385 - reconstruction_loss: 16352.9072 - kl_loss: 49.7977
# Epoch 114/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 16237.5159 - reconstruction_loss: 16147.5430 - kl_loss: 50.2871
# Epoch 115/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 16035.0218 - reconstruction_loss: 15946.2676 - kl_loss: 50.0817
# Epoch 116/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 15836.2056 - reconstruction_loss: 15746.8994 - kl_loss: 50.0643
# Epoch 117/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 15639.5722 - reconstruction_loss: 15551.6494 - kl_loss: 49.6390
# Epoch 118/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 15446.9375 - reconstruction_loss: 15359.8740 - kl_loss: 49.6058
# Epoch 119/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 15257.4967 - reconstruction_loss: 15170.1182 - kl_loss: 49.8545
# Epoch 120/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 15070.9355 - reconstruction_loss: 14984.9736 - kl_loss: 49.6308
# Epoch 121/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 14888.4095 - reconstruction_loss: 14802.8613 - kl_loss: 50.2116
# Epoch 122/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 14707.4464 - reconstruction_loss: 14621.4531 - kl_loss: 50.7828
# Epoch 123/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 14530.3678 - reconstruction_loss: 14444.7314 - kl_loss: 50.5435
# Epoch 124/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 14356.5323 - reconstruction_loss: 14272.2422 - kl_loss: 50.2255
# Epoch 125/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 14185.4799 - reconstruction_loss: 14101.2129 - kl_loss: 50.1012
# Epoch 126/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 14016.1029 - reconstruction_loss: 13932.8369 - kl_loss: 49.9045
# Epoch 127/2000
# 47/47 [==============================] - 6s 132ms/step - loss: 13850.1346 - reconstruction_loss: 13767.1533 - kl_loss: 50.0602
# Epoch 128/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 13688.4605 - reconstruction_loss: 13605.9219 - kl_loss: 50.3587
# Epoch 129/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 13529.9857 - reconstruction_loss: 13448.2207 - kl_loss: 50.1120
# Epoch 130/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 13375.8458 - reconstruction_loss: 13295.1035 - kl_loss: 49.8233
# Epoch 131/2000
# 47/47 [==============================] - 6s 132ms/step - loss: 13225.1001 - reconstruction_loss: 13144.8340 - kl_loss: 49.9075
# Epoch 132/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 13078.7296 - reconstruction_loss: 12999.4746 - kl_loss: 50.0329
# Epoch 133/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 12935.5012 - reconstruction_loss: 12856.6865 - kl_loss: 50.2104
# Epoch 134/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 12795.7074 - reconstruction_loss: 12717.9014 - kl_loss: 49.8938
# Epoch 135/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 12660.9048 - reconstruction_loss: 12583.4082 - kl_loss: 49.8862
# Epoch 136/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 12529.1487 - reconstruction_loss: 12452.6758 - kl_loss: 49.6368
# Epoch 137/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 12401.1610 - reconstruction_loss: 12325.7051 - kl_loss: 49.3444
# Epoch 138/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 12277.3573 - reconstruction_loss: 12202.5195 - kl_loss: 49.3183
# Epoch 139/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 12157.5870 - reconstruction_loss: 12084.0156 - kl_loss: 48.9796
# Epoch 140/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 12042.8501 - reconstruction_loss: 11969.8408 - kl_loss: 49.2212
# Epoch 141/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11931.7956 - reconstruction_loss: 11859.1914 - kl_loss: 49.3812
# Epoch 142/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11824.7874 - reconstruction_loss: 11753.6797 - kl_loss: 49.0295
# Epoch 143/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11722.2229 - reconstruction_loss: 11651.5342 - kl_loss: 49.1239
# Epoch 144/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 11623.5224 - reconstruction_loss: 11553.5781 - kl_loss: 48.6685
# Epoch 145/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11529.2966 - reconstruction_loss: 11461.4160 - kl_loss: 48.0959
# Epoch 146/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11439.3249 - reconstruction_loss: 11372.0156 - kl_loss: 48.3738
# Epoch 147/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11353.7520 - reconstruction_loss: 11287.4092 - kl_loss: 48.1300
# Epoch 148/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11271.6466 - reconstruction_loss: 11206.5156 - kl_loss: 47.9573
# Epoch 149/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11194.7928 - reconstruction_loss: 11129.9150 - kl_loss: 47.7193
# Epoch 150/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 11120.8846 - reconstruction_loss: 11057.4805 - kl_loss: 47.0815
# Epoch 151/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 11051.3838 - reconstruction_loss: 10989.5361 - kl_loss: 46.8549
# Epoch 152/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10986.4732 - reconstruction_loss: 10925.2197 - kl_loss: 47.0456
# Epoch 153/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10924.8420 - reconstruction_loss: 10863.5547 - kl_loss: 47.1156
# Epoch 154/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10867.0629 - reconstruction_loss: 10807.5791 - kl_loss: 46.4761
# Epoch 155/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10811.8291 - reconstruction_loss: 10753.0693 - kl_loss: 45.9920
# Epoch 156/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10761.1618 - reconstruction_loss: 10703.6904 - kl_loss: 45.5353
# Epoch 157/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10713.8566 - reconstruction_loss: 10656.7939 - kl_loss: 45.4556
# Epoch 158/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10669.4897 - reconstruction_loss: 10613.6924 - kl_loss: 45.0763
# Epoch 159/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10627.5821 - reconstruction_loss: 10572.8193 - kl_loss: 44.5921
# Epoch 160/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10590.2833 - reconstruction_loss: 10536.2988 - kl_loss: 44.5180
# Epoch 161/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10554.7758 - reconstruction_loss: 10500.9111 - kl_loss: 44.6152
# Epoch 162/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10521.0604 - reconstruction_loss: 10467.4004 - kl_loss: 43.8764
# Epoch 163/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10488.9843 - reconstruction_loss: 10437.0596 - kl_loss: 43.1570
# Epoch 164/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10459.3690 - reconstruction_loss: 10408.2197 - kl_loss: 42.6909
# Epoch 165/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10434.1476 - reconstruction_loss: 10384.0557 - kl_loss: 42.2961
# Epoch 166/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10411.6635 - reconstruction_loss: 10362.8281 - kl_loss: 42.0061
# Epoch 167/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10391.2816 - reconstruction_loss: 10343.4199 - kl_loss: 41.2336
# Epoch 168/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10374.9176 - reconstruction_loss: 10327.5898 - kl_loss: 40.9558
# Epoch 169/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10359.1991 - reconstruction_loss: 10312.8467 - kl_loss: 40.2064
# Epoch 170/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10346.2495 - reconstruction_loss: 10301.1152 - kl_loss: 39.5452
# Epoch 171/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10335.0163 - reconstruction_loss: 10290.4004 - kl_loss: 39.3420
# Epoch 172/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10325.5432 - reconstruction_loss: 10280.7012 - kl_loss: 39.3310
# Epoch 173/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10316.3338 - reconstruction_loss: 10273.5469 - kl_loss: 37.9842
# Epoch 174/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10308.5693 - reconstruction_loss: 10265.7891 - kl_loss: 37.6680
# Epoch 175/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10302.7186 - reconstruction_loss: 10260.7344 - kl_loss: 37.0826
# Epoch 176/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10296.7570 - reconstruction_loss: 10255.6006 - kl_loss: 36.6972
# Epoch 177/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10291.4755 - reconstruction_loss: 10250.7285 - kl_loss: 36.1738
# Epoch 178/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10287.2026 - reconstruction_loss: 10247.4561 - kl_loss: 35.4245
# Epoch 179/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10283.8640 - reconstruction_loss: 10243.7480 - kl_loss: 35.4092
# Epoch 180/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10280.1564 - reconstruction_loss: 10241.2168 - kl_loss: 34.6512
# Epoch 181/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10276.7240 - reconstruction_loss: 10238.3887 - kl_loss: 33.8495
# Epoch 182/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10274.0251 - reconstruction_loss: 10236.0186 - kl_loss: 33.5697
# Epoch 183/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10271.7540 - reconstruction_loss: 10234.4307 - kl_loss: 32.9557
# Epoch 184/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10268.5008 - reconstruction_loss: 10232.3545 - kl_loss: 32.2998
# Epoch 185/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10266.4899 - reconstruction_loss: 10229.7754 - kl_loss: 31.9212
# Epoch 186/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10265.0857 - reconstruction_loss: 10228.8193 - kl_loss: 31.1899
# Epoch 187/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10261.9556 - reconstruction_loss: 10227.1904 - kl_loss: 30.3141
# Epoch 188/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10259.7692 - reconstruction_loss: 10224.9033 - kl_loss: 29.7398
# Epoch 189/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10257.4059 - reconstruction_loss: 10224.1250 - kl_loss: 28.7089
# Epoch 190/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10254.1914 - reconstruction_loss: 10221.7188 - kl_loss: 27.8682
# Epoch 191/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10252.4714 - reconstruction_loss: 10220.2900 - kl_loss: 26.9048
# Epoch 192/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10248.2692 - reconstruction_loss: 10217.5889 - kl_loss: 25.5916
# Epoch 193/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10245.3199 - reconstruction_loss: 10214.9287 - kl_loss: 24.5374
# Epoch 194/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10239.5893 - reconstruction_loss: 10210.3125 - kl_loss: 22.6335
# Epoch 195/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10233.2436 - reconstruction_loss: 10204.7744 - kl_loss: 21.6414
# Epoch 196/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10227.4950 - reconstruction_loss: 10198.5400 - kl_loss: 20.4033
# Epoch 197/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10217.6758 - reconstruction_loss: 10188.8721 - kl_loss: 19.6935
# Epoch 198/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10203.8400 - reconstruction_loss: 10175.9980 - kl_loss: 18.2770
# Epoch 199/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10191.6782 - reconstruction_loss: 10164.6738 - kl_loss: 17.9577
# Epoch 200/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10173.9876 - reconstruction_loss: 10147.0498 - kl_loss: 17.2195
# Epoch 201/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10162.1205 - reconstruction_loss: 10131.5557 - kl_loss: 16.9692
# Epoch 202/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10146.7376 - reconstruction_loss: 10115.3594 - kl_loss: 16.8433
# Epoch 203/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10137.6464 - reconstruction_loss: 10105.8721 - kl_loss: 16.9817
# Epoch 204/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10125.3034 - reconstruction_loss: 10094.6406 - kl_loss: 16.9194
# Epoch 205/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10114.0775 - reconstruction_loss: 10083.6260 - kl_loss: 16.8297
# Epoch 206/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10107.6279 - reconstruction_loss: 10077.8828 - kl_loss: 16.7280
# Epoch 207/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10101.3312 - reconstruction_loss: 10070.9639 - kl_loss: 16.7558
# Epoch 208/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10096.5616 - reconstruction_loss: 10066.5439 - kl_loss: 16.5698
# Epoch 209/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10092.2045 - reconstruction_loss: 10061.8994 - kl_loss: 16.5418
# Epoch 210/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10086.7676 - reconstruction_loss: 10057.1973 - kl_loss: 16.4075
# Epoch 211/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10084.5423 - reconstruction_loss: 10054.2451 - kl_loss: 16.2980
# Epoch 212/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10081.1940 - reconstruction_loss: 10051.1289 - kl_loss: 16.1093
# Epoch 213/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10076.9809 - reconstruction_loss: 10047.7715 - kl_loss: 15.8066
# Epoch 214/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10073.8413 - reconstruction_loss: 10044.5898 - kl_loss: 15.6155
# Epoch 215/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10071.6691 - reconstruction_loss: 10041.6582 - kl_loss: 15.5012
# Epoch 216/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10068.9912 - reconstruction_loss: 10039.4746 - kl_loss: 15.1865
# Epoch 217/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10067.3052 - reconstruction_loss: 10038.3135 - kl_loss: 15.0338
# Epoch 218/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10064.3967 - reconstruction_loss: 10035.0420 - kl_loss: 14.9079
# Epoch 219/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10061.8893 - reconstruction_loss: 10033.3867 - kl_loss: 14.6870
# Epoch 220/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10060.0311 - reconstruction_loss: 10030.9854 - kl_loss: 14.3991
# Epoch 221/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10057.4965 - reconstruction_loss: 10029.4238 - kl_loss: 14.3810
# Epoch 222/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10055.7870 - reconstruction_loss: 10027.3916 - kl_loss: 14.0964
# Epoch 223/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10055.6010 - reconstruction_loss: 10026.2539 - kl_loss: 14.0086
# Epoch 224/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10051.6943 - reconstruction_loss: 10023.5322 - kl_loss: 13.8999
# Epoch 225/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10052.1365 - reconstruction_loss: 10022.5439 - kl_loss: 13.9044
# Epoch 226/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10048.9539 - reconstruction_loss: 10020.7471 - kl_loss: 13.6273
# Epoch 227/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10048.3960 - reconstruction_loss: 10019.3320 - kl_loss: 13.5886
# Epoch 228/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10046.7063 - reconstruction_loss: 10018.1660 - kl_loss: 13.4117
# Epoch 229/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10045.8740 - reconstruction_loss: 10016.6133 - kl_loss: 13.2417
# Epoch 230/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 10042.2339 - reconstruction_loss: 10014.5527 - kl_loss: 13.1258
# Epoch 231/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 10042.6249 - reconstruction_loss: 10014.0176 - kl_loss: 12.9841
# Epoch 232/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 10040.4255 - reconstruction_loss: 10011.8408 - kl_loss: 13.0074
# Epoch 233/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10038.5088 - reconstruction_loss: 10009.9492 - kl_loss: 12.8354
# Epoch 234/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10036.9899 - reconstruction_loss: 10009.0713 - kl_loss: 12.6986
# Epoch 235/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10034.8177 - reconstruction_loss: 10006.8486 - kl_loss: 12.5485
# Epoch 236/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10034.9092 - reconstruction_loss: 10006.3936 - kl_loss: 12.5833
# Epoch 237/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10033.1212 - reconstruction_loss: 10005.6670 - kl_loss: 12.4502
# Epoch 238/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10032.5977 - reconstruction_loss: 10004.2051 - kl_loss: 12.1954
# Epoch 239/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10031.8292 - reconstruction_loss: 10003.0117 - kl_loss: 12.2507
# Epoch 240/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10029.4045 - reconstruction_loss: 10001.2744 - kl_loss: 12.0714
# Epoch 241/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10027.8345 - reconstruction_loss: 10000.1992 - kl_loss: 12.0214
# Epoch 242/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10027.1838 - reconstruction_loss: 9999.4541 - kl_loss: 11.8369
# Epoch 243/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10026.4904 - reconstruction_loss: 9998.6250 - kl_loss: 11.9052
# Epoch 244/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10027.2307 - reconstruction_loss: 9998.5928 - kl_loss: 11.8197
# Epoch 245/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10022.8209 - reconstruction_loss: 9996.2617 - kl_loss: 11.7619
# Epoch 246/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 10022.8735 - reconstruction_loss: 9995.0264 - kl_loss: 11.6558
# Epoch 247/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10020.5933 - reconstruction_loss: 9993.6992 - kl_loss: 11.5243
# Epoch 248/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10022.2402 - reconstruction_loss: 9993.7158 - kl_loss: 11.5414
# Epoch 249/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 10021.1511 - reconstruction_loss: 9992.5049 - kl_loss: 11.5019
# Epoch 250/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10018.5724 - reconstruction_loss: 9991.4092 - kl_loss: 11.4530
# Epoch 251/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 10019.3388 - reconstruction_loss: 9990.3281 - kl_loss: 11.3234
# Epoch 252/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 10015.9802 - reconstruction_loss: 9989.1846 - kl_loss: 11.2843
# Epoch 253/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 10014.4323 - reconstruction_loss: 9987.9160 - kl_loss: 11.2274
# Epoch 254/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 10013.7072 - reconstruction_loss: 9987.2393 - kl_loss: 11.2074
# Epoch 255/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10013.5952 - reconstruction_loss: 9986.4404 - kl_loss: 11.1313
# Epoch 256/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 10011.3124 - reconstruction_loss: 9984.8193 - kl_loss: 11.1593
# Epoch 257/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 10013.6125 - reconstruction_loss: 9984.9238 - kl_loss: 11.0926
# Epoch 258/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10009.8741 - reconstruction_loss: 9983.2471 - kl_loss: 10.9640
# Epoch 259/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10011.0253 - reconstruction_loss: 9982.5820 - kl_loss: 10.9430
# Epoch 260/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10009.9662 - reconstruction_loss: 9982.1475 - kl_loss: 10.9621
# Epoch 261/2000
# 47/47 [==============================] - 6s 129ms/step - loss: 10008.0179 - reconstruction_loss: 9980.6094 - kl_loss: 10.8945
# Epoch 262/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10005.9841 - reconstruction_loss: 9979.3516 - kl_loss: 10.7519
# Epoch 263/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10006.5674 - reconstruction_loss: 9979.2773 - kl_loss: 10.7226
# Epoch 264/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10004.9677 - reconstruction_loss: 9978.8506 - kl_loss: 10.7050
# Epoch 265/2000
# 47/47 [==============================] - 6s 133ms/step - loss: 10004.9894 - reconstruction_loss: 9977.6650 - kl_loss: 10.7097
# Epoch 266/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10005.6330 - reconstruction_loss: 9977.0449 - kl_loss: 10.6769
# Epoch 267/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10002.3659 - reconstruction_loss: 9975.0068 - kl_loss: 10.6537
# Epoch 268/2000
# 47/47 [==============================] - 6s 133ms/step - loss: 10001.0580 - reconstruction_loss: 9974.6387 - kl_loss: 10.5388
# Epoch 269/2000
# 47/47 [==============================] - 6s 131ms/step - loss: 10000.1314 - reconstruction_loss: 9973.7715 - kl_loss: 10.4764
# Epoch 270/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 10000.6528 - reconstruction_loss: 9973.0605 - kl_loss: 10.4802
# Epoch 271/2000
# 47/47 [==============================] - 6s 130ms/step - loss: 9999.0694 - reconstruction_loss: 9972.6709 - kl_loss: 10.4578
# Epoch 272/2000
# 47/47 [==============================] - 6s 132ms/step - loss: 9998.3351 - reconstruction_loss: 9971.3848 - kl_loss: 10.4862
# Epoch 273/2000
# 47/47 [==============================] - 6s 132ms/step - loss: 9997.8390 - reconstruction_loss: 9971.5908 - kl_loss: 10.4164
# Epoch 274/2000
# 47/47 [==============================] - 6s 132ms/step - loss: 9995.1230 - reconstruction_loss: 9969.4971 - kl_loss: 10.4551
# Epoch 275/2000
# 47/47 [==============================] - 6s 133ms/step - loss: 9995.6785 - reconstruction_loss: 9968.4873 - kl_loss: 10.3297
# Epoch 276/2000
# 47/47 [==============================] - 6s 133ms/step - loss: 9994.4793 - reconstruction_loss: 9968.4502 - kl_loss: 10.4356
# Epoch 277/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9994.2590 - reconstruction_loss: 9967.4473 - kl_loss: 10.3086
# Epoch 278/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9994.2224 - reconstruction_loss: 9967.6533 - kl_loss: 10.2987
# Epoch 279/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9993.2303 - reconstruction_loss: 9966.6055 - kl_loss: 10.3546
# Epoch 280/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9992.0145 - reconstruction_loss: 9965.9746 - kl_loss: 10.3613
# Epoch 281/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9991.7713 - reconstruction_loss: 9965.4307 - kl_loss: 10.2949
# Epoch 282/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9990.3296 - reconstruction_loss: 9963.7715 - kl_loss: 10.2649
# Epoch 283/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9988.9463 - reconstruction_loss: 9963.0166 - kl_loss: 10.2681
# Epoch 284/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9988.7974 - reconstruction_loss: 9962.4180 - kl_loss: 10.2883
# Epoch 285/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9987.3541 - reconstruction_loss: 9961.8711 - kl_loss: 10.2115
# Epoch 286/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9986.9771 - reconstruction_loss: 9961.5791 - kl_loss: 10.1148
# Epoch 287/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9987.7307 - reconstruction_loss: 9961.0156 - kl_loss: 10.1956
# Epoch 288/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9985.6397 - reconstruction_loss: 9960.1006 - kl_loss: 10.1778
# Epoch 289/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9987.2790 - reconstruction_loss: 9959.7568 - kl_loss: 10.1567
# Epoch 290/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9985.4883 - reconstruction_loss: 9958.9238 - kl_loss: 10.1297
# Epoch 291/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9984.8476 - reconstruction_loss: 9959.0625 - kl_loss: 10.1456
# Epoch 292/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9984.5750 - reconstruction_loss: 9957.9775 - kl_loss: 10.1576
# Epoch 293/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9983.3238 - reconstruction_loss: 9956.6719 - kl_loss: 10.1502
# Epoch 294/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9982.2906 - reconstruction_loss: 9955.9062 - kl_loss: 10.1663
# Epoch 295/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9982.3695 - reconstruction_loss: 9954.9766 - kl_loss: 10.0408
# Epoch 296/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9981.0524 - reconstruction_loss: 9955.2051 - kl_loss: 9.9478
# Epoch 297/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9979.1470 - reconstruction_loss: 9954.5723 - kl_loss: 10.0682
# Epoch 298/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9979.9630 - reconstruction_loss: 9953.9932 - kl_loss: 10.0615
# Epoch 299/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9980.0948 - reconstruction_loss: 9953.9775 - kl_loss: 10.0275
# Epoch 300/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9977.2533 - reconstruction_loss: 9951.8701 - kl_loss: 9.8932
# Epoch 301/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9977.9719 - reconstruction_loss: 9951.9492 - kl_loss: 10.0655
# Epoch 302/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9977.1439 - reconstruction_loss: 9951.2764 - kl_loss: 9.9782
# Epoch 303/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9976.2480 - reconstruction_loss: 9950.7012 - kl_loss: 9.9806
# Epoch 304/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9977.5355 - reconstruction_loss: 9951.1758 - kl_loss: 10.0484
# Epoch 305/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9975.1949 - reconstruction_loss: 9949.5498 - kl_loss: 9.9598
# Epoch 306/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9975.2982 - reconstruction_loss: 9949.2598 - kl_loss: 10.0050
# Epoch 307/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9974.4868 - reconstruction_loss: 9948.5283 - kl_loss: 9.9397
# Epoch 308/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 9973.8244 - reconstruction_loss: 9947.8467 - kl_loss: 9.8999
# Epoch 309/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 9973.8925 - reconstruction_loss: 9947.7305 - kl_loss: 9.8832
# Epoch 310/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 9973.8375 - reconstruction_loss: 9947.3555 - kl_loss: 10.0299
# Epoch 311/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9971.6992 - reconstruction_loss: 9946.4824 - kl_loss: 9.9379
# Epoch 312/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9971.3731 - reconstruction_loss: 9945.3457 - kl_loss: 9.8189
# Epoch 313/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9970.8067 - reconstruction_loss: 9944.8838 - kl_loss: 9.9057
# Epoch 314/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9969.7464 - reconstruction_loss: 9944.5293 - kl_loss: 9.8729
# Epoch 315/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9969.5460 - reconstruction_loss: 9944.4541 - kl_loss: 9.9436
# Epoch 316/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9970.0570 - reconstruction_loss: 9943.7598 - kl_loss: 9.9239
# Epoch 317/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9968.9390 - reconstruction_loss: 9942.8623 - kl_loss: 9.9182
# Epoch 318/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9967.0394 - reconstruction_loss: 9941.8232 - kl_loss: 9.8434
# Epoch 319/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9967.3424 - reconstruction_loss: 9941.9814 - kl_loss: 9.9715
# Epoch 320/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9967.9785 - reconstruction_loss: 9941.3652 - kl_loss: 9.9092
# Epoch 321/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9966.3732 - reconstruction_loss: 9940.6533 - kl_loss: 9.9226
# Epoch 322/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9967.3551 - reconstruction_loss: 9940.2930 - kl_loss: 10.0510
# Epoch 323/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9964.8073 - reconstruction_loss: 9938.8613 - kl_loss: 9.9400
# Epoch 324/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 9964.8275 - reconstruction_loss: 9938.2412 - kl_loss: 9.9912
# ...
# Epoch 1888/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9821.7819 - reconstruction_loss: 9774.8467 - kl_loss: 25.6806
# Epoch 1889/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9817.3571 - reconstruction_loss: 9773.4443 - kl_loss: 25.7602
# Epoch 1890/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9818.8913 - reconstruction_loss: 9773.6572 - kl_loss: 26.0409
# Epoch 1891/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9817.6631 - reconstruction_loss: 9771.9141 - kl_loss: 26.0665
# Epoch 1892/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9817.6484 - reconstruction_loss: 9774.3018 - kl_loss: 26.0233
# Epoch 1893/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9818.7146 - reconstruction_loss: 9772.2305 - kl_loss: 26.4613
# Epoch 1894/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9815.8323 - reconstruction_loss: 9771.4404 - kl_loss: 26.5084
# Epoch 1895/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9817.0443 - reconstruction_loss: 9769.8428 - kl_loss: 26.6832
# Epoch 1896/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9816.2016 - reconstruction_loss: 9770.1592 - kl_loss: 26.5924
# Epoch 1897/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9815.8162 - reconstruction_loss: 9768.7930 - kl_loss: 26.7092
# Epoch 1898/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9814.5935 - reconstruction_loss: 9768.5283 - kl_loss: 26.6519
# Epoch 1899/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9814.2719 - reconstruction_loss: 9768.5566 - kl_loss: 26.7010
# Epoch 1900/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9814.0866 - reconstruction_loss: 9768.2471 - kl_loss: 26.8259
# Epoch 1901/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9813.3569 - reconstruction_loss: 9767.0127 - kl_loss: 26.8205
# Epoch 1902/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9811.2252 - reconstruction_loss: 9765.5029 - kl_loss: 26.8233
# Epoch 1903/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9811.6557 - reconstruction_loss: 9764.8242 - kl_loss: 26.7488
# Epoch 1904/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9811.4515 - reconstruction_loss: 9768.4883 - kl_loss: 26.6955
# Epoch 1905/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9815.7056 - reconstruction_loss: 9769.3086 - kl_loss: 26.0324
# Epoch 1906/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9812.3323 - reconstruction_loss: 9765.6201 - kl_loss: 26.7982
# Epoch 1907/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9809.8133 - reconstruction_loss: 9764.2236 - kl_loss: 27.3449
# Epoch 1908/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9810.2042 - reconstruction_loss: 9763.4482 - kl_loss: 27.6533
# Epoch 1909/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9810.6603 - reconstruction_loss: 9762.6172 - kl_loss: 27.6681
# Epoch 1910/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9809.2092 - reconstruction_loss: 9762.1338 - kl_loss: 27.6955
# Epoch 1911/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9809.7240 - reconstruction_loss: 9762.6367 - kl_loss: 27.8478
# Epoch 1912/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9809.4198 - reconstruction_loss: 9762.0176 - kl_loss: 28.0763
# Epoch 1913/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9808.2187 - reconstruction_loss: 9760.0225 - kl_loss: 27.9405
# Epoch 1914/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9809.1410 - reconstruction_loss: 9760.8467 - kl_loss: 27.9537
# Epoch 1915/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9807.3183 - reconstruction_loss: 9759.4863 - kl_loss: 28.0132
# Epoch 1916/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9808.0818 - reconstruction_loss: 9759.6279 - kl_loss: 28.1606
# Epoch 1917/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9807.1848 - reconstruction_loss: 9758.9551 - kl_loss: 28.1285
# Epoch 1918/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9805.4903 - reconstruction_loss: 9758.8135 - kl_loss: 28.2465
# Epoch 1919/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9807.9655 - reconstruction_loss: 9758.9961 - kl_loss: 28.3837
# Epoch 1920/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9805.3832 - reconstruction_loss: 9757.5391 - kl_loss: 28.4928
# Epoch 1921/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9805.1359 - reconstruction_loss: 9758.1182 - kl_loss: 28.6185
# Epoch 1922/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9807.3517 - reconstruction_loss: 9757.1943 - kl_loss: 28.8933
# Epoch 1923/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9804.8702 - reconstruction_loss: 9755.8633 - kl_loss: 29.0096
# Epoch 1924/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9803.4714 - reconstruction_loss: 9754.8760 - kl_loss: 28.8987
# Epoch 1925/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9803.1049 - reconstruction_loss: 9755.4951 - kl_loss: 29.1367
# Epoch 1926/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9802.5000 - reconstruction_loss: 9753.3154 - kl_loss: 29.3042
# Epoch 1927/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9801.6206 - reconstruction_loss: 9754.8008 - kl_loss: 29.2003
# Epoch 1928/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9801.5119 - reconstruction_loss: 9753.7598 - kl_loss: 29.4293
# Epoch 1929/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9802.1745 - reconstruction_loss: 9752.9531 - kl_loss: 29.4059
# Epoch 1930/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9803.6570 - reconstruction_loss: 9752.9766 - kl_loss: 29.5176
# Epoch 1931/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9800.2549 - reconstruction_loss: 9750.4941 - kl_loss: 29.4382
# Epoch 1932/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9800.5270 - reconstruction_loss: 9750.8457 - kl_loss: 29.3661
# Epoch 1933/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9799.8892 - reconstruction_loss: 9750.5811 - kl_loss: 29.4030
# Epoch 1934/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9800.2305 - reconstruction_loss: 9750.2305 - kl_loss: 29.4743
# Epoch 1935/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9803.9928 - reconstruction_loss: 9751.7627 - kl_loss: 29.7501
# Epoch 1936/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9798.1402 - reconstruction_loss: 9748.2861 - kl_loss: 29.6945
# Epoch 1937/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9797.7936 - reconstruction_loss: 9748.2090 - kl_loss: 29.6554
# Epoch 1938/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9796.3214 - reconstruction_loss: 9747.9121 - kl_loss: 29.4441
# Epoch 1939/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9796.4264 - reconstruction_loss: 9747.6211 - kl_loss: 29.6139
# Epoch 1940/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9795.4678 - reconstruction_loss: 9745.9893 - kl_loss: 29.8912
# Epoch 1941/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9796.5291 - reconstruction_loss: 9746.4326 - kl_loss: 29.9075
# Epoch 1942/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9795.3434 - reconstruction_loss: 9746.8076 - kl_loss: 29.9406
# Epoch 1943/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9796.9205 - reconstruction_loss: 9746.6230 - kl_loss: 30.2556
# Epoch 1944/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9794.1948 - reconstruction_loss: 9744.6680 - kl_loss: 30.3672
# Epoch 1945/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9794.5001 - reconstruction_loss: 9744.4131 - kl_loss: 30.2887
# Epoch 1946/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9793.5045 - reconstruction_loss: 9743.5000 - kl_loss: 30.3620
# Epoch 1947/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9793.9798 - reconstruction_loss: 9743.2393 - kl_loss: 30.5999
# Epoch 1948/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9793.3907 - reconstruction_loss: 9742.8936 - kl_loss: 30.6950
# Epoch 1949/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9794.3377 - reconstruction_loss: 9743.3174 - kl_loss: 30.8034
# Epoch 1950/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9791.3928 - reconstruction_loss: 9741.3096 - kl_loss: 30.8647
# Epoch 1951/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9792.0837 - reconstruction_loss: 9741.4268 - kl_loss: 30.8755
# Epoch 1952/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9791.5967 - reconstruction_loss: 9740.6289 - kl_loss: 30.9662
# Epoch 1953/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9791.0267 - reconstruction_loss: 9739.9922 - kl_loss: 31.0875
# Epoch 1954/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9790.7246 - reconstruction_loss: 9739.5508 - kl_loss: 31.0166
# Epoch 1955/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9789.3541 - reconstruction_loss: 9740.3281 - kl_loss: 31.1168
# Epoch 1956/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9793.7814 - reconstruction_loss: 9740.1191 - kl_loss: 31.4647
# Epoch 1957/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9789.0056 - reconstruction_loss: 9737.1807 - kl_loss: 31.3839
# Epoch 1958/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9788.8352 - reconstruction_loss: 9740.5391 - kl_loss: 31.4006
# Epoch 1959/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9792.3014 - reconstruction_loss: 9740.1943 - kl_loss: 30.9341
# Epoch 1960/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9788.4397 - reconstruction_loss: 9737.0576 - kl_loss: 31.8100
# Epoch 1961/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9788.1327 - reconstruction_loss: 9735.6680 - kl_loss: 32.1035
# Epoch 1962/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9786.9483 - reconstruction_loss: 9733.9277 - kl_loss: 32.2341
# Epoch 1963/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9786.1715 - reconstruction_loss: 9734.2920 - kl_loss: 32.0946
# Epoch 1964/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9785.1650 - reconstruction_loss: 9734.0078 - kl_loss: 32.0772
# Epoch 1965/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9786.0677 - reconstruction_loss: 9734.4082 - kl_loss: 32.2802
# Epoch 1966/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9783.9232 - reconstruction_loss: 9732.4824 - kl_loss: 32.1157
# Epoch 1967/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9786.2992 - reconstruction_loss: 9732.9424 - kl_loss: 32.1591
# Epoch 1968/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9785.3411 - reconstruction_loss: 9731.9414 - kl_loss: 32.2367
# Epoch 1969/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9784.1212 - reconstruction_loss: 9731.8047 - kl_loss: 32.2670
# Epoch 1970/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9784.5492 - reconstruction_loss: 9731.3115 - kl_loss: 32.4124
# Epoch 1971/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9782.8962 - reconstruction_loss: 9730.3984 - kl_loss: 32.3972
# Epoch 1972/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9782.1427 - reconstruction_loss: 9730.5088 - kl_loss: 32.5834
# Epoch 1973/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9780.2985 - reconstruction_loss: 9728.3701 - kl_loss: 32.6777
# Epoch 1974/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9780.6264 - reconstruction_loss: 9728.1416 - kl_loss: 32.8904
# Epoch 1975/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9780.6017 - reconstruction_loss: 9727.9102 - kl_loss: 32.9592
# Epoch 1976/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9779.9686 - reconstruction_loss: 9727.2490 - kl_loss: 32.9408
# Epoch 1977/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9778.6086 - reconstruction_loss: 9726.3926 - kl_loss: 32.9401
# Epoch 1978/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9781.5557 - reconstruction_loss: 9730.9199 - kl_loss: 33.1646
# Epoch 1979/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9781.4001 - reconstruction_loss: 9727.0215 - kl_loss: 33.5843
# Epoch 1980/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9780.6298 - reconstruction_loss: 9726.1748 - kl_loss: 33.6880
# Epoch 1981/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9779.2919 - reconstruction_loss: 9724.8467 - kl_loss: 33.7375
# Epoch 1982/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9777.9058 - reconstruction_loss: 9724.3945 - kl_loss: 33.7125
# Epoch 1983/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 9778.5865 - reconstruction_loss: 9724.0527 - kl_loss: 33.8088
# Epoch 1984/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9776.6144 - reconstruction_loss: 9723.6543 - kl_loss: 33.7017
# Epoch 1985/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9776.0299 - reconstruction_loss: 9722.5742 - kl_loss: 33.7480
# Epoch 1986/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9776.5452 - reconstruction_loss: 9723.3545 - kl_loss: 33.8227
# Epoch 1987/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9776.2389 - reconstruction_loss: 9722.1855 - kl_loss: 33.6975
# Epoch 1988/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9776.8217 - reconstruction_loss: 9722.4922 - kl_loss: 33.9422
# Epoch 1989/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9774.6064 - reconstruction_loss: 9720.9121 - kl_loss: 34.0210
# Epoch 1990/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9774.9388 - reconstruction_loss: 9721.0703 - kl_loss: 34.0937
# Epoch 1991/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9772.8342 - reconstruction_loss: 9718.9111 - kl_loss: 34.1591
# Epoch 1992/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9773.0031 - reconstruction_loss: 9719.0430 - kl_loss: 34.1707
# Epoch 1993/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9772.6996 - reconstruction_loss: 9718.9717 - kl_loss: 34.0895
# Epoch 1994/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9772.6581 - reconstruction_loss: 9718.3506 - kl_loss: 34.0634
# Epoch 1995/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9773.3193 - reconstruction_loss: 9719.0791 - kl_loss: 34.0157
# Epoch 1996/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9772.5243 - reconstruction_loss: 9717.6973 - kl_loss: 34.2486
# Epoch 1997/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9772.7032 - reconstruction_loss: 9717.9531 - kl_loss: 34.3884
# Epoch 1998/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9772.0887 - reconstruction_loss: 9716.6748 - kl_loss: 34.4160
# Epoch 1999/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9772.6591 - reconstruction_loss: 9717.7012 - kl_loss: 34.5526
# Epoch 2000/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 9770.7729 - reconstruction_loss: 9715.6973 - kl_loss: 34.8397

# %%
### Guardar modelohttps://www.tensorflow.org/guide/saved_model?hl=es-419
vae.encoder.save('Models/GDirVAE_encoder_DRY_1_32.h5')
vae.decoder.save('Models/GDirVAE_decoder_DRY_1_32.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2023-11-01 03:29:39.086407: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.
