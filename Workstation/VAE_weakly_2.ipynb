# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['TF_ENABLE_ONEDNN_OPTS'] =  "0"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

## Librerías
import seaborn as sns
import sys
import cv2 as cv2
import glob
from PIL import Image
import tensorflow as tf
import sys
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import gc
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
import os


from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler

print(tf.__version__)
# Out:
# 2023-10-25 23:17:10.113181: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-25 23:17:10.113216: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-25 23:17:10.113237: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-25 23:17:10.118633: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.14.0

# %%
## Uso de GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# 2023-10-25 23:17:11.458940: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:11.462832: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:11.462982: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
## Obtener todas las rutas de las imágenes en el dataset
ruta = '../Datasets/Micrografías_segmentadas/secas/*/*/*/*.jpg'
rutas_dataset  = glob.glob('../../../Datasets/Micrografías segmentaciones/secas/*/*/*/*.jpg')

## Separar rutas
mask_list = []
image_list = []
for ruta in rutas_dataset:    
    ruta_list = ruta.split('/')       
    clase = ruta_list[6]
    number = ruta_list[7]
    tipo = ruta_list[8]
    name = ruta_list[9].split('.')[0]
    
    if tipo == 'train':
        image_list.append([name,ruta,clase,number])
    elif tipo == 'mask_bin':
        mask_list.append([name,ruta,clase,number])
    else:
        None

mask_pd = pd.DataFrame(mask_list,columns=['name','route_mask','label','number']).sort_values(by='name')
image_pd = pd.DataFrame(image_list,columns=['name','route_image','label','number']).sort_values(by='name')

routes_dataset = image_pd.merge(mask_pd,on=['name','label','number'],how='left')

routes_dataset.dropna(inplace=True)

routes_dataset = routes_dataset.sample(frac = 1)

print('Imágenes secas:', np.shape(routes_dataset)[0])
print('MF1:', '- secas: ', np.shape(routes_dataset[routes_dataset['label']=='MF1'])[0])
print('MF2:', '- secas: ', np.shape(routes_dataset[routes_dataset['label']=='MF2'])[0])
print('MF3:', '- secas: ', np.shape(routes_dataset[routes_dataset['label']=='MF3'])[0])

char_to_num = {'MF1':'0','MF2':'1','MF3':'2'}

routes_dataset['label'].replace(char_to_num,inplace=True)

routes_dataset
# Out:
# Imágenes secas: 923
# MF1: - secas:  378
# MF2: - secas:  284
# MF3: - secas:  261
#                         name  \
# 207  IMG_20230707_170612_jpg
# 867  IMG_20230711_214815_jpg
# 281  IMG_20230707_173848_jpg
# 209  IMG_20230707_170638_jpg
# 226  IMG_20230707_170921_jpg
# ..                       ...
# 454  IMG_20230707_191631_jpg
# 742  IMG_20230711_182619_jpg
# 624  IMG_20230711_165942_jpg
# 594  IMG_20230711_163624_jpg
# 170  IMG_20230707_164323_jpg
#
#                                            route_image label number  \
# 207  ../../../Datasets/Micrografías segmentaciones/...     0      3
# 867  ../../../Datasets/Micrografías segmentaciones/...     2      6
# 281  ../../../Datasets/Micrografías segmentaciones/...     0      4
# 209  ../../../Datasets/Micrografías segmentaciones/...     0      3
# 226  ../../../Datasets/Micrografías segmentaciones/...     0      3
# ..                                                 ...   ...    ...
# 454  ../../../Datasets/Micrografías segmentaciones/...     0      7
# 742  ../../../Datasets/Micrografías segmentaciones/...     1      7
# 624  ../../../Datasets/Micrografías segmentaciones/...     1      4
# 594  ../../../Datasets/Micrografías segmentaciones/...     1      3
# 170  ../../../Datasets/Micrografías segmentaciones/...     0      2
#
#                                             route_mask
# 207  ../../../Datasets/Micrografías segmentaciones/...
# 867  ../../../Datasets/Micrografías segmentaciones/...
# 281  ../../../Datasets/Micrografías segmentaciones/...
# 209  ../../../Datasets/Micrografías segmentaciones/...
# 226  ../../../Datasets/Micrografías segmentaciones/...
# ..                                                 ...
# 454  ../../../Datasets/Micrografías segmentaciones/...
# 742  ../../../Datasets/Micrografías segmentaciones/...
# 624  ../../../Datasets/Micrografías segmentaciones/...
# 594  ../../../Datasets/Micrografías segmentaciones/...
# 170  ../../../Datasets/Micrografías segmentaciones/...
#
# [923 rows x 5 columns]

# %%
## Establecer el porcentaje de separación
thold1 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='0'])))
thold2 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='1'])))
thold3 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='2'])))

## Separar por clases para entrenamiento
train_cu1 = routes_dataset[routes_dataset.label == '0'][0:thold1]
train_cu2 = routes_dataset[routes_dataset.label == '1'][0:thold2]
train_cu3 = routes_dataset[routes_dataset.label == '2'][0:thold3]

## tomar las demás imágenes para test
test_cu1 = routes_dataset[routes_dataset.label == '0'][thold1:]
test_cu2 = routes_dataset[routes_dataset.label == '1'][thold2:]
test_cu3 = routes_dataset[routes_dataset.label == '2'][thold3:]


## Constuir un solo dataset de training
train_df =  pd.concat([pd.concat([train_cu1,train_cu2]),train_cu3]).sample(frac=1,random_state=42).reset_index(drop=True)

## Construir un solo dataset de test
test_df = pd.concat([pd.concat([test_cu1,test_cu2]),test_cu3]).sample(frac=1,random_state=42).reset_index(drop=True)

## Cantidad de muestras por clase
print('Clase MF1: train: ',len(train_cu1),', test: ',len(test_cu1))
print('Clase MF2: train: ',len(train_cu2),', test: ',len(test_cu2))
print('Clase MF3: train: ',len(train_cu3),', test: ',len(test_cu3))
# Out:
# Clase MF1: train:  303 , test:  75
# Clase MF2: train:  228 , test:  56
# Clase MF3: train:  209 , test:  52

# %%
def get_contours_and_features(binary_map):
    #contours_map  = np.zeros_like(binary_map)
    binary_map = cv2.cvtColor(binary_map, cv2.COLOR_BGR2GRAY)
    contours, hierarchy = cv2.findContours(binary_map, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    #contours_map = cv2.drawContours(contours_map, contours, -1, 255, 1)
    contours_features = []
    for contour in contours:
        error = 1e-5

        moments = cv2.moments(contour)
        cx = moments['m10'] / (moments['m00'] + error)
        cy = moments['m01'] / (moments['m00'] + error)
        center_of_mass = [cx, cy]
        features = {
            'area': cv2.contourArea(contour),
            'perimeter': cv2.arcLength(contour, True),
            'moments': moments,
            'center_of_mass': center_of_mass,
            'contour': contour
        }
        contours_features.append(features)
        del features    
    return contours_features

def get_item(contour_features, key='area'):
    areas = []
    for contour_feature in contour_features:
        area =  contour_feature[key]
        areas.append(area)
    return areas

def load_image(file_name):
  raw = tf.io.read_file(file_name)
  tensor = tf.io.decode_jpeg(raw,channels=1)
  tensor = tf.image.resize(tensor, [128,128])
  tensor = tf.cast(tensor, tf.float32) / 255.0
  return tensor

def get_binary_image(filenames):
    tensores = []
    for filename in filenames:
        raw = tf.io.read_file(filename)
        tensor = tf.io.decode_jpeg(raw,channels=3)
        tensor = tf.image.resize(tensor, [128,128])
        tensor = tf.cast(tensor, tf.float32) / 255.0
        tensores.append(tensor)
    return tensores

def get_geometric_atributes(binary_images):
    atributes = []
    for binary_img in binary_images:
        ## Formato
        image = binary_img.numpy().astype(np.uint8)       
        
        ## Capturar contornos
        contour_features = get_contours_and_features(image)        

        ## obtener área de poros
        area = np.ceil(np.sum(get_item(contour_features, key='area')))

        ## obtener perímetro de poros
        perimetro = np.ceil(np.sum(get_item(contour_features, key='perimeter'))
)
        ## intersticio
        area_total = np.ceil(np.shape(image)[0] * np.shape(image)[1])
        intersticio = np.ceil(area_total - area)

        ## Cantidad de poros
        poros = np.shape(contour_features)[0]

        #atributes = [area,perimetro,intersticio,poros]
        atributes.append([area,perimetro,intersticio,poros])
    
    return atributes

def create_dataset(buffer,file_names, labels, file_mask):    
  images = get_binary_image(file_mask)
  attributes = get_geometric_atributes(images)
  dataset = tf.data.Dataset.from_tensor_slices((file_names,labels,attributes ))
  dataset.shuffle(buffer_size=buffer)
  dataset = dataset.map(lambda file_name, label, attributes : (load_image(file_name), label, attributes ))
  
  return dataset

file_names = train_df['route_image'].to_numpy()
file_mask = train_df['route_mask'].to_numpy()
labels = train_df['label'].to_numpy()
dataset = create_dataset(16,file_names, labels,file_mask)
# Out:
# 2023-10-25 23:17:11.708661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:11.708827: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:11.708929: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:12.315859: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:12.315995: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:12.316101: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-25 23:17:12.316186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7662 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:08:00.0, compute capability: 8.6

# %%
cnt = 0
for i in dataset.batch(16):
    a = i[0]
    b = i[1]
    c = i[2]

n =  0
print(c[n].numpy())
print(b[n].numpy())
plt.imshow(a[n],cmap='gray')
# Out:
# [ 6305.  1846. 10079.    31.]
# b'0'

# %% [markdown]
# ## MODELO

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class VAE(keras.Model):
    def __init__(self, encoder, decoder, regressor, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.regressor = regressor
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")        
        self.estimation_loss_tracker = keras.metrics.Mean(name="estimation_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.estimation_loss_tracker,            
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            ## Valores estimados por el encoder
            z_mean, z_log_var, z = self.encoder(data[0])
            
            ## Valores geométricos asociados a los datos
            geometrics_features = data[2]

            ## Reconstrucción del embebido del encoder
            reconstruction = self.decoder(z)            

            ## Reducción de la reconstrucción
            reconstruction /= tf.reduce_max(reconstruction)

            ## Valores estimados apartir del regresor
            estimation = self.regressor(reconstruction)
            
            ## Error de reconstrucción
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data[0], reconstruction), axis=(1, 2)
                )
            )

            '''
            reconstruction_loss =tf.reduce_mean(
                tf.reduce_sum( tf.keras.losses.MeanSquaredError()(data, reconstruction)
                             )
            )
            '''
            
            ## Error de estimación de valores geométricos
            estimation_loss = tf.reduce_mean(tf.keras.losses.MeanSquaredError()(geometrics_features, estimation))
            
            
            ## Error de divergencia KL
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))   

            ## Error total          
            total_loss = reconstruction_loss + kl_loss + estimation_loss
        
        ## Actualización de los gradientes
        grads = tape.gradient(total_loss, self.trainable_weights)

        ## Actualización de lA RECONSTRUCCIÓN
        self.reconstruction = reconstruction

        ### Actualización de los pesos
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)   
        self.estimation_loss_tracker.update_state(estimation_loss)    
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(), 
            "ArithmeticError": self.estimation_loss_tracker.result(),        
        }

# %%
###_____________________________ENCODER________________________##
latent_dim = 32

nx, ny = 128, 128

encoder_inputs = keras.Input(shape=(nx, ny,1))

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E1')(encoder_inputs)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E2')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same',name='layer_E3')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same',name='layer_E4')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_E6')(x)
x = layers.Flatten()(x)



z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(inputs=encoder_inputs, outputs=[z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  layer_E1 (Conv2D)           (None, 128, 128, 1024)       10240     ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 1024)         0         ['layer_E1[0][0]']
#  D)
#
#  batch_normalization (Batch  (None, 64, 64, 1024)         4096      ['max_pooling2d[0][0]']
#  Normalization)
#
#  layer_E2 (Conv2D)           (None, 64, 64, 1024)         9438208   ['batch_normalization[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 1024)         0         ['layer_E2[0][0]']
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 32, 32, 1024)         4096      ['max_pooling2d_1[0][0]']
#  chNormalization)
#
#  layer_E3 (Conv2D)           (None, 32, 32, 512)          4719104   ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 512)          0         ['layer_E3[0][0]']
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 512)          2048      ['max_pooling2d_2[0][0]']
#  chNormalization)
#
#  layer_E4 (Conv2D)           (None, 16, 16, 256)          1179904   ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 256)            0         ['layer_E4[0][0]']
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 8, 8, 256)            1024      ['max_pooling2d_3[0][0]']
#  chNormalization)
#
#  layer_E6 (Conv2D)           (None, 8, 8, 128)            295040    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  flatten (Flatten)           (None, 8192)                 0         ['layer_E6[0][0]']
#
#  z_mean (Dense)              (None, 32)                   262176    ['flatten[0][0]']
#
#  z_log_var (Dense)           (None, 32)                   262176    ['flatten[0][0]']
#
#  sampling (Sampling)         (None, 32)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 16178112 (61.71 MB)
# Trainable params: 16172480 (61.69 MB)
# Non-trainable params: 5632 (22.00 KB)
# __________________________________________________________________________________________________

# %%
## Entrada Z
latent_inputs = keras.Input(shape=(latent_dim,))

##dimensiones
ndim = 16
nfilts = 128

## anti-flatten de la última capa convolucional
x = layers.Dense(ndim * ndim * nfilts, activation="relu")(latent_inputs)

## Reshape para reconstruir la última convolucional
x = layers.Reshape((ndim,ndim, nfilts))(x)

## Capas convolucionales
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D1')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D2')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_D4')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same',name='layer_D6')(x)

decoder_outputs = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='layer_D7')(x)

## Construcción del decoder
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 32768)             1081344
#
#  reshape (Reshape)           (None, 16, 16, 128)       0
#
#  layer_D1 (Conv2D)           (None, 16, 16, 128)       147584
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 128)       0
#  D)
#
#  batch_normalization_4 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  layer_D2 (Conv2D)           (None, 32, 32, 128)       147584
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 128)       0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 64, 64, 128)       512
#  chNormalization)
#
#  layer_D4 (Conv2D)           (None, 64, 64, 64)        73792
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 64)      0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  layer_D6 (Conv2D)           (None, 128, 128, 16)      9232
#
#  layer_D7 (Conv2D)           (None, 128, 128, 1)       145
#
# =================================================================
# Total params: 1460961 (5.57 MB)
# Trainable params: 1460321 (5.57 MB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
### Estimador de valores geométricos

## Input layer
regressor_inputs = keras.Input(shape=(128,128,1))

## Hidden layers
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same',name='layer_R1')(regressor_inputs)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R2')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_R3')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R4')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_R5')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R6')(x)
x = layers.BatchNormalization()(x)

## Output layer
flatten = layers.Flatten()(x)
regressor_outputs = layers.Dense(4, activation="relu")(flatten)

## regressor model
regressor = keras.Model(regressor_inputs, regressor_outputs, name="regressor")
regressor.summary()
# Out:
# Model: "regressor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  layer_R1 (Conv2D)           (None, 128, 128, 32)      320
#
#  layer_R2 (MaxPooling2D)     (None, 64, 64, 32)        0
#
#  batch_normalization_7 (Bat  (None, 64, 64, 32)        128
#  chNormalization)
#
#  layer_R3 (Conv2D)           (None, 64, 64, 64)        18496
#
#  layer_R4 (MaxPooling2D)     (None, 32, 32, 64)        0
#
#  batch_normalization_8 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  layer_R5 (Conv2D)           (None, 32, 32, 128)       73856
#
#  layer_R6 (MaxPooling2D)     (None, 16, 16, 128)       0
#
#  batch_normalization_9 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 4)                 131076
#
# =================================================================
# Total params: 224644 (877.52 KB)
# Trainable params: 224196 (875.77 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
vae = VAE(encoder, decoder,regressor)
opt = tf.optimizers.Adam(learning_rate = 0.000001)
#nll = lambda x , rv_x: -rv_x.log_prob(x)
vae.compile(optimizer=opt)


vae.fit(dataset.batch(16), epochs=2000, 
                batch_size=16,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=100)])
# Out:
# Epoch 1/2000
# 2023-10-25 23:18:51.642565: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2023-10-25 23:18:57.170941: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8178013e00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-25 23:18:57.170964: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2023-10-25 23:18:57.214853: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-25 23:18:58.092782: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-10-25 23:19:05.207997: W tensorflow/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2023-10-25 23:19:07.056721: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-25 23:19:07.056939: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 47/47 [==============================] - 43s 211ms/step - loss: 36747469.0833 - reconstruction_loss: 45151.7188 - kl_loss: 0.0030 - ArithmeticError: 36702231.2500
# Epoch 2/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36747404.1667 - reconstruction_loss: 44805.7305 - kl_loss: 0.0033 - ArithmeticError: 36702231.2500
# Epoch 3/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36746615.6667 - reconstruction_loss: 44510.5977 - kl_loss: 0.0041 - ArithmeticError: 36702231.2500
# Epoch 4/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36746708.0000 - reconstruction_loss: 44231.2852 - kl_loss: 0.0053 - ArithmeticError: 36702231.2500
# Epoch 5/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36746666.2500 - reconstruction_loss: 44154.6445 - kl_loss: 0.0069 - ArithmeticError: 36702231.2500
# Epoch 6/2000
# 47/47 [==============================] - 7s 144ms/step - loss: 36746164.2500 - reconstruction_loss: 43791.8125 - kl_loss: 0.0086 - ArithmeticError: 36702231.2500
# Epoch 7/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36745730.6667 - reconstruction_loss: 43554.3945 - kl_loss: 0.0117 - ArithmeticError: 36702231.2500
# Epoch 8/2000
# 47/47 [==============================] - 7s 144ms/step - loss: 36744722.3333 - reconstruction_loss: 42488.6133 - kl_loss: 0.0157 - ArithmeticError: 36702231.2500
# Epoch 9/2000
# 47/47 [==============================] - 7s 144ms/step - loss: 36745178.4167 - reconstruction_loss: 42671.3398 - kl_loss: 0.0224 - ArithmeticError: 36702231.2500
# Epoch 10/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36744552.2500 - reconstruction_loss: 42464.6641 - kl_loss: 0.0307 - ArithmeticError: 36702231.2500
# Epoch 11/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36744096.0000 - reconstruction_loss: 41846.0234 - kl_loss: 0.0459 - ArithmeticError: 36702231.2500
# Epoch 12/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36743901.0000 - reconstruction_loss: 41656.5820 - kl_loss: 0.0700 - ArithmeticError: 36702231.2500
# Epoch 13/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36743422.6667 - reconstruction_loss: 41216.6094 - kl_loss: 0.1117 - ArithmeticError: 36702231.2500
# Epoch 14/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36743271.0000 - reconstruction_loss: 41002.5938 - kl_loss: 0.1799 - ArithmeticError: 36702231.2500
# Epoch 15/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36743150.0000 - reconstruction_loss: 40857.7773 - kl_loss: 0.3016 - ArithmeticError: 36702231.2500
# Epoch 16/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36742225.4167 - reconstruction_loss: 39890.4219 - kl_loss: 0.5562 - ArithmeticError: 36702231.2500
# Epoch 17/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36741663.3333 - reconstruction_loss: 39176.3750 - kl_loss: 1.0808 - ArithmeticError: 36702231.2500
# Epoch 18/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36740998.9167 - reconstruction_loss: 38421.2422 - kl_loss: 2.4225 - ArithmeticError: 36702231.2500
# Epoch 19/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36739288.1667 - reconstruction_loss: 36572.6094 - kl_loss: 6.1809 - ArithmeticError: 36702231.2500
# Epoch 20/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36736502.1667 - reconstruction_loss: 33038.0977 - kl_loss: 21.9952 - ArithmeticError: 36702231.2500
# Epoch 21/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36730561.8333 - reconstruction_loss: 25610.1680 - kl_loss: 156.5720 - ArithmeticError: 36702231.2500
# Epoch 22/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36719307.1667 - reconstruction_loss: 14797.4600 - kl_loss: 1733.7058 - ArithmeticError: 36702231.2500
# Epoch 23/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36718076.3333 - reconstruction_loss: 14076.7061 - kl_loss: 1898.7968 - ArithmeticError: 36702231.2500
# Epoch 24/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36718055.5833 - reconstruction_loss: 13827.1689 - kl_loss: 1784.3998 - ArithmeticError: 36702231.2500
# Epoch 25/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36717902.5833 - reconstruction_loss: 13963.9326 - kl_loss: 1811.5142 - ArithmeticError: 36702231.2500
# Epoch 26/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36717532.5833 - reconstruction_loss: 13659.3643 - kl_loss: 1698.6660 - ArithmeticError: 36702231.2500
# Epoch 27/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36717580.7500 - reconstruction_loss: 13692.7285 - kl_loss: 1550.2592 - ArithmeticError: 36702231.2500
# Epoch 28/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36717634.0000 - reconstruction_loss: 13431.9775 - kl_loss: 1580.3735 - ArithmeticError: 36702231.2500
# Epoch 29/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36717310.5000 - reconstruction_loss: 13403.4014 - kl_loss: 1521.1737 - ArithmeticError: 36702231.2500
# Epoch 30/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716607.2500 - reconstruction_loss: 13004.0010 - kl_loss: 1372.1093 - ArithmeticError: 36702231.2500
# Epoch 31/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716654.3333 - reconstruction_loss: 13143.5244 - kl_loss: 1292.7271 - ArithmeticError: 36702231.2500
# Epoch 32/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716694.1667 - reconstruction_loss: 13147.7949 - kl_loss: 1338.8029 - ArithmeticError: 36702231.2500
# Epoch 33/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716505.1667 - reconstruction_loss: 13115.2510 - kl_loss: 1380.7087 - ArithmeticError: 36702231.2500
# Epoch 34/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716036.2500 - reconstruction_loss: 12897.0098 - kl_loss: 1213.6852 - ArithmeticError: 36702231.2500
# Epoch 35/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715983.0000 - reconstruction_loss: 12627.7725 - kl_loss: 1207.4418 - ArithmeticError: 36702231.2500
# Epoch 36/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716247.9167 - reconstruction_loss: 12888.0625 - kl_loss: 1228.6338 - ArithmeticError: 36702231.2500
# Epoch 37/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716001.1667 - reconstruction_loss: 12731.8975 - kl_loss: 1237.1957 - ArithmeticError: 36702231.2500
# Epoch 38/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36716074.7500 - reconstruction_loss: 12744.4238 - kl_loss: 1209.4167 - ArithmeticError: 36702231.2500
# Epoch 39/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715729.7500 - reconstruction_loss: 12437.2900 - kl_loss: 1160.0034 - ArithmeticError: 36702231.2500
# Epoch 40/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715695.0833 - reconstruction_loss: 12576.3965 - kl_loss: 1069.5952 - ArithmeticError: 36702231.2500
# Epoch 41/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715734.6667 - reconstruction_loss: 12551.2529 - kl_loss: 1112.4716 - ArithmeticError: 36702231.2500
# Epoch 42/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715546.5000 - reconstruction_loss: 12367.9053 - kl_loss: 1105.9052 - ArithmeticError: 36702231.2500
# Epoch 43/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715724.7500 - reconstruction_loss: 12295.5508 - kl_loss: 1094.6946 - ArithmeticError: 36702231.2500
# Epoch 44/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715658.0000 - reconstruction_loss: 12341.1465 - kl_loss: 1039.5605 - ArithmeticError: 36702231.2500
# Epoch 45/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715176.7500 - reconstruction_loss: 12031.8457 - kl_loss: 932.8865 - ArithmeticError: 36702231.2500
# Epoch 46/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715508.8333 - reconstruction_loss: 12147.9883 - kl_loss: 976.9767 - ArithmeticError: 36702231.2500
# Epoch 47/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715288.7500 - reconstruction_loss: 12149.8125 - kl_loss: 949.0131 - ArithmeticError: 36702231.2500
# Epoch 48/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715705.9167 - reconstruction_loss: 12208.4268 - kl_loss: 1063.8304 - ArithmeticError: 36702231.2500
# Epoch 49/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715373.4167 - reconstruction_loss: 12176.9707 - kl_loss: 991.7533 - ArithmeticError: 36702231.2500
# Epoch 50/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715210.6667 - reconstruction_loss: 12402.5195 - kl_loss: 987.3224 - ArithmeticError: 36702231.2500
# Epoch 51/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715306.3333 - reconstruction_loss: 12034.3350 - kl_loss: 996.8306 - ArithmeticError: 36702231.2500
# Epoch 52/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 36715051.1667 - reconstruction_loss: 12038.7158 - kl_loss: 925.9012 - ArithmeticError: 36702231.2500
# Epoch 53/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715389.8333 - reconstruction_loss: 11996.7832 - kl_loss: 1010.4510 - ArithmeticError: 36702231.2500
# Epoch 54/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715095.8333 - reconstruction_loss: 11914.4160 - kl_loss: 901.3843 - ArithmeticError: 36702231.2500
# Epoch 55/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36714927.9167 - reconstruction_loss: 11838.3408 - kl_loss: 888.2415 - ArithmeticError: 36702231.2500
# Epoch 56/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36715132.0833 - reconstruction_loss: 11925.2246 - kl_loss: 908.1659 - ArithmeticError: 36702231.2500
# Epoch 57/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714820.2500 - reconstruction_loss: 11877.8281 - kl_loss: 868.8927 - ArithmeticError: 36702231.2500
# Epoch 58/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714797.8333 - reconstruction_loss: 11684.3887 - kl_loss: 887.8710 - ArithmeticError: 36702231.2500
# Epoch 59/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714851.5000 - reconstruction_loss: 11809.9639 - kl_loss: 841.1703 - ArithmeticError: 36702231.2500
# Epoch 60/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36715036.5833 - reconstruction_loss: 12015.1631 - kl_loss: 924.1611 - ArithmeticError: 36702231.2500
# Epoch 61/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714800.1667 - reconstruction_loss: 11756.9990 - kl_loss: 905.4088 - ArithmeticError: 36702231.2500
# Epoch 62/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714765.0000 - reconstruction_loss: 11577.4414 - kl_loss: 864.3384 - ArithmeticError: 36702231.2500
# Epoch 63/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714620.0833 - reconstruction_loss: 11640.6592 - kl_loss: 769.9825 - ArithmeticError: 36702231.2500
# Epoch 64/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714581.0833 - reconstruction_loss: 11846.1406 - kl_loss: 783.5836 - ArithmeticError: 36702231.2500
# Epoch 65/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714598.8333 - reconstruction_loss: 11775.4258 - kl_loss: 812.4100 - ArithmeticError: 36702231.2500
# Epoch 66/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714723.0833 - reconstruction_loss: 11523.8906 - kl_loss: 869.6376 - ArithmeticError: 36702231.2500
# Epoch 67/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714404.5000 - reconstruction_loss: 11786.0693 - kl_loss: 711.9803 - ArithmeticError: 36702231.2500
# Epoch 68/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714551.7500 - reconstruction_loss: 11634.5918 - kl_loss: 763.8191 - ArithmeticError: 36702231.2500
# Epoch 69/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 36714497.5000 - reconstruction_loss: 11452.3682 - kl_loss: 792.8629 - ArithmeticError: 36702231.2500
# Epoch 70/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36714492.0000 - reconstruction_loss: 11614.8047 - kl_loss: 730.8865 - ArithmeticError: 36702231.2500
# Epoch 71/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714589.8333 - reconstruction_loss: 11570.9600 - kl_loss: 821.5067 - ArithmeticError: 36702231.2500
# Epoch 72/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714407.5000 - reconstruction_loss: 11384.2529 - kl_loss: 770.6692 - ArithmeticError: 36702231.2500
# Epoch 73/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714337.1667 - reconstruction_loss: 11410.8936 - kl_loss: 707.0193 - ArithmeticError: 36702231.2500
# Epoch 74/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714391.6667 - reconstruction_loss: 11377.5117 - kl_loss: 735.7776 - ArithmeticError: 36702231.2500
# Epoch 75/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714324.3333 - reconstruction_loss: 11496.5371 - kl_loss: 715.4133 - ArithmeticError: 36702231.2500
# Epoch 76/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714357.2500 - reconstruction_loss: 11365.3867 - kl_loss: 748.1008 - ArithmeticError: 36702231.2500
# Epoch 77/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714134.3333 - reconstruction_loss: 11351.1885 - kl_loss: 673.9180 - ArithmeticError: 36702231.2500
# Epoch 78/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714393.1667 - reconstruction_loss: 11339.1201 - kl_loss: 706.7255 - ArithmeticError: 36702231.2500
# Epoch 79/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36714113.8333 - reconstruction_loss: 11257.1982 - kl_loss: 644.5164 - ArithmeticError: 36702224.3333
# Epoch 80/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714237.8333 - reconstruction_loss: 11332.6260 - kl_loss: 666.8072 - ArithmeticError: 36702219.1667
# Epoch 81/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714221.4167 - reconstruction_loss: 11344.8271 - kl_loss: 671.8375 - ArithmeticError: 36702217.5833
# Epoch 82/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714082.3333 - reconstruction_loss: 11220.9814 - kl_loss: 662.8478 - ArithmeticError: 36702213.3333
# Epoch 83/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36713996.9167 - reconstruction_loss: 11219.3076 - kl_loss: 622.7413 - ArithmeticError: 36702203.1667
# Epoch 84/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36714014.7500 - reconstruction_loss: 11282.1387 - kl_loss: 664.8993 - ArithmeticError: 36701988.3333
# Epoch 85/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36713594.7500 - reconstruction_loss: 11259.7568 - kl_loss: 653.6640 - ArithmeticError: 36701658.0000
# Epoch 86/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36713183.6667 - reconstruction_loss: 11255.5674 - kl_loss: 602.7713 - ArithmeticError: 36701356.7500
# Epoch 87/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36712672.0833 - reconstruction_loss: 11248.8965 - kl_loss: 589.3276 - ArithmeticError: 36700853.7500
# Epoch 88/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36710357.6667 - reconstruction_loss: 11307.0625 - kl_loss: 485.2374 - ArithmeticError: 36698535.5000
# Epoch 89/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36707989.5833 - reconstruction_loss: 11787.4805 - kl_loss: 363.3871 - ArithmeticError: 36695976.8333
# Epoch 90/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36705452.1667 - reconstruction_loss: 11875.4033 - kl_loss: 296.1200 - ArithmeticError: 36693273.8333
# Epoch 91/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36702633.1667 - reconstruction_loss: 12586.2510 - kl_loss: 186.9738 - ArithmeticError: 36690109.5000
# Epoch 92/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36699376.2500 - reconstruction_loss: 13500.1914 - kl_loss: 130.9594 - ArithmeticError: 36685960.6667
# Epoch 93/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36695775.4167 - reconstruction_loss: 14306.7871 - kl_loss: 94.3614 - ArithmeticError: 36681413.5833
# Epoch 94/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36691383.4167 - reconstruction_loss: 15855.6279 - kl_loss: 60.0797 - ArithmeticError: 36676031.0000
# Epoch 95/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36686564.2500 - reconstruction_loss: 16753.6602 - kl_loss: 47.5884 - ArithmeticError: 36669774.1667
# Epoch 96/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36681190.1667 - reconstruction_loss: 18197.4688 - kl_loss: 37.7119 - ArithmeticError: 36662631.9167
# Epoch 97/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36675500.8333 - reconstruction_loss: 19706.5273 - kl_loss: 28.2367 - ArithmeticError: 36656527.2500
# Epoch 98/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36669203.1667 - reconstruction_loss: 20385.8535 - kl_loss: 26.1496 - ArithmeticError: 36649171.7500
# Epoch 99/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36662464.8333 - reconstruction_loss: 21713.4922 - kl_loss: 23.8579 - ArithmeticError: 36640977.4167
# Epoch 100/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36655637.6667 - reconstruction_loss: 22185.3281 - kl_loss: 20.9758 - ArithmeticError: 36633918.2500
# Epoch 101/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36648003.7500 - reconstruction_loss: 23792.4473 - kl_loss: 19.6429 - ArithmeticError: 36624155.5833
# Epoch 102/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36640307.7500 - reconstruction_loss: 23993.5586 - kl_loss: 18.8546 - ArithmeticError: 36616306.1667
# Epoch 103/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36632058.4167 - reconstruction_loss: 25876.0684 - kl_loss: 17.4537 - ArithmeticError: 36606335.0000
# Epoch 104/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36623506.0000 - reconstruction_loss: 25677.9199 - kl_loss: 18.2233 - ArithmeticError: 36597768.8333
# Epoch 105/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36614506.5000 - reconstruction_loss: 27095.8242 - kl_loss: 17.4392 - ArithmeticError: 36587777.2500
# Epoch 106/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36605097.0000 - reconstruction_loss: 27350.8164 - kl_loss: 18.9419 - ArithmeticError: 36577968.6667
# Epoch 107/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36595449.8333 - reconstruction_loss: 28174.9395 - kl_loss: 19.6806 - ArithmeticError: 36567139.0000
# Epoch 108/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36585321.5000 - reconstruction_loss: 28596.6113 - kl_loss: 21.3277 - ArithmeticError: 36556868.5833
# Epoch 109/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36574890.0000 - reconstruction_loss: 29179.1641 - kl_loss: 23.3163 - ArithmeticError: 36545898.1667
# Epoch 110/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36564131.1667 - reconstruction_loss: 29090.8691 - kl_loss: 25.1751 - ArithmeticError: 36534963.5833
# Epoch 111/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36553204.7500 - reconstruction_loss: 29521.0801 - kl_loss: 23.7648 - ArithmeticError: 36523598.9167
# Epoch 112/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36541890.5000 - reconstruction_loss: 30145.1523 - kl_loss: 21.9961 - ArithmeticError: 36511719.6667
# Epoch 113/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36530334.4167 - reconstruction_loss: 30543.3262 - kl_loss: 20.2356 - ArithmeticError: 36499922.0000
# Epoch 114/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36518343.1667 - reconstruction_loss: 31232.1973 - kl_loss: 18.9530 - ArithmeticError: 36487241.0000
# Epoch 115/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36506095.5833 - reconstruction_loss: 31460.7559 - kl_loss: 17.3560 - ArithmeticError: 36474568.0000
# Epoch 116/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36493526.5833 - reconstruction_loss: 32023.7656 - kl_loss: 14.9862 - ArithmeticError: 36461712.7500
# Epoch 117/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36480556.6667 - reconstruction_loss: 32406.0801 - kl_loss: 12.9170 - ArithmeticError: 36448258.3333
# Epoch 118/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36467082.1667 - reconstruction_loss: 33025.6875 - kl_loss: 11.0724 - ArithmeticError: 36434134.4167
# Epoch 119/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36453419.3333 - reconstruction_loss: 33493.1172 - kl_loss: 9.8839 - ArithmeticError: 36420002.5000
# Epoch 120/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36439324.9167 - reconstruction_loss: 34146.3477 - kl_loss: 8.6218 - ArithmeticError: 36405434.7500
# Epoch 121/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36424877.1667 - reconstruction_loss: 34244.2773 - kl_loss: 7.6752 - ArithmeticError: 36390513.7500
# Epoch 122/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36410112.0833 - reconstruction_loss: 34871.5742 - kl_loss: 6.4380 - ArithmeticError: 36375274.9167
# Epoch 123/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36395023.5833 - reconstruction_loss: 35350.8633 - kl_loss: 5.5306 - ArithmeticError: 36359746.6667
# Epoch 124/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36379487.5000 - reconstruction_loss: 35611.5195 - kl_loss: 4.4623 - ArithmeticError: 36343998.5833
# Epoch 125/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36363451.4167 - reconstruction_loss: 36187.7266 - kl_loss: 3.7019 - ArithmeticError: 36327513.3333
# Epoch 126/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36346853.2500 - reconstruction_loss: 36815.2891 - kl_loss: 3.5083 - ArithmeticError: 36309852.4167
# Epoch 127/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36330119.8333 - reconstruction_loss: 36992.5000 - kl_loss: 3.0353 - ArithmeticError: 36293125.5000
# Epoch 128/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36312836.0833 - reconstruction_loss: 37415.1367 - kl_loss: 2.7050 - ArithmeticError: 36275267.5833
# Epoch 129/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36295239.2500 - reconstruction_loss: 37728.7422 - kl_loss: 2.2883 - ArithmeticError: 36257628.9167
# Epoch 130/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36277357.5000 - reconstruction_loss: 38001.7891 - kl_loss: 1.9404 - ArithmeticError: 36239351.8333
# Epoch 131/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36258812.2500 - reconstruction_loss: 38295.7969 - kl_loss: 1.6827 - ArithmeticError: 36220648.0833
# Epoch 132/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36239661.7500 - reconstruction_loss: 38934.3555 - kl_loss: 1.5743 - ArithmeticError: 36200668.1667
# Epoch 133/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36220247.5000 - reconstruction_loss: 39158.2969 - kl_loss: 1.4901 - ArithmeticError: 36180935.9167
# Epoch 134/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36200540.9167 - reconstruction_loss: 39570.0469 - kl_loss: 1.3753 - ArithmeticError: 36161008.6667
# Epoch 135/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36180708.6667 - reconstruction_loss: 39478.4453 - kl_loss: 1.3289 - ArithmeticError: 36141558.6667
# Epoch 136/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36159960.9167 - reconstruction_loss: 39849.2305 - kl_loss: 1.2278 - ArithmeticError: 36120223.0000
# Epoch 137/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36138650.2500 - reconstruction_loss: 40006.0156 - kl_loss: 1.2636 - ArithmeticError: 36098402.5000
# Epoch 138/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 36117183.5000 - reconstruction_loss: 40334.3047 - kl_loss: 1.1176 - ArithmeticError: 36076937.0000
# Epoch 139/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36095038.8333 - reconstruction_loss: 40825.8984 - kl_loss: 1.1160 - ArithmeticError: 36054072.4167
# Epoch 140/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36072794.5000 - reconstruction_loss: 41168.0039 - kl_loss: 1.1515 - ArithmeticError: 36031718.0000
# Epoch 141/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36049839.3333 - reconstruction_loss: 41463.8633 - kl_loss: 1.2531 - ArithmeticError: 36008272.1667
# Epoch 142/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36026541.1667 - reconstruction_loss: 42034.7969 - kl_loss: 1.2971 - ArithmeticError: 35984531.1667
# Epoch 143/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 36003034.2500 - reconstruction_loss: 41924.5859 - kl_loss: 1.3618 - ArithmeticError: 35961205.8333
# Epoch 144/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35978908.0000 - reconstruction_loss: 42264.2812 - kl_loss: 1.4023 - ArithmeticError: 35936801.1667
# Epoch 145/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35954253.6667 - reconstruction_loss: 42773.5781 - kl_loss: 1.5514 - ArithmeticError: 35911541.5833
# Epoch 146/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35929159.0000 - reconstruction_loss: 43031.8281 - kl_loss: 1.7024 - ArithmeticError: 35886022.2500
# Epoch 147/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35903649.5833 - reconstruction_loss: 43276.1211 - kl_loss: 1.8623 - ArithmeticError: 35860581.0000
# Epoch 148/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35877479.1667 - reconstruction_loss: 43487.5781 - kl_loss: 1.9704 - ArithmeticError: 35834110.4167
# Epoch 149/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35850723.8333 - reconstruction_loss: 43911.9805 - kl_loss: 2.0719 - ArithmeticError: 35806878.2500
# Epoch 150/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35823740.5000 - reconstruction_loss: 44168.1211 - kl_loss: 2.0802 - ArithmeticError: 35779709.0000
# Epoch 151/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35796149.3333 - reconstruction_loss: 44351.2891 - kl_loss: 2.2077 - ArithmeticError: 35751727.1667
# Epoch 152/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35768192.6667 - reconstruction_loss: 44673.5430 - kl_loss: 2.4795 - ArithmeticError: 35723444.4167
# Epoch 153/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35739639.6667 - reconstruction_loss: 45268.9805 - kl_loss: 2.8684 - ArithmeticError: 35694310.6667
# Epoch 154/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35710744.3333 - reconstruction_loss: 45540.5625 - kl_loss: 3.2114 - ArithmeticError: 35665170.1667
# Epoch 155/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35681441.6667 - reconstruction_loss: 45838.2930 - kl_loss: 3.6007 - ArithmeticError: 35635694.3333
# Epoch 156/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35651517.8333 - reconstruction_loss: 46232.4961 - kl_loss: 3.9972 - ArithmeticError: 35605193.7500
# Epoch 157/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35621228.5000 - reconstruction_loss: 46518.5625 - kl_loss: 4.5877 - ArithmeticError: 35574802.8333
# Epoch 158/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35590509.2500 - reconstruction_loss: 46840.5898 - kl_loss: 5.1797 - ArithmeticError: 35543891.2500
# Epoch 159/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35559083.7500 - reconstruction_loss: 47241.2773 - kl_loss: 5.5491 - ArithmeticError: 35512001.0000
# Epoch 160/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35527243.5000 - reconstruction_loss: 47592.4258 - kl_loss: 6.2745 - ArithmeticError: 35479658.9167
# Epoch 161/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35494948.8333 - reconstruction_loss: 48005.3281 - kl_loss: 7.3328 - ArithmeticError: 35446932.2500
# Epoch 162/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35461999.5000 - reconstruction_loss: 48539.7969 - kl_loss: 8.3001 - ArithmeticError: 35413214.8333
# Epoch 163/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35428993.5833 - reconstruction_loss: 48609.2031 - kl_loss: 8.9745 - ArithmeticError: 35380490.0833
# Epoch 164/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35395133.0833 - reconstruction_loss: 48886.5430 - kl_loss: 9.8246 - ArithmeticError: 35346140.7500
# Epoch 165/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35360726.6667 - reconstruction_loss: 49531.1914 - kl_loss: 10.5134 - ArithmeticError: 35311139.6667
# Epoch 166/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35326078.8333 - reconstruction_loss: 49752.6289 - kl_loss: 11.1998 - ArithmeticError: 35276404.9167
# Epoch 167/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35290799.0000 - reconstruction_loss: 49991.1719 - kl_loss: 11.8363 - ArithmeticError: 35240874.9167
# Epoch 168/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35255228.8333 - reconstruction_loss: 50299.0859 - kl_loss: 13.2528 - ArithmeticError: 35205409.2500
# Epoch 169/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35218731.2500 - reconstruction_loss: 50788.6914 - kl_loss: 14.1818 - ArithmeticError: 35167944.6667
# Epoch 170/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35181919.8333 - reconstruction_loss: 51175.2031 - kl_loss: 14.6805 - ArithmeticError: 35130819.0000
# Epoch 171/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35144641.2500 - reconstruction_loss: 51391.2656 - kl_loss: 15.0302 - ArithmeticError: 35093298.3333
# Epoch 172/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 35106925.6667 - reconstruction_loss: 51571.5312 - kl_loss: 15.6711 - ArithmeticError: 35055365.6667
# Epoch 173/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35068632.7500 - reconstruction_loss: 51764.1719 - kl_loss: 16.5459 - ArithmeticError: 35016965.0000
# Epoch 174/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 35029595.8333 - reconstruction_loss: 52271.7031 - kl_loss: 17.3003 - ArithmeticError: 34977165.2500
# Epoch 175/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 34990345.8333 - reconstruction_loss: 52486.3125 - kl_loss: 18.2311 - ArithmeticError: 34937877.9167
# Epoch 176/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34950452.0000 - reconstruction_loss: 52796.3711 - kl_loss: 19.3451 - ArithmeticError: 34897798.6667
# Epoch 177/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34909873.5833 - reconstruction_loss: 53152.5781 - kl_loss: 20.3790 - ArithmeticError: 34856581.8333
# Epoch 178/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34869021.5833 - reconstruction_loss: 53116.2500 - kl_loss: 21.5367 - ArithmeticError: 34815913.5833
# Epoch 179/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34827202.1667 - reconstruction_loss: 53191.9609 - kl_loss: 23.1541 - ArithmeticError: 34774047.5000
# Epoch 180/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 34784067.5833 - reconstruction_loss: 53806.8633 - kl_loss: 24.8947 - ArithmeticError: 34730261.0000
# Epoch 181/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34740755.0833 - reconstruction_loss: 53955.6523 - kl_loss: 26.8008 - ArithmeticError: 34686769.6667
# Epoch 182/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 34696988.6667 - reconstruction_loss: 54028.3789 - kl_loss: 28.5029 - ArithmeticError: 34642912.8333
# Epoch 183/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34652737.7500 - reconstruction_loss: 54430.7695 - kl_loss: 29.8081 - ArithmeticError: 34598309.2500
# Epoch 184/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 34607950.0833 - reconstruction_loss: 54575.6445 - kl_loss: 30.7283 - ArithmeticError: 34553265.5833
# Epoch 185/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34562296.7500 - reconstruction_loss: 54932.0391 - kl_loss: 32.0268 - ArithmeticError: 34507400.0833
# Epoch 186/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34516066.0000 - reconstruction_loss: 54998.4375 - kl_loss: 33.2617 - ArithmeticError: 34461067.5000
# Epoch 187/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34468942.9167 - reconstruction_loss: 55302.7109 - kl_loss: 34.4836 - ArithmeticError: 34413657.3333
# Epoch 188/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34421324.1667 - reconstruction_loss: 55338.9453 - kl_loss: 36.7768 - ArithmeticError: 34365931.5833
# Epoch 189/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 34373146.2500 - reconstruction_loss: 55451.5703 - kl_loss: 39.5313 - ArithmeticError: 34317398.5000
# Epoch 190/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34324562.6667 - reconstruction_loss: 55600.6289 - kl_loss: 41.7672 - ArithmeticError: 34268991.6667
# Epoch 191/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 34275420.3333 - reconstruction_loss: 55635.5156 - kl_loss: 43.8032 - ArithmeticError: 34219523.2500
# Epoch 192/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34225691.1667 - reconstruction_loss: 56107.9531 - kl_loss: 45.8399 - ArithmeticError: 34169516.6667
# Epoch 193/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34175426.5833 - reconstruction_loss: 56312.9805 - kl_loss: 47.8727 - ArithmeticError: 34119041.1667
# Epoch 194/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 34124603.7500 - reconstruction_loss: 56253.1523 - kl_loss: 51.0072 - ArithmeticError: 34068285.2500
# Epoch 195/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34073257.2500 - reconstruction_loss: 56233.3477 - kl_loss: 53.9034 - ArithmeticError: 34016930.3333
# Epoch 196/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 34021359.7500 - reconstruction_loss: 56412.4297 - kl_loss: 56.6776 - ArithmeticError: 33964976.2500
# Epoch 197/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33968834.2500 - reconstruction_loss: 56503.7109 - kl_loss: 59.4675 - ArithmeticError: 33912205.9167
# Epoch 198/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33915768.6667 - reconstruction_loss: 56645.5547 - kl_loss: 62.1492 - ArithmeticError: 33859076.9167
# Epoch 199/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 33862150.5000 - reconstruction_loss: 56672.6602 - kl_loss: 64.8218 - ArithmeticError: 33805319.0833
# Epoch 200/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33807992.1667 - reconstruction_loss: 56962.8984 - kl_loss: 67.2147 - ArithmeticError: 33751036.5000
# Epoch 201/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33753258.0000 - reconstruction_loss: 57035.1602 - kl_loss: 68.9408 - ArithmeticError: 33696118.0000
# Epoch 202/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33697991.3333 - reconstruction_loss: 57102.9023 - kl_loss: 70.6290 - ArithmeticError: 33640801.0833
# Epoch 203/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33642089.9167 - reconstruction_loss: 57173.9961 - kl_loss: 73.2770 - ArithmeticError: 33584842.2500
# Epoch 204/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33585581.3333 - reconstruction_loss: 57212.4688 - kl_loss: 75.5558 - ArithmeticError: 33528065.5417
# Epoch 205/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 33528714.0833 - reconstruction_loss: 57228.9258 - kl_loss: 76.9947 - ArithmeticError: 33471544.9167
# Epoch 206/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 33471005.2500 - reconstruction_loss: 57546.6797 - kl_loss: 78.0743 - ArithmeticError: 33413227.4167
# Epoch 207/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33412564.2917 - reconstruction_loss: 57526.2539 - kl_loss: 79.7451 - ArithmeticError: 33354867.4167
# Epoch 208/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 33351933.6667 - reconstruction_loss: 57740.4961 - kl_loss: 81.0049 - ArithmeticError: 33294155.7500
# Epoch 209/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 33290738.1250 - reconstruction_loss: 57688.5625 - kl_loss: 82.5163 - ArithmeticError: 33232843.2500
# Epoch 210/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 33229311.9583 - reconstruction_loss: 57927.8125 - kl_loss: 83.3172 - ArithmeticError: 33171275.2500
# Epoch 211/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 33167432.6667 - reconstruction_loss: 58101.9141 - kl_loss: 84.1092 - ArithmeticError: 33109117.7917
# Epoch 212/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 33105169.2083 - reconstruction_loss: 58158.7695 - kl_loss: 84.6320 - ArithmeticError: 33046895.5417
# Epoch 213/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 33042239.5000 - reconstruction_loss: 58350.1445 - kl_loss: 85.0617 - ArithmeticError: 32983640.2500
# Epoch 214/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32978892.8750 - reconstruction_loss: 58507.5273 - kl_loss: 85.8404 - ArithmeticError: 32920279.0417
# Epoch 215/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32914970.9167 - reconstruction_loss: 58545.3047 - kl_loss: 86.6698 - ArithmeticError: 32856319.2917
# Epoch 216/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32850427.0833 - reconstruction_loss: 58863.9883 - kl_loss: 87.3097 - ArithmeticError: 32791452.6667
# Epoch 217/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32784465.7917 - reconstruction_loss: 58833.7695 - kl_loss: 88.2566 - ArithmeticError: 32725474.6667
# Epoch 218/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 32717120.5833 - reconstruction_loss: 59043.8633 - kl_loss: 89.1882 - ArithmeticError: 32657859.3333
# Epoch 219/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 32649834.9583 - reconstruction_loss: 59045.5625 - kl_loss: 89.9283 - ArithmeticError: 32590676.0417
# Epoch 220/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32581979.2917 - reconstruction_loss: 59238.5898 - kl_loss: 90.1933 - ArithmeticError: 32522503.0417
# Epoch 221/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32513640.4583 - reconstruction_loss: 59576.4844 - kl_loss: 90.0073 - ArithmeticError: 32454015.8750
# Epoch 222/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32444251.7083 - reconstruction_loss: 59479.5898 - kl_loss: 90.6574 - ArithmeticError: 32384652.8750
# Epoch 223/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 32374206.6667 - reconstruction_loss: 59755.6914 - kl_loss: 91.5169 - ArithmeticError: 32314262.2500
# Epoch 224/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32303905.0833 - reconstruction_loss: 59944.7188 - kl_loss: 91.2490 - ArithmeticError: 32243846.8333
# Epoch 225/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 32233072.5833 - reconstruction_loss: 59703.2891 - kl_loss: 92.8496 - ArithmeticError: 32173125.2083
# Epoch 226/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32161741.1667 - reconstruction_loss: 60000.4258 - kl_loss: 93.1249 - ArithmeticError: 32101703.0000
# Epoch 227/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 32089783.5833 - reconstruction_loss: 60131.8516 - kl_loss: 93.4361 - ArithmeticError: 32029467.4167
# Epoch 228/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 32017340.9583 - reconstruction_loss: 60218.3359 - kl_loss: 93.8059 - ArithmeticError: 31956963.2917
# Epoch 229/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31944377.2083 - reconstruction_loss: 60381.0586 - kl_loss: 94.4610 - ArithmeticError: 31883862.5000
# Epoch 230/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 31870854.4583 - reconstruction_loss: 60711.8555 - kl_loss: 94.7558 - ArithmeticError: 31810162.2917
# Epoch 231/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31796735.3333 - reconstruction_loss: 60784.6016 - kl_loss: 95.4045 - ArithmeticError: 31735870.2500
# Epoch 232/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31722140.2917 - reconstruction_loss: 60809.0000 - kl_loss: 95.9443 - ArithmeticError: 31661235.1667
# Epoch 233/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31646891.9583 - reconstruction_loss: 61045.1602 - kl_loss: 96.8658 - ArithmeticError: 31585733.1667
# Epoch 234/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31571176.2083 - reconstruction_loss: 61117.9453 - kl_loss: 97.4442 - ArithmeticError: 31509926.0417
# Epoch 235/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31495123.7500 - reconstruction_loss: 61187.6211 - kl_loss: 97.7697 - ArithmeticError: 31433980.0000
# Epoch 236/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31418179.2500 - reconstruction_loss: 61328.6445 - kl_loss: 98.6405 - ArithmeticError: 31356725.7917
# Epoch 237/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31340781.0417 - reconstruction_loss: 61456.1523 - kl_loss: 99.6356 - ArithmeticError: 31279170.0417
# Epoch 238/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 31262960.9583 - reconstruction_loss: 61573.2031 - kl_loss: 99.6346 - ArithmeticError: 31201327.3333
# Epoch 239/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31184642.0833 - reconstruction_loss: 61611.8633 - kl_loss: 100.1424 - ArithmeticError: 31122932.0000
# Epoch 240/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31105557.3750 - reconstruction_loss: 61740.8516 - kl_loss: 101.6054 - ArithmeticError: 31043612.6667
# Epoch 241/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 31025981.7500 - reconstruction_loss: 62157.4219 - kl_loss: 101.3949 - ArithmeticError: 30963641.9167
# Epoch 242/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 30945997.6667 - reconstruction_loss: 62396.0312 - kl_loss: 100.6981 - ArithmeticError: 30883443.8333
# Epoch 243/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 30865515.9583 - reconstruction_loss: 62312.8125 - kl_loss: 101.6104 - ArithmeticError: 30803083.4583
# Epoch 244/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30784469.9583 - reconstruction_loss: 62375.4531 - kl_loss: 102.1855 - ArithmeticError: 30721947.3750
# Epoch 245/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 30702898.5000 - reconstruction_loss: 62583.9297 - kl_loss: 102.3908 - ArithmeticError: 30640131.9583
# Epoch 246/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30620866.8750 - reconstruction_loss: 62766.3086 - kl_loss: 102.8375 - ArithmeticError: 30558054.3750
# Epoch 247/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30538172.3750 - reconstruction_loss: 62820.7070 - kl_loss: 103.5716 - ArithmeticError: 30475211.0417
# Epoch 248/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30455087.9583 - reconstruction_loss: 62815.4258 - kl_loss: 103.7199 - ArithmeticError: 30392107.7917
# Epoch 249/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30371467.9583 - reconstruction_loss: 63018.9805 - kl_loss: 103.1946 - ArithmeticError: 30308329.7500
# Epoch 250/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 30287367.1250 - reconstruction_loss: 63142.4375 - kl_loss: 103.5943 - ArithmeticError: 30224035.3750
# Epoch 251/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30202425.9583 - reconstruction_loss: 63222.8672 - kl_loss: 104.3018 - ArithmeticError: 30139124.2917
# Epoch 252/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30115302.7917 - reconstruction_loss: 63384.2656 - kl_loss: 104.7241 - ArithmeticError: 30051868.6250
# Epoch 253/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 30028135.9167 - reconstruction_loss: 63343.4531 - kl_loss: 105.2129 - ArithmeticError: 29964494.0417
# Epoch 254/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 29940944.4583 - reconstruction_loss: 63420.9531 - kl_loss: 105.7769 - ArithmeticError: 29877536.9167
# Epoch 255/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 29853228.0000 - reconstruction_loss: 63609.7695 - kl_loss: 105.9148 - ArithmeticError: 29789485.3333
# Epoch 256/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 29765137.0417 - reconstruction_loss: 63745.7227 - kl_loss: 106.7883 - ArithmeticError: 29701232.1250
# Epoch 257/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 29676596.1667 - reconstruction_loss: 63860.1055 - kl_loss: 107.2323 - ArithmeticError: 29612532.0417
# Epoch 258/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 29587693.0417 - reconstruction_loss: 64101.4023 - kl_loss: 107.0391 - ArithmeticError: 29523372.7500
# Epoch 259/2000
# ...
# Epoch 1913/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10105659.7292 - reconstruction_loss: 11400.7578 - kl_loss: 451.3610 - ArithmeticError: 10093808.6042
# Epoch 1914/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10105467.2708 - reconstruction_loss: 11391.6504 - kl_loss: 454.6888 - ArithmeticError: 10093611.0000
# Epoch 1915/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10105816.2500 - reconstruction_loss: 11414.2979 - kl_loss: 448.8905 - ArithmeticError: 10093943.6250
# Epoch 1916/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10105410.1667 - reconstruction_loss: 11408.9482 - kl_loss: 446.0178 - ArithmeticError: 10093565.8750
# Epoch 1917/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10105771.0208 - reconstruction_loss: 11463.0254 - kl_loss: 428.6628 - ArithmeticError: 10093907.0833
# Epoch 1918/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10103390.3542 - reconstruction_loss: 11422.3496 - kl_loss: 441.9049 - ArithmeticError: 10091545.6667
# Epoch 1919/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10103826.7917 - reconstruction_loss: 11422.5146 - kl_loss: 439.0995 - ArithmeticError: 10091990.6250
# Epoch 1920/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10102000.7917 - reconstruction_loss: 11414.9424 - kl_loss: 431.4708 - ArithmeticError: 10090190.4167
# Epoch 1921/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10100842.8125 - reconstruction_loss: 11426.5879 - kl_loss: 428.5664 - ArithmeticError: 10089016.1875
# Epoch 1922/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10100036.0000 - reconstruction_loss: 11427.5410 - kl_loss: 432.4213 - ArithmeticError: 10088205.2500
# Epoch 1923/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10099541.4375 - reconstruction_loss: 11434.9551 - kl_loss: 431.3074 - ArithmeticError: 10087700.4792
# Epoch 1924/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10099336.6250 - reconstruction_loss: 11430.2939 - kl_loss: 435.2663 - ArithmeticError: 10087488.3750
# Epoch 1925/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10099176.0625 - reconstruction_loss: 11426.1074 - kl_loss: 437.2519 - ArithmeticError: 10087326.3958
# Epoch 1926/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10099137.5417 - reconstruction_loss: 11421.4453 - kl_loss: 441.3390 - ArithmeticError: 10087282.3750
# Epoch 1927/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098961.2500 - reconstruction_loss: 11418.3672 - kl_loss: 445.2704 - ArithmeticError: 10087104.4792
# Epoch 1928/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098748.8125 - reconstruction_loss: 11414.7344 - kl_loss: 448.9363 - ArithmeticError: 10086889.5833
# Epoch 1929/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098348.8542 - reconstruction_loss: 11417.4961 - kl_loss: 448.3553 - ArithmeticError: 10086479.7500
# Epoch 1930/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098388.0000 - reconstruction_loss: 11411.3389 - kl_loss: 450.8931 - ArithmeticError: 10086529.8542
# Epoch 1931/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098169.5833 - reconstruction_loss: 11422.9717 - kl_loss: 450.6126 - ArithmeticError: 10086308.1458
# Epoch 1932/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098078.2292 - reconstruction_loss: 11417.2832 - kl_loss: 454.4877 - ArithmeticError: 10086211.8333
# Epoch 1933/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098183.6458 - reconstruction_loss: 11403.4600 - kl_loss: 458.2533 - ArithmeticError: 10086324.2917
# Epoch 1934/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10098066.0417 - reconstruction_loss: 11423.1650 - kl_loss: 446.7524 - ArithmeticError: 10086213.7917
# Epoch 1935/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10097739.7917 - reconstruction_loss: 11407.5293 - kl_loss: 454.6448 - ArithmeticError: 10085887.6875
# Epoch 1936/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10097548.1250 - reconstruction_loss: 11409.4521 - kl_loss: 447.9608 - ArithmeticError: 10085707.3333
# Epoch 1937/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10097805.8333 - reconstruction_loss: 11418.3574 - kl_loss: 440.5282 - ArithmeticError: 10085970.1250
# Epoch 1938/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10097741.9375 - reconstruction_loss: 11411.2656 - kl_loss: 437.6551 - ArithmeticError: 10085924.6458
# Epoch 1939/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10096821.2917 - reconstruction_loss: 11410.8896 - kl_loss: 441.8075 - ArithmeticError: 10084977.6458
# Epoch 1940/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10096514.5417 - reconstruction_loss: 11407.2061 - kl_loss: 444.8338 - ArithmeticError: 10084676.4167
# Epoch 1941/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10096209.3958 - reconstruction_loss: 11402.4902 - kl_loss: 446.1934 - ArithmeticError: 10084372.5208
# Epoch 1942/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10096289.8958 - reconstruction_loss: 11414.4590 - kl_loss: 440.6475 - ArithmeticError: 10084457.4167
# Epoch 1943/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095877.0833 - reconstruction_loss: 11411.6494 - kl_loss: 442.3599 - ArithmeticError: 10084039.8125
# Epoch 1944/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10096152.5625 - reconstruction_loss: 11407.7949 - kl_loss: 437.6681 - ArithmeticError: 10084316.7917
# Epoch 1945/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095977.3958 - reconstruction_loss: 11401.5947 - kl_loss: 439.1601 - ArithmeticError: 10084141.5625
# Epoch 1946/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095868.6875 - reconstruction_loss: 11412.7031 - kl_loss: 437.8526 - ArithmeticError: 10084022.6042
# Epoch 1947/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095607.7917 - reconstruction_loss: 11397.6514 - kl_loss: 440.1698 - ArithmeticError: 10083774.5000
# Epoch 1948/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095683.4583 - reconstruction_loss: 11399.6621 - kl_loss: 442.2834 - ArithmeticError: 10083843.8542
# Epoch 1949/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095561.9792 - reconstruction_loss: 11391.4189 - kl_loss: 449.0653 - ArithmeticError: 10083725.9583
# Epoch 1950/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095873.4792 - reconstruction_loss: 11375.0547 - kl_loss: 450.7834 - ArithmeticError: 10084065.2917
# Epoch 1951/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095114.4583 - reconstruction_loss: 11393.4014 - kl_loss: 445.7807 - ArithmeticError: 10083278.9375
# Epoch 1952/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095018.0000 - reconstruction_loss: 11398.7979 - kl_loss: 448.7455 - ArithmeticError: 10083177.1042
# Epoch 1953/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10094761.1250 - reconstruction_loss: 11391.0361 - kl_loss: 452.3994 - ArithmeticError: 10082914.8750
# Epoch 1954/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10095153.4167 - reconstruction_loss: 11399.5928 - kl_loss: 451.2689 - ArithmeticError: 10083298.8125
# Epoch 1955/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10095616.1667 - reconstruction_loss: 11381.5410 - kl_loss: 446.2464 - ArithmeticError: 10083803.2708
# Epoch 1956/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10095473.5417 - reconstruction_loss: 11385.1885 - kl_loss: 438.3486 - ArithmeticError: 10083667.7917
# Epoch 1957/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10094638.3125 - reconstruction_loss: 11381.1797 - kl_loss: 447.3011 - ArithmeticError: 10082814.6875
# Epoch 1958/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10095634.2917 - reconstruction_loss: 11383.5557 - kl_loss: 446.0756 - ArithmeticError: 10083807.8750
# Epoch 1959/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10094842.3125 - reconstruction_loss: 11372.9229 - kl_loss: 441.9959 - ArithmeticError: 10083028.7500
# Epoch 1960/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10094438.7708 - reconstruction_loss: 11375.3457 - kl_loss: 444.6236 - ArithmeticError: 10082626.0417
# Epoch 1961/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095583.0208 - reconstruction_loss: 11385.7910 - kl_loss: 439.9572 - ArithmeticError: 10083780.6458
# Epoch 1962/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10095124.2292 - reconstruction_loss: 11368.9277 - kl_loss: 441.1309 - ArithmeticError: 10083352.5625
# Epoch 1963/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10093986.2917 - reconstruction_loss: 11374.4492 - kl_loss: 436.6422 - ArithmeticError: 10082207.1042
# Epoch 1964/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10093064.7917 - reconstruction_loss: 11394.1543 - kl_loss: 434.7792 - ArithmeticError: 10081262.0000
# Epoch 1965/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10093741.2500 - reconstruction_loss: 11376.9053 - kl_loss: 438.7607 - ArithmeticError: 10081953.4167
# Epoch 1966/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10093610.0833 - reconstruction_loss: 11380.8906 - kl_loss: 432.2577 - ArithmeticError: 10081827.9167
# Epoch 1967/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10092483.6667 - reconstruction_loss: 11371.2012 - kl_loss: 440.0431 - ArithmeticError: 10080682.6458
# Epoch 1968/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10091571.5625 - reconstruction_loss: 11385.9053 - kl_loss: 440.4796 - ArithmeticError: 10079761.2500
# Epoch 1969/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10091467.2083 - reconstruction_loss: 11361.5186 - kl_loss: 447.5175 - ArithmeticError: 10079683.8958
# Epoch 1970/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10091010.5208 - reconstruction_loss: 11371.7930 - kl_loss: 443.4355 - ArithmeticError: 10079210.6250
# Epoch 1971/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10090717.6875 - reconstruction_loss: 11369.0674 - kl_loss: 445.9998 - ArithmeticError: 10078918.0833
# Epoch 1972/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10090230.6042 - reconstruction_loss: 11382.6172 - kl_loss: 446.0221 - ArithmeticError: 10078416.9583
# Epoch 1973/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10089931.2708 - reconstruction_loss: 11371.6143 - kl_loss: 449.1320 - ArithmeticError: 10078121.4792
# Epoch 1974/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10089704.2917 - reconstruction_loss: 11375.8525 - kl_loss: 451.8368 - ArithmeticError: 10077891.8542
# Epoch 1975/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10089455.6042 - reconstruction_loss: 11373.3906 - kl_loss: 452.8331 - ArithmeticError: 10077642.9792
# Epoch 1976/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10089139.6667 - reconstruction_loss: 11381.6289 - kl_loss: 449.2330 - ArithmeticError: 10077326.3750
# Epoch 1977/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10088994.0625 - reconstruction_loss: 11370.8828 - kl_loss: 451.4145 - ArithmeticError: 10077188.1250
# Epoch 1978/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10088715.5625 - reconstruction_loss: 11370.9033 - kl_loss: 452.1233 - ArithmeticError: 10076906.4792
# Epoch 1979/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10089007.7083 - reconstruction_loss: 11374.4746 - kl_loss: 445.4273 - ArithmeticError: 10077206.7083
# Epoch 1980/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10088499.2292 - reconstruction_loss: 11367.5674 - kl_loss: 450.4314 - ArithmeticError: 10076700.3750
# Epoch 1981/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10089180.7083 - reconstruction_loss: 11369.9785 - kl_loss: 453.0672 - ArithmeticError: 10077376.3750
# Epoch 1982/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10088812.0208 - reconstruction_loss: 11365.0107 - kl_loss: 454.1036 - ArithmeticError: 10077005.4583
# Epoch 1983/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10088934.6875 - reconstruction_loss: 11362.2646 - kl_loss: 453.4367 - ArithmeticError: 10077134.0000
# Epoch 1984/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10087655.9375 - reconstruction_loss: 11347.6475 - kl_loss: 456.3606 - ArithmeticError: 10075859.1458
# Epoch 1985/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10087278.4583 - reconstruction_loss: 11364.0801 - kl_loss: 449.9083 - ArithmeticError: 10075480.7708
# Epoch 1986/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10087101.9375 - reconstruction_loss: 11361.9922 - kl_loss: 450.9850 - ArithmeticError: 10075304.8125
# Epoch 1987/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10086689.1875 - reconstruction_loss: 11354.6006 - kl_loss: 458.2750 - ArithmeticError: 10074889.2708
# Epoch 1988/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10086809.9792 - reconstruction_loss: 11366.1289 - kl_loss: 453.6735 - ArithmeticError: 10075009.2083
# Epoch 1989/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10086611.6458 - reconstruction_loss: 11356.2803 - kl_loss: 454.9946 - ArithmeticError: 10074821.1458
# Epoch 1990/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10086773.8333 - reconstruction_loss: 11351.7021 - kl_loss: 460.5839 - ArithmeticError: 10074976.9583
# Epoch 1991/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10087814.2917 - reconstruction_loss: 11335.1836 - kl_loss: 457.4955 - ArithmeticError: 10076027.5833
# Epoch 1992/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10086904.1042 - reconstruction_loss: 11340.3076 - kl_loss: 445.7023 - ArithmeticError: 10075126.4792
# Epoch 1993/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10085891.1042 - reconstruction_loss: 11353.9258 - kl_loss: 443.6259 - ArithmeticError: 10074105.7292
# Epoch 1994/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10085611.1042 - reconstruction_loss: 11349.8828 - kl_loss: 445.1571 - ArithmeticError: 10073828.5000
# Epoch 1995/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10085621.2083 - reconstruction_loss: 11349.8027 - kl_loss: 447.3858 - ArithmeticError: 10073840.7500
# Epoch 1996/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10085102.3542 - reconstruction_loss: 11342.3682 - kl_loss: 449.3427 - ArithmeticError: 10073329.7500
# Epoch 1997/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10084742.6250 - reconstruction_loss: 11342.9229 - kl_loss: 450.6819 - ArithmeticError: 10072966.9375
# Epoch 1998/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10084379.5208 - reconstruction_loss: 11350.4658 - kl_loss: 453.8303 - ArithmeticError: 10072593.5833
# Epoch 1999/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10084134.3125 - reconstruction_loss: 11354.8936 - kl_loss: 452.0255 - ArithmeticError: 10072346.4167
# Epoch 2000/2000
# 47/47 [==============================] - 7s 149ms/step - loss: 10084135.6875 - reconstruction_loss: 11345.3008 - kl_loss: 452.2149 - ArithmeticError: 10072354.2708

# %%
### Guardar modelohttps://www.tensorflow.org/guide/saved_model?hl=es-419
vae.encoder.save('Models/weakly2_GVAE_encoder_DRY_1_32.h5')
vae.decoder.save('Models/weakly2_GVAE_decoder_DRY_1_32.h5')
vae.regressor.save('Models/weakly2_GVAE_regressor_DRY_1_32.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
