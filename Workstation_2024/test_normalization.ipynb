# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['TF_ENABLE_ONEDNN_OPTS'] =  "0"



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

## Librerías
import seaborn as sns
import sys
import cv2 as cv2
import glob
from PIL import Image
import tensorflow as tf
import sys
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import gc
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
import os


from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler

print(tf.__version__)
# Out:
# 2024-01-26 02:14:36.598704: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 02:14:36.598735: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 02:14:36.602199: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-26 02:14:36.908446: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.14.0

# %%
## Uso de GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# 2024-01-26 02:14:40.648409: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:40.781613: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:40.781765: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # Datos

# %%
## Function to get contours and features
def get_contours_and_features(binary_map):
    # get binary map
    binary_map = cv2.cvtColor(binary_map, cv2.COLOR_BGR2GRAY)
    # get contours from binary map
    contours, hierarchy = cv2.findContours(binary_map, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    # get features from contours
    contours_features = []
    for contour in contours:
        error = 1e-5

        moments = cv2.moments(contour)
        cx = moments['m10'] / (moments['m00'] + error)
        cy = moments['m01'] / (moments['m00'] + error)
        center_of_mass = [cx, cy]
        features = {
            'area': cv2.contourArea(contour),
            'perimeter': cv2.arcLength(contour, True),
            'moments': moments,
            'center_of_mass': center_of_mass,
            'contour': contour
        }
        contours_features.append(features)
        del features    
    return contours_features

# function to get a determined property from a list of contours features (area by default)
def get_item(contour_features, key='area'):
    areas = []
    for contour_feature in contour_features:
        area =  contour_feature[key]
        areas.append(area)
    return areas

# function to get tensor of one image
def load_image(file_name):
  raw = tf.io.read_file(file_name)
  tensor = tf.io.decode_jpeg(raw,channels=1)
  tensor = tf.image.resize(tensor, [128,128])
  tensor = tf.cast(tensor, tf.float32) / 255.0
  return tensor

# function to get set of binary image from image loaded
def get_binary_image(filenames):
    tensores = []
    for filename in filenames:
        raw = tf.io.read_file(filename)
        tensor = tf.io.decode_jpeg(raw,channels=3)
        tensor = tf.image.resize(tensor, [128,128])
        tensor = tf.cast(tensor, tf.float32) / 255.0
        tensores.append(tensor)
    return tensores

def get_geometric_atributes(binary_images):
    atributes = []
    for binary_img in binary_images:
        ## Formato
        image = binary_img.numpy().astype(np.uint8)       
        
        ## Capturar contornos
        contour_features = get_contours_and_features(image)        

        ## obtener área de poros##
        area = np.ceil(np.sum(get_item(contour_features, key='area')))

        ## obtener perímetro de poros
        perimetro = np.ceil(np.sum(get_item(contour_features, key='perimeter'))
)
        ## intersticio
        area_total = np.ceil(np.shape(image)[0] * np.shape(image)[1])
        intersticio = np.ceil(area_total - area)

        ## Cantidad de poros
        poros = np.shape(contour_features)[0]

        #atributes = [area,perimetro,intersticio,poros]
        atributes.append([area,perimetro,intersticio,poros])
    
    return atributes

# function to associate geometric atributes with images

def normalize_geometric_properties(dataset):

    ## Listas para guardar propiedades
    areas = []
    perimetros = []
    intersticios = []
    poros = []

    for i in range(len(dataset)):    
        
        ## obtener ruta de la imagen
        mask_route = dataset['route_mask'].to_numpy()[i]
        ## obtener imagen binaria
        mask = get_binary_image([mask_route])
        ## capturar propiedades
        atrs = get_geometric_atributes(mask)[0]

        ## agregar a listas las propiedades
        areas.append(atrs[0])
        perimetros.append(atrs[1])
        intersticios.append(atrs[2])
        poros.append(atrs[3])

    ## normalizar datos
        
    # normalizar area
    min_area = np.min(areas)
    max_area = np.max(areas)
    areas_norm = (areas - min_area) / (max_area - min_area)

    # normailizar perimetro
    min_perimetro = np.min(perimetros)
    max_perimetro = np.max(perimetros)
    perimetros_norm = (perimetros - min_perimetro) / (max_perimetro - min_perimetro)

    #normalizar intersticio
    min_intersticio = np.min(intersticios)
    max_intersticio = np.max(intersticios)
    intersticios_norm = (intersticios - min_intersticio) / (max_intersticio - min_intersticio)

    #normalizar poros
    min_poros = np.min(poros)
    max_poros = np.max(poros)
    poros_norm = (poros - min_poros) / (max_poros - min_poros)


    dataset['area'] = areas_norm
    dataset['perimetro'] = perimetros_norm
    dataset['intersticio'] = intersticios_norm
    dataset['poros'] = poros_norm


    return dataset, [min_area, min_perimetro, min_intersticio, min_poros], [max_area, max_perimetro, max_intersticio, max_poros]


## desnormalizar datos
def de_normalize_value(value, min_value, max_value):
    return (value * (max_value - min_value)) + min_value

## Reorganizar atributos geométricos
def organize_geometric_atributes(dataset):
    attributes = []
    for i in range(len(dataset)):
        attributes.append([dataset['area'].to_numpy()[i],dataset['perimetro'].to_numpy()[i],dataset['intersticio'].to_numpy()[i],dataset['poros'].to_numpy()[i]])

    return attributes

def split_dataset(routes_dataset):
    ## Establecer el porcentaje de separación
    thold1 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='0'])))
    thold2 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='1'])))
    thold3 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='2'])))

    ## Separar por clases para entrenamiento
    train_cu1 = routes_dataset[routes_dataset.label == '0'][0:thold1]
    train_cu2 = routes_dataset[routes_dataset.label == '1'][0:thold2]
    train_cu3 = routes_dataset[routes_dataset.label == '2'][0:thold3]

    ## tomar las demás imágenes para test
    test_cu1 = routes_dataset[routes_dataset.label == '0'][thold1:]
    test_cu2 = routes_dataset[routes_dataset.label == '1'][thold2:]
    test_cu3 = routes_dataset[routes_dataset.label == '2'][thold3:]


    ## Constuir un solo dataset de training
    train_df =  pd.concat([pd.concat([train_cu1,train_cu2]),train_cu3]).sample(frac=1,random_state=42).reset_index(drop=True)

    ## Construir un solo dataset de test
    test_df = pd.concat([pd.concat([test_cu1,test_cu2]),test_cu3]).sample(frac=1,random_state=100).reset_index(drop=True)

    ## Cantidad de muestras por clase
    print('Clase MF1: train: ',len(train_cu1),', test: ',len(test_cu1))
    print('Clase MF2: train: ',len(train_cu2),', test: ',len(test_cu2))
    print('Clase MF3: train: ',len(train_cu3),', test: ',len(test_cu3))

    return train_df, test_df


def create_dataset(buffer,dataset): 
  ## Get file names
  file_names = dataset['route_image'].to_numpy()
  ## Get labels
  labels = dataset['label'].to_numpy()
  ## Get geometric atributes from binary images
  attributes = organize_geometric_atributes(dataset)
  ## Create dataset from tensors assosiated with labels and attributes
  dataset = tf.data.Dataset.from_tensor_slices((file_names,labels,attributes))
  ## Shuffle dataset
  dataset.shuffle(buffer_size=buffer)
  ## Map dataset to load images (a = image, b = label, c = attributes, d = mask)
  dataset = dataset.map(lambda file_name, label, attributes : (load_image(file_name), label, attributes))

  return dataset

# %%
## Obtener todas las rutas de las imágenes en el dataset
ruta = '../Datasets/Micrografías_segmentadas/secas/*/*/*/*.jpg'
rutas_dataset  = glob.glob('../../../Datasets/Micrografías segmentaciones/secas/*/*/*/*.jpg')

## Separar rutas
mask_list = []
image_list = []
for ruta in rutas_dataset:    
    ruta_list = ruta.split('/')       
    clase = ruta_list[6]
    number = ruta_list[7]
    tipo = ruta_list[8]
    name = ruta_list[9].split('.')[0]
    
    if tipo == 'train':
        image_list.append([name,ruta,clase,number])
    elif tipo == 'mask_bin':
        mask_list.append([name,ruta,clase,number])
    else:
        None

mask_pd = pd.DataFrame(mask_list,columns=['name','route_mask','label','number']).sort_values(by='name')
image_pd = pd.DataFrame(image_list,columns=['name','route_image','label','number']).sort_values(by='name')

routes_dataset = image_pd.merge(mask_pd,on=['name','label','number'],how='left')

routes_dataset.dropna(inplace=True)

routes_dataset = routes_dataset.sample(frac = 1)

print('Imágenes secas:', np.shape(routes_dataset)[0])
print('MF1:', np.shape(routes_dataset[routes_dataset['label']=='MF1'])[0])
print('MF2:', np.shape(routes_dataset[routes_dataset['label']=='MF2'])[0])
print('MF3:', np.shape(routes_dataset[routes_dataset['label']=='MF3'])[0])

char_to_num = {'MF1':'0','MF2':'1','MF3':'2'}

routes_dataset['label'].replace(char_to_num,inplace=True)

dataset, mins, maxs = normalize_geometric_properties(routes_dataset)

train_df, test_df = split_dataset(dataset)

dataset = create_dataset(16,train_df)
# Out:
# Imágenes secas: 923
# MF1: 378
# MF2: 284
# MF3: 261
# 2024-01-26 02:14:41.711115: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:41.711280: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:41.711450: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:41.970712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:41.970846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:41.970958: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 02:14:41.971048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7786 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:08:00.0, compute capability: 8.6
# Clase MF1: train:  303 , test:  75
# Clase MF2: train:  228 , test:  56
# Clase MF3: train:  209 , test:  52

# %%
cnt = 0
for i in dataset.batch(16):
    a = i[0]
    b = i[1]
    c = i[2]
    #d = i[3]

n =  0
print(c[n].numpy())
print(b[n].numpy())
plt.imshow(a[n],cmap='gray')
#plt.imshow(d[n],cmap='gray')
plt.show()
# Out:
# [0.55264021 0.22932145 0.44735979 0.08      ]
# b'0'

# %% [markdown]
# ## Modelo

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class VAE(keras.Model):
    def __init__(self, encoder, decoder, regressor, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.regressor = regressor
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")        
        self.estimation_loss_tracker = keras.metrics.Mean(name="estimation_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.estimation_loss_tracker,            
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            ## Valores estimados por el encoder
            z_mean, z_log_var, z = self.encoder(data[0])
            
            ## Valores geométricos asociados a los datos
            geometrics_features = data[2]

            ## Reconstrucción del embebido del encoder
            reconstruction = self.decoder(z)            

            ## Reducción de la reconstrucción
            reconstruction /= tf.reduce_max(reconstruction)

            ## Valores estimados apartir del regresor
            estimation = self.regressor(reconstruction)
            
            ## Error de reconstrucción
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data[0], reconstruction), axis=(1, 2)
                )
            )

            '''
            reconstruction_loss =tf.reduce_mean(
                tf.reduce_sum( tf.keras.losses.MeanSquaredError()(data, reconstruction)
                             )
            )
            '''
            
            ## Error de estimación de valores geométricos
            estimation_loss = tf.reduce_mean(tf.keras.losses.MeanSquaredError()(geometrics_features, estimation))
            
            
            ## Error de divergencia KL
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))   

            ## Error total          
            total_loss = reconstruction_loss + kl_loss + estimation_loss
        
        ## Actualización de los gradientes
        grads = tape.gradient(total_loss, self.trainable_weights)

        ## Actualización de lA RECONSTRUCCIÓN
        self.reconstruction = reconstruction

        ### Actualización de los pesos
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)   
        self.estimation_loss_tracker.update_state(estimation_loss)    
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(), 
            "ArithmeticError": self.estimation_loss_tracker.result(),        
        }

# %%
###_____________________________ENCODER________________________##
latent_dim = 32

nx, ny = 128, 128

encoder_inputs = keras.Input(shape=(nx, ny,1))

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E1')(encoder_inputs)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E2')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same',name='layer_E3')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same',name='layer_E4')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_E6')(x)
x = layers.Flatten()(x)



z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(inputs=encoder_inputs, outputs=[z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  layer_E1 (Conv2D)           (None, 128, 128, 1024)       10240     ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 1024)         0         ['layer_E1[0][0]']
#  D)
#
#  batch_normalization (Batch  (None, 64, 64, 1024)         4096      ['max_pooling2d[0][0]']
#  Normalization)
#
#  layer_E2 (Conv2D)           (None, 64, 64, 1024)         9438208   ['batch_normalization[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 1024)         0         ['layer_E2[0][0]']
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 32, 32, 1024)         4096      ['max_pooling2d_1[0][0]']
#  chNormalization)
#
#  layer_E3 (Conv2D)           (None, 32, 32, 512)          4719104   ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 512)          0         ['layer_E3[0][0]']
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 512)          2048      ['max_pooling2d_2[0][0]']
#  chNormalization)
#
#  layer_E4 (Conv2D)           (None, 16, 16, 256)          1179904   ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 256)            0         ['layer_E4[0][0]']
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 8, 8, 256)            1024      ['max_pooling2d_3[0][0]']
#  chNormalization)
#
#  layer_E6 (Conv2D)           (None, 8, 8, 128)            295040    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  flatten (Flatten)           (None, 8192)                 0         ['layer_E6[0][0]']
#
#  z_mean (Dense)              (None, 32)                   262176    ['flatten[0][0]']
#
#  z_log_var (Dense)           (None, 32)                   262176    ['flatten[0][0]']
#
#  sampling (Sampling)         (None, 32)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 16178112 (61.71 MB)
# Trainable params: 16172480 (61.69 MB)
# Non-trainable params: 5632 (22.00 KB)
# __________________________________________________________________________________________________

# %%
## Entrada Z
latent_inputs = keras.Input(shape=(latent_dim,))

##dimensiones
ndim = 16
nfilts = 128

## anti-flatten de la última capa convolucional
x = layers.Dense(ndim * ndim * nfilts, activation="relu")(latent_inputs)

## Reshape para reconstruir la última convolucional
x = layers.Reshape((ndim,ndim, nfilts))(x)

## Capas convolucionales
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D1')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D2')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_D4')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same',name='layer_D6')(x)

decoder_outputs = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='layer_D7')(x)

## Construcción del decoder
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 32768)             1081344
#
#  reshape (Reshape)           (None, 16, 16, 128)       0
#
#  layer_D1 (Conv2D)           (None, 16, 16, 128)       147584
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 128)       0
#  D)
#
#  batch_normalization_4 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  layer_D2 (Conv2D)           (None, 32, 32, 128)       147584
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 128)       0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 64, 64, 128)       512
#  chNormalization)
#
#  layer_D4 (Conv2D)           (None, 64, 64, 64)        73792
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 64)      0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  layer_D6 (Conv2D)           (None, 128, 128, 16)      9232
#
#  layer_D7 (Conv2D)           (None, 128, 128, 1)       145
#
# =================================================================
# Total params: 1460961 (5.57 MB)
# Trainable params: 1460321 (5.57 MB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
### Estimador de valores geométricos

## Input layer
regressor_inputs = keras.Input(shape=(128,128,1))

## Hidden layers
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same',name='layer_R1')(regressor_inputs)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R2')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_R3')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R4')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_R5')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R6')(x)
x = layers.BatchNormalization()(x)

## Output layer
flatten = layers.Flatten()(x)
regressor_outputs = layers.Dense(4, activation="relu")(flatten)

## regressor model
regressor = keras.Model(regressor_inputs, regressor_outputs, name="regressor")
regressor.summary()
# Out:
# Model: "regressor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  layer_R1 (Conv2D)           (None, 128, 128, 32)      320
#
#  layer_R2 (MaxPooling2D)     (None, 64, 64, 32)        0
#
#  batch_normalization_7 (Bat  (None, 64, 64, 32)        128
#  chNormalization)
#
#  layer_R3 (Conv2D)           (None, 64, 64, 64)        18496
#
#  layer_R4 (MaxPooling2D)     (None, 32, 32, 64)        0
#
#  batch_normalization_8 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  layer_R5 (Conv2D)           (None, 32, 32, 128)       73856
#
#  layer_R6 (MaxPooling2D)     (None, 16, 16, 128)       0
#
#  batch_normalization_9 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 4)                 131076
#
# =================================================================
# Total params: 224644 (877.52 KB)
# Trainable params: 224196 (875.77 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
vae = VAE(encoder, decoder,regressor)
opt = tf.optimizers.Adam(learning_rate = 0.000001)
#nll = lambda x , rv_x: -rv_x.log_prob(x)
vae.compile(optimizer=opt)


vae.fit(dataset.batch(16), epochs=2000, 
                batch_size=16,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=100)])
# Out:
# Epoch 1/2000
# 2024-01-26 02:15:01.119798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2024-01-26 02:15:04.352254: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe500015b10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-26 02:15:04.352287: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-01-26 02:15:04.369760: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-26 02:15:04.490642: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-01-26 02:15:08.990637: W tensorflow/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2024-01-26 02:15:10.775751: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-26 02:15:10.775793: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 47/47 [==============================] - 26s 199ms/step - loss: 46341.7234 - reconstruction_loss: 45999.3281 - kl_loss: 0.0035 - ArithmeticError: 0.1986
# Epoch 2/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 45254.2309 - reconstruction_loss: 45193.9727 - kl_loss: 0.0040 - ArithmeticError: 0.1704
# Epoch 3/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 44891.1952 - reconstruction_loss: 44901.2305 - kl_loss: 0.0048 - ArithmeticError: 0.1472
# Epoch 4/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 44631.2452 - reconstruction_loss: 44534.3516 - kl_loss: 0.0059 - ArithmeticError: 0.1286
# Epoch 5/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 44324.6108 - reconstruction_loss: 44309.1328 - kl_loss: 0.0074 - ArithmeticError: 0.1142
# Epoch 6/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 43498.6835 - reconstruction_loss: 43582.9531 - kl_loss: 0.0096 - ArithmeticError: 0.1036
# Epoch 7/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 43460.0904 - reconstruction_loss: 43528.1641 - kl_loss: 0.0129 - ArithmeticError: 0.0963
# Epoch 8/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 42969.3534 - reconstruction_loss: 43112.1367 - kl_loss: 0.0179 - ArithmeticError: 0.0916
# Epoch 9/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 42739.1883 - reconstruction_loss: 42865.6055 - kl_loss: 0.0245 - ArithmeticError: 0.0889
# Epoch 10/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 42603.8498 - reconstruction_loss: 42494.0156 - kl_loss: 0.0341 - ArithmeticError: 0.0873
# Epoch 11/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 42325.6403 - reconstruction_loss: 42543.8164 - kl_loss: 0.0472 - ArithmeticError: 0.0865
# Epoch 12/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 42246.8759 - reconstruction_loss: 42073.9258 - kl_loss: 0.0665 - ArithmeticError: 0.0861
# Epoch 13/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 41681.7907 - reconstruction_loss: 41710.2773 - kl_loss: 0.0936 - ArithmeticError: 0.0860
# Epoch 14/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 40759.6213 - reconstruction_loss: 40639.9219 - kl_loss: 0.1409 - ArithmeticError: 0.0859
# Epoch 15/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 40940.9542 - reconstruction_loss: 40595.7031 - kl_loss: 0.2200 - ArithmeticError: 0.0858
# Epoch 16/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 40078.5580 - reconstruction_loss: 39954.2148 - kl_loss: 0.3831 - ArithmeticError: 0.0858
# Epoch 17/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 39631.0858 - reconstruction_loss: 39309.2695 - kl_loss: 0.6963 - ArithmeticError: 0.0858
# Epoch 18/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 38570.6542 - reconstruction_loss: 38589.6523 - kl_loss: 1.4002 - ArithmeticError: 0.0858
# Epoch 19/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 37485.9019 - reconstruction_loss: 37163.3242 - kl_loss: 2.9811 - ArithmeticError: 0.0858
# Epoch 20/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 36078.2359 - reconstruction_loss: 35744.7852 - kl_loss: 7.4655 - ArithmeticError: 0.0858
# Epoch 21/2000
# 47/47 [==============================] - 7s 145ms/step - loss: 33042.8487 - reconstruction_loss: 31870.8594 - kl_loss: 25.3381 - ArithmeticError: 0.0858
# Epoch 22/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 27003.2474 - reconstruction_loss: 24572.6328 - kl_loss: 169.0029 - ArithmeticError: 0.0861
# Epoch 23/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 17240.1835 - reconstruction_loss: 15461.0010 - kl_loss: 1669.2170 - ArithmeticError: 0.0907
# Epoch 24/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 16311.8691 - reconstruction_loss: 14664.5078 - kl_loss: 1722.6627 - ArithmeticError: 0.0899
# Epoch 25/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 15980.3542 - reconstruction_loss: 14344.5547 - kl_loss: 1697.9684 - ArithmeticError: 0.0889
# Epoch 26/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 15751.6230 - reconstruction_loss: 14236.6680 - kl_loss: 1684.4596 - ArithmeticError: 0.0877
# Epoch 27/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 15647.8270 - reconstruction_loss: 14137.9277 - kl_loss: 1577.1262 - ArithmeticError: 0.0874
# Epoch 28/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 15391.2697 - reconstruction_loss: 14222.0527 - kl_loss: 1544.9692 - ArithmeticError: 0.0875
# Epoch 29/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 15244.8488 - reconstruction_loss: 13712.3457 - kl_loss: 1555.5166 - ArithmeticError: 0.0873
# Epoch 30/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 15313.2191 - reconstruction_loss: 13740.1885 - kl_loss: 1489.4021 - ArithmeticError: 0.0870
# Epoch 31/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14927.3208 - reconstruction_loss: 13680.2061 - kl_loss: 1390.6141 - ArithmeticError: 0.0871
# Epoch 32/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14907.7569 - reconstruction_loss: 13401.5146 - kl_loss: 1350.0143 - ArithmeticError: 0.0872
# Epoch 33/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14422.9056 - reconstruction_loss: 13437.3828 - kl_loss: 1266.3606 - ArithmeticError: 0.0870
# Epoch 34/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14478.8743 - reconstruction_loss: 13209.6504 - kl_loss: 1274.8567 - ArithmeticError: 0.0871
# Epoch 35/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14620.2083 - reconstruction_loss: 13408.4326 - kl_loss: 1187.3215 - ArithmeticError: 0.0868
# Epoch 36/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14286.7431 - reconstruction_loss: 13138.9199 - kl_loss: 1219.6981 - ArithmeticError: 0.0868
# Epoch 37/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13941.7101 - reconstruction_loss: 12930.4658 - kl_loss: 1114.6697 - ArithmeticError: 0.0868
# Epoch 38/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14520.5813 - reconstruction_loss: 13388.6973 - kl_loss: 1172.7511 - ArithmeticError: 0.0866
# Epoch 39/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14446.8739 - reconstruction_loss: 13227.7314 - kl_loss: 1232.8593 - ArithmeticError: 0.0869
# Epoch 40/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 14074.8707 - reconstruction_loss: 12915.6475 - kl_loss: 1165.7419 - ArithmeticError: 0.0867
# Epoch 41/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13857.0463 - reconstruction_loss: 13201.7646 - kl_loss: 1045.2688 - ArithmeticError: 0.0867
# Epoch 42/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13665.3475 - reconstruction_loss: 12685.2715 - kl_loss: 1059.7507 - ArithmeticError: 0.0866
# Epoch 43/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13804.7158 - reconstruction_loss: 12706.6943 - kl_loss: 978.5602 - ArithmeticError: 0.0868
# Epoch 44/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13468.6323 - reconstruction_loss: 12597.7021 - kl_loss: 934.6913 - ArithmeticError: 0.0866
# Epoch 45/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13706.5386 - reconstruction_loss: 12597.9600 - kl_loss: 960.0828 - ArithmeticError: 0.0865
# Epoch 46/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13967.8947 - reconstruction_loss: 12765.8555 - kl_loss: 1031.8501 - ArithmeticError: 0.0866
# Epoch 47/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13774.1698 - reconstruction_loss: 12720.9150 - kl_loss: 970.0513 - ArithmeticError: 0.0868
# Epoch 48/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13971.4448 - reconstruction_loss: 12792.4121 - kl_loss: 1040.2253 - ArithmeticError: 0.0869
# Epoch 49/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 13462.8124 - reconstruction_loss: 12569.7168 - kl_loss: 1002.3391 - ArithmeticError: 0.0865
# Epoch 50/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13658.0470 - reconstruction_loss: 12578.3164 - kl_loss: 1007.6439 - ArithmeticError: 0.0869
# Epoch 51/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13268.4651 - reconstruction_loss: 12427.1025 - kl_loss: 902.7158 - ArithmeticError: 0.0865
# Epoch 52/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13234.0353 - reconstruction_loss: 12414.0508 - kl_loss: 903.8008 - ArithmeticError: 0.0864
# Epoch 53/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 13454.2340 - reconstruction_loss: 12427.2031 - kl_loss: 921.5189 - ArithmeticError: 0.0865
# Epoch 54/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 13604.3398 - reconstruction_loss: 12400.1582 - kl_loss: 962.1294 - ArithmeticError: 0.0866
# Epoch 55/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 13261.2352 - reconstruction_loss: 12384.3203 - kl_loss: 908.3934 - ArithmeticError: 0.0863
# Epoch 56/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13259.4802 - reconstruction_loss: 12253.6533 - kl_loss: 910.4655 - ArithmeticError: 0.0863
# Epoch 57/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 13208.3156 - reconstruction_loss: 12272.7598 - kl_loss: 870.6408 - ArithmeticError: 0.0866
# Epoch 58/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12994.0348 - reconstruction_loss: 12233.9219 - kl_loss: 857.0117 - ArithmeticError: 0.0863
# Epoch 59/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12957.9592 - reconstruction_loss: 12129.8779 - kl_loss: 845.3745 - ArithmeticError: 0.0864
# Epoch 60/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12827.0504 - reconstruction_loss: 12029.1025 - kl_loss: 762.0644 - ArithmeticError: 0.0863
# Epoch 61/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12896.5300 - reconstruction_loss: 12065.3447 - kl_loss: 790.7705 - ArithmeticError: 0.0862
# Epoch 62/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12753.6336 - reconstruction_loss: 12068.3506 - kl_loss: 770.5901 - ArithmeticError: 0.0861
# Epoch 63/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12942.3009 - reconstruction_loss: 12083.4385 - kl_loss: 828.1602 - ArithmeticError: 0.0862
# Epoch 64/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12840.1098 - reconstruction_loss: 12039.3311 - kl_loss: 834.4555 - ArithmeticError: 0.0862
# Epoch 65/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12890.3694 - reconstruction_loss: 12119.5596 - kl_loss: 808.8877 - ArithmeticError: 0.0863
# Epoch 66/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12716.9689 - reconstruction_loss: 12040.9121 - kl_loss: 817.0572 - ArithmeticError: 0.0862
# Epoch 67/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12737.5817 - reconstruction_loss: 11955.7061 - kl_loss: 802.7387 - ArithmeticError: 0.0861
# Epoch 68/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12772.5925 - reconstruction_loss: 11967.8242 - kl_loss: 772.3800 - ArithmeticError: 0.0863
# Epoch 69/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12512.9951 - reconstruction_loss: 11771.6143 - kl_loss: 742.0825 - ArithmeticError: 0.0861
# Epoch 70/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 13040.6903 - reconstruction_loss: 11947.3926 - kl_loss: 772.9897 - ArithmeticError: 0.0870
# Epoch 71/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12477.3799 - reconstruction_loss: 11885.1885 - kl_loss: 724.9811 - ArithmeticError: 0.0861
# Epoch 72/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12629.3769 - reconstruction_loss: 11892.2725 - kl_loss: 766.0290 - ArithmeticError: 0.0861
# Epoch 73/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12631.2131 - reconstruction_loss: 11819.0176 - kl_loss: 802.2125 - ArithmeticError: 0.0860
# Epoch 74/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12468.5582 - reconstruction_loss: 11777.8701 - kl_loss: 701.0178 - ArithmeticError: 0.0860
# Epoch 75/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12515.6760 - reconstruction_loss: 11790.5029 - kl_loss: 706.9733 - ArithmeticError: 0.0862
# Epoch 76/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12458.7541 - reconstruction_loss: 11805.4824 - kl_loss: 726.8331 - ArithmeticError: 0.0862
# Epoch 77/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12457.9903 - reconstruction_loss: 11723.6660 - kl_loss: 750.6200 - ArithmeticError: 0.0859
# Epoch 78/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12360.0412 - reconstruction_loss: 11673.8525 - kl_loss: 705.8918 - ArithmeticError: 0.0860
# Epoch 79/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12574.8168 - reconstruction_loss: 11902.7803 - kl_loss: 725.5486 - ArithmeticError: 0.0868
# Epoch 80/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12242.2470 - reconstruction_loss: 11622.8408 - kl_loss: 699.1780 - ArithmeticError: 0.0863
# Epoch 81/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12253.5874 - reconstruction_loss: 11611.9561 - kl_loss: 680.0019 - ArithmeticError: 0.0861
# Epoch 82/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12158.9936 - reconstruction_loss: 11721.7490 - kl_loss: 640.7526 - ArithmeticError: 0.0861
# Epoch 83/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12255.8948 - reconstruction_loss: 11629.0195 - kl_loss: 716.8433 - ArithmeticError: 0.0863
# Epoch 84/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12413.8788 - reconstruction_loss: 11641.8574 - kl_loss: 732.2456 - ArithmeticError: 0.0864
# Epoch 85/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 12500.9515 - reconstruction_loss: 11617.6865 - kl_loss: 705.6599 - ArithmeticError: 0.0868
# Epoch 86/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12112.7310 - reconstruction_loss: 11534.1582 - kl_loss: 650.5077 - ArithmeticError: 0.0861
# Epoch 87/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12342.7249 - reconstruction_loss: 11550.8232 - kl_loss: 655.5641 - ArithmeticError: 0.0869
# Epoch 88/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12025.9925 - reconstruction_loss: 11478.9668 - kl_loss: 570.9377 - ArithmeticError: 0.0861
# Epoch 89/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12109.3348 - reconstruction_loss: 11481.1104 - kl_loss: 615.3918 - ArithmeticError: 0.0861
# Epoch 90/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12045.5993 - reconstruction_loss: 11473.9385 - kl_loss: 618.4982 - ArithmeticError: 0.0860
# Epoch 91/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12219.5040 - reconstruction_loss: 11506.7061 - kl_loss: 662.1326 - ArithmeticError: 0.0865
# Epoch 92/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12020.3529 - reconstruction_loss: 11343.6904 - kl_loss: 604.2695 - ArithmeticError: 0.0860
# Epoch 93/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12001.9949 - reconstruction_loss: 11479.4736 - kl_loss: 556.0926 - ArithmeticError: 0.0862
# Epoch 94/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11950.1913 - reconstruction_loss: 11280.6914 - kl_loss: 608.6635 - ArithmeticError: 0.0861
# Epoch 95/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11923.1057 - reconstruction_loss: 11439.1113 - kl_loss: 549.3860 - ArithmeticError: 0.0863
# Epoch 96/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11984.0517 - reconstruction_loss: 11344.6133 - kl_loss: 612.6106 - ArithmeticError: 0.0862
# Epoch 97/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11926.0917 - reconstruction_loss: 11639.3389 - kl_loss: 568.5320 - ArithmeticError: 0.0862
# Epoch 98/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11830.7640 - reconstruction_loss: 11281.4629 - kl_loss: 582.7368 - ArithmeticError: 0.0862
# Epoch 99/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11752.0438 - reconstruction_loss: 11234.5488 - kl_loss: 538.5723 - ArithmeticError: 0.0861
# Epoch 100/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11815.6210 - reconstruction_loss: 11257.8828 - kl_loss: 553.5272 - ArithmeticError: 0.0862
# Epoch 101/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11751.9062 - reconstruction_loss: 11256.6621 - kl_loss: 536.1064 - ArithmeticError: 0.0862
# Epoch 102/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 12009.9769 - reconstruction_loss: 11241.4600 - kl_loss: 566.7734 - ArithmeticError: 0.0871
# Epoch 103/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 11708.2578 - reconstruction_loss: 11189.8936 - kl_loss: 490.1019 - ArithmeticError: 0.0863
# Epoch 104/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11681.9156 - reconstruction_loss: 11270.3643 - kl_loss: 502.2227 - ArithmeticError: 0.0862
# Epoch 105/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 11730.4315 - reconstruction_loss: 11137.4531 - kl_loss: 590.5223 - ArithmeticError: 0.0863
# Epoch 106/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11813.6722 - reconstruction_loss: 11239.6494 - kl_loss: 528.3838 - ArithmeticError: 0.0868
# Epoch 107/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11660.9484 - reconstruction_loss: 11146.5752 - kl_loss: 509.1313 - ArithmeticError: 0.0864
# Epoch 108/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11627.7167 - reconstruction_loss: 11169.8555 - kl_loss: 497.5094 - ArithmeticError: 0.0862
# Epoch 109/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 11580.0599 - reconstruction_loss: 11131.7217 - kl_loss: 493.6560 - ArithmeticError: 0.0864
# Epoch 110/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11536.1334 - reconstruction_loss: 11050.8623 - kl_loss: 481.2506 - ArithmeticError: 0.0863
# Epoch 111/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11514.2436 - reconstruction_loss: 11049.9521 - kl_loss: 470.0485 - ArithmeticError: 0.0863
# Epoch 112/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11537.5555 - reconstruction_loss: 11080.7695 - kl_loss: 445.0370 - ArithmeticError: 0.0866
# Epoch 113/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11608.0585 - reconstruction_loss: 11090.8623 - kl_loss: 439.6525 - ArithmeticError: 0.0867
# Epoch 114/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11487.6991 - reconstruction_loss: 11032.4756 - kl_loss: 460.7202 - ArithmeticError: 0.0863
# Epoch 115/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 11478.0315 - reconstruction_loss: 11021.0664 - kl_loss: 445.5977 - ArithmeticError: 0.0864
# Epoch 116/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11465.8053 - reconstruction_loss: 11041.8701 - kl_loss: 441.6515 - ArithmeticError: 0.0866
# Epoch 117/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 11519.5649 - reconstruction_loss: 10987.3486 - kl_loss: 466.3122 - ArithmeticError: 0.0866
# Epoch 118/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11431.5890 - reconstruction_loss: 11019.4268 - kl_loss: 422.6610 - ArithmeticError: 0.0866
# Epoch 119/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11378.6462 - reconstruction_loss: 10921.8945 - kl_loss: 441.1946 - ArithmeticError: 0.0865
# Epoch 120/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11347.6769 - reconstruction_loss: 10980.0439 - kl_loss: 393.4809 - ArithmeticError: 0.0865
# Epoch 121/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11337.7727 - reconstruction_loss: 10926.9072 - kl_loss: 404.4158 - ArithmeticError: 0.0867
# Epoch 122/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11309.6673 - reconstruction_loss: 10941.7051 - kl_loss: 398.4176 - ArithmeticError: 0.0867
# Epoch 123/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11302.8965 - reconstruction_loss: 10928.2500 - kl_loss: 411.3553 - ArithmeticError: 0.0867
# Epoch 124/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11325.8661 - reconstruction_loss: 10904.5625 - kl_loss: 419.6819 - ArithmeticError: 0.0870
# Epoch 125/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11242.8813 - reconstruction_loss: 10975.3701 - kl_loss: 379.0502 - ArithmeticError: 0.0868
# Epoch 126/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11243.6471 - reconstruction_loss: 10966.8711 - kl_loss: 396.7267 - ArithmeticError: 0.0869
# Epoch 127/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11218.7802 - reconstruction_loss: 10831.1895 - kl_loss: 406.8289 - ArithmeticError: 0.0869
# Epoch 128/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11202.3283 - reconstruction_loss: 10811.2715 - kl_loss: 352.7373 - ArithmeticError: 0.0870
# Epoch 129/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11233.8183 - reconstruction_loss: 10854.1924 - kl_loss: 341.6381 - ArithmeticError: 0.0869
# Epoch 130/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11149.5452 - reconstruction_loss: 10820.1709 - kl_loss: 350.7773 - ArithmeticError: 0.0868
# Epoch 131/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11151.8182 - reconstruction_loss: 10817.2764 - kl_loss: 331.3969 - ArithmeticError: 0.0868
# Epoch 132/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11141.5397 - reconstruction_loss: 10760.7871 - kl_loss: 332.3887 - ArithmeticError: 0.0869
# Epoch 133/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 11076.1559 - reconstruction_loss: 10750.8027 - kl_loss: 319.1117 - ArithmeticError: 0.0868
# Epoch 134/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 11035.6070 - reconstruction_loss: 10746.2637 - kl_loss: 307.7095 - ArithmeticError: 0.0868
# Epoch 135/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10969.8854 - reconstruction_loss: 10700.4990 - kl_loss: 288.9228 - ArithmeticError: 0.0867
# Epoch 136/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10989.1959 - reconstruction_loss: 10799.4590 - kl_loss: 303.1484 - ArithmeticError: 0.0868
# Epoch 137/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10997.2243 - reconstruction_loss: 10667.2764 - kl_loss: 327.1128 - ArithmeticError: 0.0872
# Epoch 138/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10936.0361 - reconstruction_loss: 10702.8057 - kl_loss: 268.8555 - ArithmeticError: 0.0868
# Epoch 139/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10984.9357 - reconstruction_loss: 10744.1533 - kl_loss: 280.6420 - ArithmeticError: 0.0868
# Epoch 140/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 11019.5712 - reconstruction_loss: 10685.5127 - kl_loss: 278.3724 - ArithmeticError: 0.0872
# Epoch 141/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10877.9522 - reconstruction_loss: 10651.1006 - kl_loss: 271.9325 - ArithmeticError: 0.0867
# Epoch 142/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10827.6969 - reconstruction_loss: 10575.4492 - kl_loss: 274.5512 - ArithmeticError: 0.0867
# Epoch 143/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10847.2109 - reconstruction_loss: 10626.3867 - kl_loss: 265.1498 - ArithmeticError: 0.0868
# Epoch 144/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10851.4761 - reconstruction_loss: 10565.4404 - kl_loss: 277.9545 - ArithmeticError: 0.0870
# Epoch 145/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10835.7887 - reconstruction_loss: 10603.9561 - kl_loss: 249.5843 - ArithmeticError: 0.0867
# Epoch 146/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10809.3519 - reconstruction_loss: 10514.8965 - kl_loss: 261.7657 - ArithmeticError: 0.0868
# Epoch 147/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10751.0791 - reconstruction_loss: 10521.3867 - kl_loss: 238.5481 - ArithmeticError: 0.0868
# Epoch 148/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10756.0254 - reconstruction_loss: 10509.6436 - kl_loss: 239.3564 - ArithmeticError: 0.0867
# Epoch 149/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10683.9928 - reconstruction_loss: 10481.4121 - kl_loss: 232.0311 - ArithmeticError: 0.0866
# Epoch 150/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10723.0227 - reconstruction_loss: 10480.2051 - kl_loss: 232.6184 - ArithmeticError: 0.0868
# Epoch 151/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10667.3754 - reconstruction_loss: 10500.0723 - kl_loss: 213.3484 - ArithmeticError: 0.0867
# Epoch 152/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10654.2626 - reconstruction_loss: 10443.7900 - kl_loss: 221.4263 - ArithmeticError: 0.0867
# Epoch 153/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10622.3210 - reconstruction_loss: 10423.8428 - kl_loss: 206.5121 - ArithmeticError: 0.0867
# Epoch 154/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10576.8804 - reconstruction_loss: 10382.9404 - kl_loss: 204.8709 - ArithmeticError: 0.0865
# Epoch 155/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10614.9339 - reconstruction_loss: 10392.5771 - kl_loss: 207.7394 - ArithmeticError: 0.0867
# Epoch 156/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10555.8130 - reconstruction_loss: 10353.1211 - kl_loss: 200.2429 - ArithmeticError: 0.0865
# Epoch 157/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10551.2820 - reconstruction_loss: 10357.3965 - kl_loss: 195.7016 - ArithmeticError: 0.0865
# Epoch 158/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10538.4724 - reconstruction_loss: 10338.2822 - kl_loss: 198.9511 - ArithmeticError: 0.0865
# Epoch 159/2000
# 47/47 [==============================] - 7s 146ms/step - loss: 10554.8981 - reconstruction_loss: 10339.6279 - kl_loss: 197.7429 - ArithmeticError: 0.0867
# Epoch 160/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10528.7568 - reconstruction_loss: 10330.1240 - kl_loss: 189.6105 - ArithmeticError: 0.0865
# Epoch 161/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10526.7003 - reconstruction_loss: 10322.9365 - kl_loss: 184.8497 - ArithmeticError: 0.0865
# Epoch 162/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10478.1796 - reconstruction_loss: 10298.5947 - kl_loss: 182.7126 - ArithmeticError: 0.0864
# Epoch 163/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10460.4074 - reconstruction_loss: 10279.0811 - kl_loss: 171.5398 - ArithmeticError: 0.0862
# Epoch 164/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10480.7324 - reconstruction_loss: 10304.7148 - kl_loss: 170.9703 - ArithmeticError: 0.0863
# Epoch 165/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10452.2359 - reconstruction_loss: 10277.5557 - kl_loss: 171.3946 - ArithmeticError: 0.0863
# Epoch 166/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10434.1549 - reconstruction_loss: 10271.5820 - kl_loss: 163.4085 - ArithmeticError: 0.0863
# Epoch 167/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10458.1217 - reconstruction_loss: 10290.5029 - kl_loss: 160.9705 - ArithmeticError: 0.0864
# Epoch 168/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10415.3160 - reconstruction_loss: 10252.1992 - kl_loss: 158.6829 - ArithmeticError: 0.0862
# Epoch 169/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10419.1427 - reconstruction_loss: 10257.2432 - kl_loss: 153.4106 - ArithmeticError: 0.0862
# Epoch 170/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10411.7621 - reconstruction_loss: 10251.2305 - kl_loss: 153.4334 - ArithmeticError: 0.0862
# Epoch 171/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10434.8728 - reconstruction_loss: 10263.0039 - kl_loss: 149.8476 - ArithmeticError: 0.0865
# Epoch 172/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10403.8595 - reconstruction_loss: 10249.3496 - kl_loss: 146.8600 - ArithmeticError: 0.0862
# Epoch 173/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10399.1595 - reconstruction_loss: 10248.6738 - kl_loss: 146.2317 - ArithmeticError: 0.0861
# Epoch 174/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10393.5627 - reconstruction_loss: 10242.8428 - kl_loss: 144.7119 - ArithmeticError: 0.0862
# Epoch 175/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10376.6420 - reconstruction_loss: 10230.1934 - kl_loss: 142.4984 - ArithmeticError: 0.0861
# Epoch 176/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10381.6976 - reconstruction_loss: 10243.8809 - kl_loss: 137.2907 - ArithmeticError: 0.0862
# Epoch 177/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10361.7965 - reconstruction_loss: 10249.0381 - kl_loss: 134.5114 - ArithmeticError: 0.0861
# Epoch 178/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10364.2099 - reconstruction_loss: 10238.3193 - kl_loss: 133.3816 - ArithmeticError: 0.0862
# Epoch 179/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10365.4621 - reconstruction_loss: 10233.7461 - kl_loss: 129.7130 - ArithmeticError: 0.0862
# Epoch 180/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10351.6572 - reconstruction_loss: 10222.9990 - kl_loss: 127.0791 - ArithmeticError: 0.0861
# Epoch 181/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10335.2979 - reconstruction_loss: 10218.3486 - kl_loss: 123.4660 - ArithmeticError: 0.0860
# Epoch 182/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10339.8877 - reconstruction_loss: 10218.4092 - kl_loss: 121.1925 - ArithmeticError: 0.0860
# Epoch 183/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10337.4038 - reconstruction_loss: 10214.0947 - kl_loss: 121.0231 - ArithmeticError: 0.0861
# Epoch 184/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10323.2893 - reconstruction_loss: 10207.8975 - kl_loss: 116.0270 - ArithmeticError: 0.0860
# Epoch 185/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10323.1501 - reconstruction_loss: 10206.5840 - kl_loss: 112.8263 - ArithmeticError: 0.0861
# Epoch 186/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10331.3128 - reconstruction_loss: 10220.0508 - kl_loss: 108.2960 - ArithmeticError: 0.0861
# Epoch 187/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10320.0630 - reconstruction_loss: 10198.9912 - kl_loss: 110.9829 - ArithmeticError: 0.0861
# Epoch 188/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10304.6165 - reconstruction_loss: 10207.3008 - kl_loss: 107.8154 - ArithmeticError: 0.0860
# Epoch 189/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10315.0188 - reconstruction_loss: 10193.3027 - kl_loss: 108.0633 - ArithmeticError: 0.0861
# Epoch 190/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10303.8383 - reconstruction_loss: 10204.8799 - kl_loss: 103.5937 - ArithmeticError: 0.0861
# Epoch 191/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10313.5153 - reconstruction_loss: 10205.1289 - kl_loss: 105.0446 - ArithmeticError: 0.0862
# Epoch 192/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10303.4578 - reconstruction_loss: 10194.2715 - kl_loss: 101.2117 - ArithmeticError: 0.0861
# Epoch 193/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10283.1884 - reconstruction_loss: 10187.6162 - kl_loss: 98.6202 - ArithmeticError: 0.0860
# Epoch 194/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10282.1405 - reconstruction_loss: 10187.5947 - kl_loss: 96.8624 - ArithmeticError: 0.0860
# Epoch 195/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10307.7947 - reconstruction_loss: 10184.4199 - kl_loss: 96.1998 - ArithmeticError: 0.0862
# Epoch 196/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10285.9591 - reconstruction_loss: 10188.9297 - kl_loss: 92.0743 - ArithmeticError: 0.0860
# Epoch 197/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10271.1485 - reconstruction_loss: 10184.1113 - kl_loss: 92.2883 - ArithmeticError: 0.0860
# Epoch 198/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10281.3676 - reconstruction_loss: 10183.7148 - kl_loss: 89.0295 - ArithmeticError: 0.0860
# Epoch 199/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10267.3518 - reconstruction_loss: 10168.1904 - kl_loss: 88.4890 - ArithmeticError: 0.0860
# Epoch 200/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10267.0443 - reconstruction_loss: 10175.5615 - kl_loss: 86.1013 - ArithmeticError: 0.0860
# Epoch 201/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10259.4978 - reconstruction_loss: 10174.5225 - kl_loss: 83.8196 - ArithmeticError: 0.0860
# Epoch 202/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10253.6365 - reconstruction_loss: 10161.5996 - kl_loss: 84.0314 - ArithmeticError: 0.0860
# Epoch 203/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10247.8887 - reconstruction_loss: 10166.2412 - kl_loss: 81.8837 - ArithmeticError: 0.0860
# Epoch 204/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10245.4515 - reconstruction_loss: 10159.9053 - kl_loss: 78.9704 - ArithmeticError: 0.0860
# Epoch 205/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10259.3661 - reconstruction_loss: 10167.4131 - kl_loss: 78.8715 - ArithmeticError: 0.0860
# Epoch 206/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10237.4956 - reconstruction_loss: 10153.7041 - kl_loss: 77.5150 - ArithmeticError: 0.0860
# Epoch 207/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10225.2479 - reconstruction_loss: 10152.1143 - kl_loss: 74.0803 - ArithmeticError: 0.0860
# Epoch 208/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10231.2458 - reconstruction_loss: 10144.1475 - kl_loss: 74.2110 - ArithmeticError: 0.0860
# Epoch 209/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10215.6986 - reconstruction_loss: 10149.6240 - kl_loss: 71.9397 - ArithmeticError: 0.0859
# Epoch 210/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10234.7311 - reconstruction_loss: 10144.1992 - kl_loss: 74.3550 - ArithmeticError: 0.0860
# Epoch 211/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10215.4682 - reconstruction_loss: 10132.7168 - kl_loss: 70.3893 - ArithmeticError: 0.0859
# Epoch 212/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10207.5671 - reconstruction_loss: 10134.2334 - kl_loss: 69.1117 - ArithmeticError: 0.0860
# Epoch 213/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10200.6675 - reconstruction_loss: 10128.9736 - kl_loss: 69.1933 - ArithmeticError: 0.0859
# Epoch 214/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10194.3851 - reconstruction_loss: 10118.0264 - kl_loss: 65.9722 - ArithmeticError: 0.0860
# Epoch 215/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10201.6305 - reconstruction_loss: 10123.2070 - kl_loss: 67.3042 - ArithmeticError: 0.0860
# Epoch 216/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10187.9622 - reconstruction_loss: 10108.7764 - kl_loss: 65.3973 - ArithmeticError: 0.0860
# Epoch 217/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10178.3390 - reconstruction_loss: 10116.5469 - kl_loss: 61.2123 - ArithmeticError: 0.0860
# Epoch 218/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10174.0476 - reconstruction_loss: 10105.6221 - kl_loss: 61.9117 - ArithmeticError: 0.0860
# Epoch 219/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10170.3537 - reconstruction_loss: 10101.4297 - kl_loss: 59.2817 - ArithmeticError: 0.0859
# Epoch 220/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10163.2405 - reconstruction_loss: 10095.1270 - kl_loss: 58.1557 - ArithmeticError: 0.0859
# Epoch 221/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10150.5789 - reconstruction_loss: 10090.9756 - kl_loss: 55.8281 - ArithmeticError: 0.0859
# Epoch 222/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10147.7449 - reconstruction_loss: 10095.4678 - kl_loss: 56.2593 - ArithmeticError: 0.0860
# Epoch 223/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10145.9283 - reconstruction_loss: 10081.5410 - kl_loss: 59.2567 - ArithmeticError: 0.0860
# Epoch 224/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10136.2815 - reconstruction_loss: 10072.7119 - kl_loss: 55.0622 - ArithmeticError: 0.0859
# Epoch 225/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10130.7229 - reconstruction_loss: 10065.6914 - kl_loss: 54.2996 - ArithmeticError: 0.0859
# Epoch 226/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10115.7683 - reconstruction_loss: 10069.4727 - kl_loss: 50.9653 - ArithmeticError: 0.0860
# Epoch 227/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10121.3404 - reconstruction_loss: 10055.1611 - kl_loss: 51.8089 - ArithmeticError: 0.0860
# Epoch 228/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10114.1733 - reconstruction_loss: 10050.2002 - kl_loss: 50.1056 - ArithmeticError: 0.0860
# Epoch 229/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10096.6528 - reconstruction_loss: 10039.8262 - kl_loss: 47.1944 - ArithmeticError: 0.0861
# Epoch 230/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10093.8563 - reconstruction_loss: 10041.8340 - kl_loss: 47.1070 - ArithmeticError: 0.0860
# Epoch 231/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10087.4170 - reconstruction_loss: 10029.8594 - kl_loss: 48.3285 - ArithmeticError: 0.0860
# Epoch 232/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10078.0449 - reconstruction_loss: 10025.6699 - kl_loss: 45.1046 - ArithmeticError: 0.0861
# Epoch 233/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10076.4714 - reconstruction_loss: 10028.0986 - kl_loss: 44.8342 - ArithmeticError: 0.0860
# Epoch 234/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10057.2697 - reconstruction_loss: 10010.4785 - kl_loss: 43.2952 - ArithmeticError: 0.0861
# Epoch 235/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10069.3899 - reconstruction_loss: 10011.5547 - kl_loss: 45.3143 - ArithmeticError: 0.0862
# Epoch 236/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10056.4752 - reconstruction_loss: 9999.3633 - kl_loss: 43.0581 - ArithmeticError: 0.0861
# Epoch 237/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10049.5356 - reconstruction_loss: 9998.0107 - kl_loss: 42.1064 - ArithmeticError: 0.0861
# Epoch 238/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10038.8944 - reconstruction_loss: 9999.2432 - kl_loss: 39.0872 - ArithmeticError: 0.0862
# Epoch 239/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10040.7511 - reconstruction_loss: 9988.7002 - kl_loss: 41.4941 - ArithmeticError: 0.0862
# Epoch 240/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10028.7139 - reconstruction_loss: 9981.1270 - kl_loss: 38.6613 - ArithmeticError: 0.0862
# Epoch 241/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10029.3666 - reconstruction_loss: 9981.2656 - kl_loss: 38.7467 - ArithmeticError: 0.0862
# Epoch 242/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10022.4020 - reconstruction_loss: 9996.1924 - kl_loss: 38.6994 - ArithmeticError: 0.0862
# Epoch 243/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10042.8810 - reconstruction_loss: 9988.6191 - kl_loss: 40.9053 - ArithmeticError: 0.0865
# Epoch 244/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10024.7080 - reconstruction_loss: 9977.1611 - kl_loss: 38.2227 - ArithmeticError: 0.0863
# Epoch 245/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10016.6808 - reconstruction_loss: 9969.9111 - kl_loss: 36.7279 - ArithmeticError: 0.0862
# Epoch 246/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10025.8786 - reconstruction_loss: 9972.8340 - kl_loss: 37.2513 - ArithmeticError: 0.0864
# Epoch 247/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10012.3612 - reconstruction_loss: 9969.6133 - kl_loss: 36.3323 - ArithmeticError: 0.0863
# Epoch 248/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10012.8552 - reconstruction_loss: 9962.8467 - kl_loss: 35.4786 - ArithmeticError: 0.0863
# Epoch 249/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10013.9465 - reconstruction_loss: 9968.6104 - kl_loss: 35.9164 - ArithmeticError: 0.0863
# Epoch 250/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10010.1747 - reconstruction_loss: 9964.6777 - kl_loss: 36.1474 - ArithmeticError: 0.0863
# Epoch 251/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 10001.9530 - reconstruction_loss: 9961.6719 - kl_loss: 34.1419 - ArithmeticError: 0.0863
# Epoch 252/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10012.1563 - reconstruction_loss: 9961.7422 - kl_loss: 34.9108 - ArithmeticError: 0.0864
# Epoch 253/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9999.9986 - reconstruction_loss: 9957.3887 - kl_loss: 33.5606 - ArithmeticError: 0.0863
# Epoch 254/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 10009.0114 - reconstruction_loss: 9961.8994 - kl_loss: 34.3107 - ArithmeticError: 0.0864
# Epoch 255/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9994.9920 - reconstruction_loss: 9956.2510 - kl_loss: 32.4219 - ArithmeticError: 0.0863
# Epoch 256/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9998.3895 - reconstruction_loss: 9954.5391 - kl_loss: 32.6014 - ArithmeticError: 0.0863
# Epoch 257/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9997.5699 - reconstruction_loss: 9955.4502 - kl_loss: 32.3358 - ArithmeticError: 0.0863
# Epoch 258/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9996.3545 - reconstruction_loss: 9953.8848 - kl_loss: 32.2289 - ArithmeticError: 0.0863
# Epoch 259/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9996.6370 - reconstruction_loss: 9955.1973 - kl_loss: 31.3853 - ArithmeticError: 0.0863
# Epoch 260/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9995.8347 - reconstruction_loss: 9955.2695 - kl_loss: 31.2645 - ArithmeticError: 0.0862
# Epoch 261/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9993.9060 - reconstruction_loss: 9953.8447 - kl_loss: 31.5009 - ArithmeticError: 0.0863
# Epoch 262/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9995.4173 - reconstruction_loss: 9954.9014 - kl_loss: 31.4403 - ArithmeticError: 0.0862
# Epoch 263/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9989.8844 - reconstruction_loss: 9949.8174 - kl_loss: 30.8258 - ArithmeticError: 0.0862
# Epoch 264/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9992.1775 - reconstruction_loss: 9954.8457 - kl_loss: 30.4837 - ArithmeticError: 0.0863
# Epoch 265/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9991.5750 - reconstruction_loss: 9952.0752 - kl_loss: 30.6917 - ArithmeticError: 0.0862
# Epoch 266/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9988.1458 - reconstruction_loss: 9949.7412 - kl_loss: 30.3620 - ArithmeticError: 0.0861
# Epoch 267/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9989.8779 - reconstruction_loss: 9952.9639 - kl_loss: 30.6381 - ArithmeticError: 0.0862
# Epoch 268/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9989.5792 - reconstruction_loss: 9950.4033 - kl_loss: 29.6731 - ArithmeticError: 0.0862
# Epoch 269/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9989.3772 - reconstruction_loss: 9949.0225 - kl_loss: 29.6170 - ArithmeticError: 0.0862
# Epoch 270/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9987.4482 - reconstruction_loss: 9949.5654 - kl_loss: 28.9440 - ArithmeticError: 0.0861
# Epoch 271/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9989.5565 - reconstruction_loss: 9948.9033 - kl_loss: 29.9289 - ArithmeticError: 0.0861
# Epoch 272/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9987.0089 - reconstruction_loss: 9947.2217 - kl_loss: 29.8000 - ArithmeticError: 0.0861
# Epoch 273/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9982.1518 - reconstruction_loss: 9944.4492 - kl_loss: 28.0470 - ArithmeticError: 0.0861
# Epoch 274/2000
# ...
# Epoch 1906/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9055.8781 - reconstruction_loss: 8948.3008 - kl_loss: 96.6617 - ArithmeticError: 0.0114
# Epoch 1907/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9060.5671 - reconstruction_loss: 8958.1777 - kl_loss: 96.4778 - ArithmeticError: 0.0116
# Epoch 1908/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9064.2996 - reconstruction_loss: 8966.2412 - kl_loss: 96.5559 - ArithmeticError: 0.0116
# Epoch 1909/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9066.7851 - reconstruction_loss: 8971.9219 - kl_loss: 96.3802 - ArithmeticError: 0.0116
# Epoch 1910/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9060.5999 - reconstruction_loss: 8963.6201 - kl_loss: 95.7491 - ArithmeticError: 0.0115
# Epoch 1911/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9055.1664 - reconstruction_loss: 8957.1660 - kl_loss: 95.2399 - ArithmeticError: 0.0114
# Epoch 1912/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9049.8454 - reconstruction_loss: 8948.4639 - kl_loss: 95.5115 - ArithmeticError: 0.0113
# Epoch 1913/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9046.1346 - reconstruction_loss: 8944.4492 - kl_loss: 95.6027 - ArithmeticError: 0.0112
# Epoch 1914/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9043.4823 - reconstruction_loss: 8942.4033 - kl_loss: 95.8280 - ArithmeticError: 0.0112
# Epoch 1915/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9041.1211 - reconstruction_loss: 8939.1807 - kl_loss: 95.8877 - ArithmeticError: 0.0112
# Epoch 1916/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9040.0177 - reconstruction_loss: 8939.3027 - kl_loss: 95.6957 - ArithmeticError: 0.0112
# Epoch 1917/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9037.6198 - reconstruction_loss: 8935.9570 - kl_loss: 95.9721 - ArithmeticError: 0.0111
# Epoch 1918/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9036.4755 - reconstruction_loss: 8933.6162 - kl_loss: 96.0382 - ArithmeticError: 0.0112
# Epoch 1919/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9034.0392 - reconstruction_loss: 8931.5635 - kl_loss: 95.8135 - ArithmeticError: 0.0110
# Epoch 1920/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9035.0390 - reconstruction_loss: 8933.3271 - kl_loss: 96.4175 - ArithmeticError: 0.0112
# Epoch 1921/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9034.0916 - reconstruction_loss: 8929.5469 - kl_loss: 96.6912 - ArithmeticError: 0.0111
# Epoch 1922/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9030.8951 - reconstruction_loss: 8926.8506 - kl_loss: 96.4364 - ArithmeticError: 0.0110
# Epoch 1923/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9028.5659 - reconstruction_loss: 8925.9121 - kl_loss: 96.3490 - ArithmeticError: 0.0111
# Epoch 1924/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9027.4655 - reconstruction_loss: 8925.4951 - kl_loss: 96.5898 - ArithmeticError: 0.0112
# Epoch 1925/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9027.2836 - reconstruction_loss: 8923.4941 - kl_loss: 97.0521 - ArithmeticError: 0.0111
# Epoch 1926/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9025.0910 - reconstruction_loss: 8921.7783 - kl_loss: 96.9049 - ArithmeticError: 0.0110
# Epoch 1927/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9022.3343 - reconstruction_loss: 8919.8428 - kl_loss: 96.5252 - ArithmeticError: 0.0111
# Epoch 1928/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9022.2697 - reconstruction_loss: 8918.5488 - kl_loss: 96.3513 - ArithmeticError: 0.0110
# Epoch 1929/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9020.5501 - reconstruction_loss: 8918.7295 - kl_loss: 96.2281 - ArithmeticError: 0.0109
# Epoch 1930/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9018.5241 - reconstruction_loss: 8916.4990 - kl_loss: 96.7978 - ArithmeticError: 0.0110
# Epoch 1931/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9019.4047 - reconstruction_loss: 8915.5352 - kl_loss: 97.1182 - ArithmeticError: 0.0111
# Epoch 1932/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9016.3794 - reconstruction_loss: 8913.8301 - kl_loss: 96.9362 - ArithmeticError: 0.0110
# Epoch 1933/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9016.3965 - reconstruction_loss: 8913.7676 - kl_loss: 96.8195 - ArithmeticError: 0.0110
# Epoch 1934/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9014.3364 - reconstruction_loss: 8911.1680 - kl_loss: 96.9954 - ArithmeticError: 0.0111
# Epoch 1935/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9013.9434 - reconstruction_loss: 8910.7090 - kl_loss: 96.9574 - ArithmeticError: 0.0110
# Epoch 1936/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9014.1025 - reconstruction_loss: 8911.2871 - kl_loss: 96.9975 - ArithmeticError: 0.0110
# Epoch 1937/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9012.8070 - reconstruction_loss: 8909.0605 - kl_loss: 97.1521 - ArithmeticError: 0.0110
# Epoch 1938/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9009.9998 - reconstruction_loss: 8907.2070 - kl_loss: 97.1648 - ArithmeticError: 0.0110
# Epoch 1939/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9009.2712 - reconstruction_loss: 8906.6680 - kl_loss: 97.1955 - ArithmeticError: 0.0110
# Epoch 1940/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9008.3237 - reconstruction_loss: 8904.8555 - kl_loss: 97.1314 - ArithmeticError: 0.0109
# Epoch 1941/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9008.6463 - reconstruction_loss: 8905.1445 - kl_loss: 97.1570 - ArithmeticError: 0.0109
# Epoch 1942/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9005.9071 - reconstruction_loss: 8902.7930 - kl_loss: 97.3298 - ArithmeticError: 0.0110
# Epoch 1943/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9008.5181 - reconstruction_loss: 8914.7549 - kl_loss: 97.1511 - ArithmeticError: 0.0109
# Epoch 1944/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9012.4398 - reconstruction_loss: 8906.5977 - kl_loss: 95.8874 - ArithmeticError: 0.0109
# Epoch 1945/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9004.9576 - reconstruction_loss: 8901.5244 - kl_loss: 96.5638 - ArithmeticError: 0.0110
# Epoch 1946/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9003.7522 - reconstruction_loss: 8900.0508 - kl_loss: 96.9972 - ArithmeticError: 0.0108
# Epoch 1947/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 9002.1552 - reconstruction_loss: 8898.5000 - kl_loss: 97.1397 - ArithmeticError: 0.0109
# Epoch 1948/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 9000.1406 - reconstruction_loss: 8897.0947 - kl_loss: 97.2946 - ArithmeticError: 0.0108
# Epoch 1949/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8999.2342 - reconstruction_loss: 8895.8506 - kl_loss: 97.4937 - ArithmeticError: 0.0108
# Epoch 1950/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8998.2203 - reconstruction_loss: 8894.8789 - kl_loss: 97.5033 - ArithmeticError: 0.0109
# Epoch 1951/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8995.8560 - reconstruction_loss: 8893.3242 - kl_loss: 97.6097 - ArithmeticError: 0.0108
# Epoch 1952/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8996.3946 - reconstruction_loss: 8892.3623 - kl_loss: 97.6335 - ArithmeticError: 0.0108
# Epoch 1953/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8995.1545 - reconstruction_loss: 8891.1631 - kl_loss: 97.8032 - ArithmeticError: 0.0109
# Epoch 1954/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8994.1941 - reconstruction_loss: 8890.2832 - kl_loss: 97.7633 - ArithmeticError: 0.0108
# Epoch 1955/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8992.5763 - reconstruction_loss: 8889.1201 - kl_loss: 97.8865 - ArithmeticError: 0.0108
# Epoch 1956/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8990.8019 - reconstruction_loss: 8887.8613 - kl_loss: 97.9196 - ArithmeticError: 0.0107
# Epoch 1957/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8991.7783 - reconstruction_loss: 8887.5557 - kl_loss: 98.4108 - ArithmeticError: 0.0108
# Epoch 1958/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8988.8847 - reconstruction_loss: 8885.5889 - kl_loss: 98.3798 - ArithmeticError: 0.0108
# Epoch 1959/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8989.8567 - reconstruction_loss: 8885.1982 - kl_loss: 98.3826 - ArithmeticError: 0.0109
# Epoch 1960/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8986.9938 - reconstruction_loss: 8883.7129 - kl_loss: 98.2451 - ArithmeticError: 0.0107
# Epoch 1961/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8987.4829 - reconstruction_loss: 8883.8955 - kl_loss: 98.3836 - ArithmeticError: 0.0109
# Epoch 1962/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8985.4107 - reconstruction_loss: 8882.0596 - kl_loss: 98.4181 - ArithmeticError: 0.0107
# Epoch 1963/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8985.6556 - reconstruction_loss: 8881.1572 - kl_loss: 98.5716 - ArithmeticError: 0.0106
# Epoch 1964/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8984.5773 - reconstruction_loss: 8880.4785 - kl_loss: 98.4378 - ArithmeticError: 0.0107
# Epoch 1965/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8983.3602 - reconstruction_loss: 8879.6787 - kl_loss: 98.4333 - ArithmeticError: 0.0107
# Epoch 1966/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8982.4985 - reconstruction_loss: 8878.4971 - kl_loss: 98.6382 - ArithmeticError: 0.0106
# Epoch 1967/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8981.3232 - reconstruction_loss: 8876.5156 - kl_loss: 98.7057 - ArithmeticError: 0.0106
# Epoch 1968/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8980.3727 - reconstruction_loss: 8876.5811 - kl_loss: 98.2196 - ArithmeticError: 0.0107
# Epoch 1969/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8980.0292 - reconstruction_loss: 8876.7969 - kl_loss: 98.3336 - ArithmeticError: 0.0107
# Epoch 1970/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8979.8728 - reconstruction_loss: 8875.2754 - kl_loss: 98.7070 - ArithmeticError: 0.0107
# Epoch 1971/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8977.4425 - reconstruction_loss: 8873.8447 - kl_loss: 98.8245 - ArithmeticError: 0.0106
# Epoch 1972/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8976.2269 - reconstruction_loss: 8872.3330 - kl_loss: 98.9881 - ArithmeticError: 0.0106
# Epoch 1973/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8975.1740 - reconstruction_loss: 8871.0830 - kl_loss: 98.8083 - ArithmeticError: 0.0106
# Epoch 1974/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8974.0703 - reconstruction_loss: 8870.6572 - kl_loss: 98.8166 - ArithmeticError: 0.0106
# Epoch 1975/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8972.8287 - reconstruction_loss: 8869.2500 - kl_loss: 98.7273 - ArithmeticError: 0.0107
# Epoch 1976/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8972.4859 - reconstruction_loss: 8868.2412 - kl_loss: 98.8862 - ArithmeticError: 0.0104
# Epoch 1977/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8970.6310 - reconstruction_loss: 8866.5000 - kl_loss: 99.0592 - ArithmeticError: 0.0106
# Epoch 1978/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8970.6823 - reconstruction_loss: 8866.2744 - kl_loss: 99.2024 - ArithmeticError: 0.0105
# Epoch 1979/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8968.8421 - reconstruction_loss: 8865.5596 - kl_loss: 98.9322 - ArithmeticError: 0.0106
# Epoch 1980/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8969.1012 - reconstruction_loss: 8865.2031 - kl_loss: 98.7566 - ArithmeticError: 0.0105
# Epoch 1981/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8967.8545 - reconstruction_loss: 8864.0068 - kl_loss: 99.1866 - ArithmeticError: 0.0105
# Epoch 1982/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8967.3688 - reconstruction_loss: 8862.8682 - kl_loss: 99.3065 - ArithmeticError: 0.0105
# Epoch 1983/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8965.5678 - reconstruction_loss: 8861.8506 - kl_loss: 99.2085 - ArithmeticError: 0.0105
# Epoch 1984/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8964.0180 - reconstruction_loss: 8859.8135 - kl_loss: 99.3308 - ArithmeticError: 0.0105
# Epoch 1985/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8963.1277 - reconstruction_loss: 8859.5840 - kl_loss: 99.2109 - ArithmeticError: 0.0104
# Epoch 1986/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8961.7196 - reconstruction_loss: 8857.9912 - kl_loss: 99.2542 - ArithmeticError: 0.0105
# Epoch 1987/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8963.5473 - reconstruction_loss: 8857.7158 - kl_loss: 99.6308 - ArithmeticError: 0.0105
# Epoch 1988/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8961.2211 - reconstruction_loss: 8857.1270 - kl_loss: 99.6872 - ArithmeticError: 0.0105
# Epoch 1989/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8960.2293 - reconstruction_loss: 8855.5225 - kl_loss: 99.7159 - ArithmeticError: 0.0104
# Epoch 1990/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8959.2874 - reconstruction_loss: 8855.9619 - kl_loss: 99.3393 - ArithmeticError: 0.0105
# Epoch 1991/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8959.2574 - reconstruction_loss: 8855.2402 - kl_loss: 98.7933 - ArithmeticError: 0.0105
# Epoch 1992/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8957.9742 - reconstruction_loss: 8853.4727 - kl_loss: 99.3193 - ArithmeticError: 0.0105
# Epoch 1993/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8956.4647 - reconstruction_loss: 8852.2471 - kl_loss: 99.5517 - ArithmeticError: 0.0104
# Epoch 1994/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8954.8370 - reconstruction_loss: 8850.9902 - kl_loss: 99.6839 - ArithmeticError: 0.0105
# Epoch 1995/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8954.0488 - reconstruction_loss: 8849.1895 - kl_loss: 99.7374 - ArithmeticError: 0.0104
# Epoch 1996/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8954.9172 - reconstruction_loss: 8849.3096 - kl_loss: 100.1026 - ArithmeticError: 0.0105
# Epoch 1997/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8952.2862 - reconstruction_loss: 8848.1758 - kl_loss: 99.9989 - ArithmeticError: 0.0104
# Epoch 1998/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8950.9102 - reconstruction_loss: 8846.8467 - kl_loss: 100.0006 - ArithmeticError: 0.0103
# Epoch 1999/2000
# 47/47 [==============================] - 7s 147ms/step - loss: 8949.8735 - reconstruction_loss: 8845.4824 - kl_loss: 99.9303 - ArithmeticError: 0.0104
# Epoch 2000/2000
# 47/47 [==============================] - 7s 148ms/step - loss: 8949.7562 - reconstruction_loss: 8845.1738 - kl_loss: 100.0070 - ArithmeticError: 0.0105

# %%
### Guardar modelohttps://www.tensorflow.org/guide/saved_model?hl=es-419
vae.encoder.save('Models/norm_GVAE_distangled_encoder_DRY_1_32.h5')
vae.decoder.save('Models/norm_GVAE_distangled_decoder_DRY_1_32.h5')
vae.regressor.save('Models/norm_GVAE_distangled_regressor_DRY_1_32.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
