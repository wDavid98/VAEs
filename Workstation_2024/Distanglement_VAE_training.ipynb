# %% [markdown]
# # Librería

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['TF_ENABLE_ONEDNN_OPTS'] =  "0"



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

## Librerías
import seaborn as sns
import sys
import cv2 as cv2
import glob
from PIL import Image
import tensorflow as tf
import sys
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import gc
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
import os


from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler

print(tf.__version__)
# Out:
# 2024-01-24 00:31:03.808623: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-24 00:31:03.808665: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-24 00:31:03.811948: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-24 00:31:04.155547: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.14.0

# %%
## Uso de GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# 2024-01-24 00:31:07.873020: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:07.937704: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:07.937859: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# # Datos

# %%
## Obtener todas las rutas de las imágenes en el dataset
ruta = '../Datasets/Micrografías_segmentadas/secas/*/*/*/*.jpg'
rutas_dataset  = glob.glob('../../../Datasets/Micrografías segmentaciones/secas/*/*/*/*.jpg')

## Separar rutas
mask_list = []
image_list = []
for ruta in rutas_dataset:    
    ruta_list = ruta.split('/')       
    clase = ruta_list[6]
    number = ruta_list[7]
    tipo = ruta_list[8]
    name = ruta_list[9].split('.')[0]
    
    if tipo == 'train':
        image_list.append([name,ruta,clase,number])
    elif tipo == 'mask_bin':
        mask_list.append([name,ruta,clase,number])
    else:
        None

mask_pd = pd.DataFrame(mask_list,columns=['name','route_mask','label','number']).sort_values(by='name')
image_pd = pd.DataFrame(image_list,columns=['name','route_image','label','number']).sort_values(by='name')

routes_dataset = image_pd.merge(mask_pd,on=['name','label','number'],how='left')

routes_dataset.dropna(inplace=True)

routes_dataset = routes_dataset.sample(frac = 1)

print('Imágenes secas:', np.shape(routes_dataset)[0])
print('MF1:', np.shape(routes_dataset[routes_dataset['label']=='MF1'])[0])
print('MF2:', np.shape(routes_dataset[routes_dataset['label']=='MF2'])[0])
print('MF3:', np.shape(routes_dataset[routes_dataset['label']=='MF3'])[0])

char_to_num = {'MF1':'0','MF2':'1','MF3':'2'}

routes_dataset['label'].replace(char_to_num,inplace=True)

routes_dataset
# Out:
# Imágenes secas: 923
# MF1: 378
# MF2: 284
# MF3: 261
#                         name  \
# 608  IMG_20230711_165654_jpg
# 766  IMG_20230711_210644_jpg
# 844  IMG_20230711_212857_jpg
# 520  IMG_20230711_154923_jpg
# 574  IMG_20230711_163337_jpg
# ..                       ...
# 589  IMG_20230711_163549_jpg
# 861  IMG_20230711_214650_jpg
# 434  IMG_20230707_191350_jpg
# 239  IMG_20230707_171111_jpg
# 710  IMG_20230711_180502_jpg
#
#                                            route_image label number  \
# 608  ../../../Datasets/Micrografías segmentaciones/...     1      4
# 766  ../../../Datasets/Micrografías segmentaciones/...     2      2
# 844  ../../../Datasets/Micrografías segmentaciones/...     2      7
# 520  ../../../Datasets/Micrografías segmentaciones/...     1      1
# 574  ../../../Datasets/Micrografías segmentaciones/...     1      3
# ..                                                 ...   ...    ...
# 589  ../../../Datasets/Micrografías segmentaciones/...     1      3
# 861  ../../../Datasets/Micrografías segmentaciones/...     2      6
# 434  ../../../Datasets/Micrografías segmentaciones/...     0      7
# 239  ../../../Datasets/Micrografías segmentaciones/...     0      3
# 710  ../../../Datasets/Micrografías segmentaciones/...     1      6
#
#                                             route_mask
# 608  ../../../Datasets/Micrografías segmentaciones/...
# 766  ../../../Datasets/Micrografías segmentaciones/...
# 844  ../../../Datasets/Micrografías segmentaciones/...
# 520  ../../../Datasets/Micrografías segmentaciones/...
# 574  ../../../Datasets/Micrografías segmentaciones/...
# ..                                                 ...
# 589  ../../../Datasets/Micrografías segmentaciones/...
# 861  ../../../Datasets/Micrografías segmentaciones/...
# 434  ../../../Datasets/Micrografías segmentaciones/...
# 239  ../../../Datasets/Micrografías segmentaciones/...
# 710  ../../../Datasets/Micrografías segmentaciones/...
#
# [923 rows x 5 columns]

# %%
## Establecer el porcentaje de separación
thold1 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='0'])))
thold2 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='1'])))
thold3 = int(np.ceil(0.8 * len(routes_dataset[routes_dataset.label=='2'])))

## Separar por clases para entrenamiento
train_cu1 = routes_dataset[routes_dataset.label == '0'][0:thold1]
train_cu2 = routes_dataset[routes_dataset.label == '1'][0:thold2]
train_cu3 = routes_dataset[routes_dataset.label == '2'][0:thold3]

## tomar las demás imágenes para test
test_cu1 = routes_dataset[routes_dataset.label == '0'][thold1:]
test_cu2 = routes_dataset[routes_dataset.label == '1'][thold2:]
test_cu3 = routes_dataset[routes_dataset.label == '2'][thold3:]


## Constuir un solo dataset de training
train_df =  pd.concat([pd.concat([train_cu1,train_cu2]),train_cu3]).sample(frac=1,random_state=42).reset_index(drop=True)

## Construir un solo dataset de test
test_df = pd.concat([pd.concat([test_cu1,test_cu2]),test_cu3]).sample(frac=1,random_state=100).reset_index(drop=True)

## Cantidad de muestras por clase
print('Clase MF1: train: ',len(train_cu1),', test: ',len(test_cu1))
print('Clase MF2: train: ',len(train_cu2),', test: ',len(test_cu2))
print('Clase MF3: train: ',len(train_cu3),', test: ',len(test_cu3))
# Out:
# Clase MF1: train:  303 , test:  75
# Clase MF2: train:  228 , test:  56
# Clase MF3: train:  209 , test:  52

# %%
## Function to get contours and features
def get_contours_and_features(binary_map):
    # get binary map
    binary_map = cv2.cvtColor(binary_map, cv2.COLOR_BGR2GRAY)
    # get contours from binary map
    contours, hierarchy = cv2.findContours(binary_map, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    # get features from contours
    contours_features = []
    for contour in contours:
        error = 1e-5

        moments = cv2.moments(contour)
        cx = moments['m10'] / (moments['m00'] + error)
        cy = moments['m01'] / (moments['m00'] + error)
        center_of_mass = [cx, cy]
        features = {
            'area': cv2.contourArea(contour),
            'perimeter': cv2.arcLength(contour, True),
            'moments': moments,
            'center_of_mass': center_of_mass,
            'contour': contour
        }
        contours_features.append(features)
        del features    
    return contours_features

# function to get a determined property from a list of contours features (area by default)
def get_item(contour_features, key='area'):
    areas = []
    for contour_feature in contour_features:
        area =  contour_feature[key]
        areas.append(area)
    return areas

# function to get tensor of one image
def load_image(file_name):
  raw = tf.io.read_file(file_name)
  tensor = tf.io.decode_jpeg(raw,channels=1)
  tensor = tf.image.resize(tensor, [128,128])
  tensor = tf.cast(tensor, tf.float32) / 255.0
  return tensor

# function to get set of binary image from image loaded
def get_binary_image(filenames):
    tensores = []
    for filename in filenames:
        raw = tf.io.read_file(filename)
        tensor = tf.io.decode_jpeg(raw,channels=3)
        tensor = tf.image.resize(tensor, [128,128])
        tensor = tf.cast(tensor, tf.float32) / 255.0
        tensores.append(tensor)
    return tensores

def get_geometric_atributes(binary_images):
    atributes = []
    for binary_img in binary_images:
        ## Formato
        image = binary_img.numpy().astype(np.uint8)       
        
        ## Capturar contornos
        contour_features = get_contours_and_features(image)        

        ## obtener área de poros##
        area = np.ceil(np.sum(get_item(contour_features, key='area')))

        ## obtener perímetro de poros
        perimetro = np.ceil(np.sum(get_item(contour_features, key='perimeter'))
)
        ## intersticio
        area_total = np.ceil(np.shape(image)[0] * np.shape(image)[1])
        intersticio = np.ceil(area_total - area)

        ## Cantidad de poros
        poros = np.shape(contour_features)[0]

        #atributes = [area,perimetro,intersticio,poros]
        atributes.append([area,perimetro,intersticio,poros])
    
    return atributes

def create_dataset(buffer,file_names, labels, file_mask): 
  ## Get binary images   
  masks = get_binary_image(file_mask)
  ## Get geometric atributes from binary images
  attributes = get_geometric_atributes(masks)
  ## Create dataset from tensors assosiated with labels and attributes
  dataset = tf.data.Dataset.from_tensor_slices((file_names,labels,attributes))
  ## Shuffle dataset
  dataset.shuffle(buffer_size=buffer)
  ## Map dataset to load images (a = image, b = label, c = attributes, d = mask)
  dataset = dataset.map(lambda file_name, label, attributes : (load_image(file_name), label, attributes))

  return dataset

file_names = train_df['route_image'].to_numpy()
file_mask = train_df['route_mask'].to_numpy()
labels = train_df['label'].to_numpy()
## Create training dataset using tf.data of 16 images
dataset = create_dataset(16,file_names, labels,file_mask)
# Out:
# 2024-01-24 00:31:10.908750: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:10.908914: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:10.909021: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:11.194084: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:11.194260: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:11.194382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 00:31:11.194474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7480 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:08:00.0, compute capability: 8.6

# %%
cnt = 0
for i in dataset.batch(16):
    a = i[0]
    b = i[1]
    c = i[2]
    #d = i[3]

n =  0
print(c[n].numpy())
print(b[n].numpy())
plt.imshow(a[n],cmap='gray')
#plt.imshow(d[n],cmap='gray')
plt.show()
# Out:
# [6788. 1941. 9596.   32.]
# b'0'

# %% [markdown]
# # Modelos

# %% [markdown]
# ### Autoencoder convencional

# %% [markdown]
# ### Variational autoencoder

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")        

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data[0])
            reconstruction = self.decoder(z)
            reconstruction /= tf.reduce_max(reconstruction)
            
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data[0], reconstruction), axis=(1, 2)
                )
            )
            
            '''
            reconstruction_loss =tf.reduce_mean(
                tf.reduce_sum( tf.keras.losses.MeanSquaredError()(data, reconstruction)
                             )
            )
            '''
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))            
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.reconstruction = reconstruction
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)       
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),            
        }

# %%
###_____________________________ENCODER________________________##
latent_dim = 32

nx, ny = 128, 128

encoder_inputs = keras.Input(shape=(nx, ny,1))

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E1')(encoder_inputs)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E2')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same',name='layer_E3')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same',name='layer_E4')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_E6')(x)
x = layers.Flatten()(x)



z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(inputs=encoder_inputs, outputs=[z_mean, z_log_var, z], name="encoder")
encoder.summary()

# %%
## Entrada Z
latent_inputs = keras.Input(shape=(latent_dim,))

##dimensiones
ndim = 16
nfilts = 128

## anti-flatten de la última capa convolucional
x = layers.Dense(ndim * ndim * nfilts, activation="relu")(latent_inputs)

## Reshape para reconstruir la última convolucional
x = layers.Reshape((ndim,ndim, nfilts))(x)

## Capas convolucionales
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D1')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D2')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_D4')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same',name='layer_D6')(x)

decoder_outputs = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='layer_D7')(x)

## Construcción del decoder
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

# %%
vae = VAE(encoder, decoder)
opt = tf.optimizers.Adam(learning_rate = 0.000001)
#nll = lambda x , rv_x: -rv_x.log_prob(x)
vae.compile(optimizer=opt)


vae.fit(dataset.batch(16), epochs=2000, 
                batch_size=16,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=100)])

# %%
### Guardar modelo https://www.tensorflow.org/guide/saved_model?hl=es-419
vae.encoder.save('Models/GVAE_encoder_DRY_1_32.h5')
vae.decoder.save('Models/GVAE_decoder_DRY_1_32.h5')

# %% [markdown]
# ### Disentangled variational autoencoder

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class VAE(keras.Model):
    def __init__(self, encoder, decoder, regressor, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.regressor = regressor
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")        
        self.estimation_loss_tracker = keras.metrics.Mean(name="estimation_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.estimation_loss_tracker,            
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            ## Valores estimados por el encoder
            z_mean, z_log_var, z = self.encoder(data[0])
            
            ## Valores geométricos asociados a los datos
            geometrics_features = data[2]

            ## Reconstrucción del embebido del encoder
            reconstruction = self.decoder(z)            

            ## Reducción de la reconstrucción
            reconstruction /= tf.reduce_max(reconstruction)

            ## Valores estimados apartir del regresor
            estimation = self.regressor(reconstruction)
            
            ## Error de reconstrucción
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data[0], reconstruction), axis=(1, 2)
                )
            )

            '''
            reconstruction_loss =tf.reduce_mean(
                tf.reduce_sum( tf.keras.losses.MeanSquaredError()(data, reconstruction)
                             )
            )
            '''
            
            ## Error de estimación de valores geométricos
            estimation_loss = tf.reduce_mean(tf.keras.losses.MeanSquaredError()(geometrics_features, estimation))
            
            
            ## Error de divergencia KL
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))   

            ## Error total          
            total_loss = reconstruction_loss + kl_loss + estimation_loss
        
        ## Actualización de los gradientes
        grads = tape.gradient(total_loss, self.trainable_weights)

        ## Actualización de lA RECONSTRUCCIÓN
        self.reconstruction = reconstruction

        ### Actualización de los pesos
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)   
        self.estimation_loss_tracker.update_state(estimation_loss)    
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(), 
            "ArithmeticError": self.estimation_loss_tracker.result(),        
        }

# %%
###_____________________________ENCODER________________________##
latent_dim = 32

nx, ny = 128, 128

encoder_inputs = keras.Input(shape=(nx, ny,1))

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E1')(encoder_inputs)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E2')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same',name='layer_E3')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same',name='layer_E4')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_E6')(x)
x = layers.Flatten()(x)



z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(inputs=encoder_inputs, outputs=[z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  layer_E1 (Conv2D)           (None, 128, 128, 1024)       10240     ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 1024)         0         ['layer_E1[0][0]']
#  D)
#
#  batch_normalization (Batch  (None, 64, 64, 1024)         4096      ['max_pooling2d[0][0]']
#  Normalization)
#
#  layer_E2 (Conv2D)           (None, 64, 64, 1024)         9438208   ['batch_normalization[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 1024)         0         ['layer_E2[0][0]']
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 32, 32, 1024)         4096      ['max_pooling2d_1[0][0]']
#  chNormalization)
#
#  layer_E3 (Conv2D)           (None, 32, 32, 512)          4719104   ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 512)          0         ['layer_E3[0][0]']
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 512)          2048      ['max_pooling2d_2[0][0]']
#  chNormalization)
#
#  layer_E4 (Conv2D)           (None, 16, 16, 256)          1179904   ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 256)            0         ['layer_E4[0][0]']
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 8, 8, 256)            1024      ['max_pooling2d_3[0][0]']
#  chNormalization)
#
#  layer_E6 (Conv2D)           (None, 8, 8, 128)            295040    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  flatten (Flatten)           (None, 8192)                 0         ['layer_E6[0][0]']
#
#  z_mean (Dense)              (None, 32)                   262176    ['flatten[0][0]']
#
#  z_log_var (Dense)           (None, 32)                   262176    ['flatten[0][0]']
#
#  sampling (Sampling)         (None, 32)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 16178112 (61.71 MB)
# Trainable params: 16172480 (61.69 MB)
# Non-trainable params: 5632 (22.00 KB)
# __________________________________________________________________________________________________

# %%
## Entrada Z
latent_inputs = keras.Input(shape=(latent_dim,))

##dimensiones
ndim = 16
nfilts = 128

## anti-flatten de la última capa convolucional
x = layers.Dense(ndim * ndim * nfilts, activation="relu")(latent_inputs)

## Reshape para reconstruir la última convolucional
x = layers.Reshape((ndim,ndim, nfilts))(x)

## Capas convolucionales
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D1')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D2')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_D4')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same',name='layer_D6')(x)

decoder_outputs = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='layer_D7')(x)

## Construcción del decoder
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 32768)             1081344
#
#  reshape (Reshape)           (None, 16, 16, 128)       0
#
#  layer_D1 (Conv2D)           (None, 16, 16, 128)       147584
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 128)       0
#  D)
#
#  batch_normalization_4 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  layer_D2 (Conv2D)           (None, 32, 32, 128)       147584
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 128)       0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 64, 64, 128)       512
#  chNormalization)
#
#  layer_D4 (Conv2D)           (None, 64, 64, 64)        73792
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 64)      0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  layer_D6 (Conv2D)           (None, 128, 128, 16)      9232
#
#  layer_D7 (Conv2D)           (None, 128, 128, 1)       145
#
# =================================================================
# Total params: 1460961 (5.57 MB)
# Trainable params: 1460321 (5.57 MB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
### Estimador de valores geométricos

## Input layer
regressor_inputs = keras.Input(shape=(128,128,1))

## Hidden layers
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same',name='layer_R1')(regressor_inputs)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R2')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_R3')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R4')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_R5')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R6')(x)
x = layers.BatchNormalization()(x)

## Output layer
flatten = layers.Flatten()(x)
regressor_outputs = layers.Dense(4, activation="relu")(flatten)

## regressor model
regressor = keras.Model(regressor_inputs, regressor_outputs, name="regressor")
regressor.summary()
# Out:
# Model: "regressor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  layer_R1 (Conv2D)           (None, 128, 128, 32)      320
#
#  layer_R2 (MaxPooling2D)     (None, 64, 64, 32)        0
#
#  batch_normalization_7 (Bat  (None, 64, 64, 32)        128
#  chNormalization)
#
#  layer_R3 (Conv2D)           (None, 64, 64, 64)        18496
#
#  layer_R4 (MaxPooling2D)     (None, 32, 32, 64)        0
#
#  batch_normalization_8 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  layer_R5 (Conv2D)           (None, 32, 32, 128)       73856
#
#  layer_R6 (MaxPooling2D)     (None, 16, 16, 128)       0
#
#  batch_normalization_9 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 4)                 131076
#
# =================================================================
# Total params: 224644 (877.52 KB)
# Trainable params: 224196 (875.77 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
vae = VAE(encoder, decoder,regressor)
opt = tf.optimizers.Adam(learning_rate = 0.000001)
#nll = lambda x , rv_x: -rv_x.log_prob(x)
vae.compile(optimizer=opt)


vae.fit(dataset.batch(16), epochs=2000, 
                batch_size=16,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=100)])
# Out:
# Epoch 1/2000
# 2024-01-24 00:32:37.527617: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2024-01-24 00:32:41.240871: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f300c014e30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-24 00:32:41.241405: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-01-24 00:32:41.279642: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-24 00:32:41.409457: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-01-24 00:32:45.850267: W tensorflow/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2024-01-24 00:32:47.697962: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-24 00:32:47.698011: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 47/47 [==============================] - 26s 184ms/step - loss: 36763081.3333 - reconstruction_loss: 45427.7695 - kl_loss: 0.0041 - ArithmeticError: 36717588.7500
# Epoch 2/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 36761918.4167 - reconstruction_loss: 45054.8828 - kl_loss: 0.0046 - ArithmeticError: 36716834.3333
# Epoch 3/2000
# 47/47 [==============================] - 6s 128ms/step - loss: 36760445.8333 - reconstruction_loss: 44638.4609 - kl_loss: 0.0053 - ArithmeticError: 36716055.8333
# Epoch 4/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36759361.0000 - reconstruction_loss: 44323.3281 - kl_loss: 0.0064 - ArithmeticError: 36715230.5833
# Epoch 5/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 36758388.0000 - reconstruction_loss: 43886.1641 - kl_loss: 0.0078 - ArithmeticError: 36714341.5000
# Epoch 6/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 36756572.9167 - reconstruction_loss: 43295.9219 - kl_loss: 0.0102 - ArithmeticError: 36713383.5833
# Epoch 7/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 36755262.2500 - reconstruction_loss: 42802.1055 - kl_loss: 0.0144 - ArithmeticError: 36712337.5000
# Epoch 8/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 36753153.1667 - reconstruction_loss: 41950.4570 - kl_loss: 0.0226 - ArithmeticError: 36711196.4167
# Epoch 9/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36751384.3333 - reconstruction_loss: 41250.0859 - kl_loss: 0.0381 - ArithmeticError: 36709948.5833
# Epoch 10/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 36749154.6667 - reconstruction_loss: 40374.5781 - kl_loss: 0.0699 - ArithmeticError: 36708591.3333
# Epoch 11/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36746787.1667 - reconstruction_loss: 39563.2969 - kl_loss: 0.1341 - ArithmeticError: 36707119.3333
# Epoch 12/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36743960.7500 - reconstruction_loss: 38430.1875 - kl_loss: 0.2994 - ArithmeticError: 36705531.2500
# Epoch 13/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36741298.8333 - reconstruction_loss: 37212.6797 - kl_loss: 0.7656 - ArithmeticError: 36703805.2500
# Epoch 14/2000
# 47/47 [==============================] - 6s 123ms/step - loss: 36738089.5000 - reconstruction_loss: 35720.6484 - kl_loss: 2.2688 - ArithmeticError: 36701960.0000
# Epoch 15/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36733919.5000 - reconstruction_loss: 33211.5977 - kl_loss: 8.5604 - ArithmeticError: 36700033.2500
# Epoch 16/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36728212.1667 - reconstruction_loss: 28592.0605 - kl_loss: 45.7544 - ArithmeticError: 36698247.3333
# Epoch 17/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36720344.7500 - reconstruction_loss: 20453.7773 - kl_loss: 417.7393 - ArithmeticError: 36697563.9167
# Epoch 18/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36715707.0833 - reconstruction_loss: 16209.0801 - kl_loss: 988.6870 - ArithmeticError: 36698649.3333
# Epoch 19/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36713914.5000 - reconstruction_loss: 16740.1016 - kl_loss: 837.0262 - ArithmeticError: 36696450.5000
# Epoch 20/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36711837.0000 - reconstruction_loss: 17027.9609 - kl_loss: 779.3911 - ArithmeticError: 36694286.7500
# Epoch 21/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36709566.0000 - reconstruction_loss: 17088.4590 - kl_loss: 675.9442 - ArithmeticError: 36692086.7500
# Epoch 22/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36707170.1667 - reconstruction_loss: 17723.6914 - kl_loss: 607.9028 - ArithmeticError: 36688941.6667
# Epoch 23/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36704435.3333 - reconstruction_loss: 17996.8848 - kl_loss: 567.5042 - ArithmeticError: 36685882.2500
# Epoch 24/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36701472.5833 - reconstruction_loss: 18427.9434 - kl_loss: 484.5116 - ArithmeticError: 36682826.0833
# Epoch 25/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36698227.6667 - reconstruction_loss: 18871.9453 - kl_loss: 423.4566 - ArithmeticError: 36679018.4167
# Epoch 26/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36694641.1667 - reconstruction_loss: 19549.0820 - kl_loss: 357.9467 - ArithmeticError: 36674941.8333
# Epoch 27/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36690745.5000 - reconstruction_loss: 19969.5488 - kl_loss: 324.1641 - ArithmeticError: 36670528.5000
# Epoch 28/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36686498.3333 - reconstruction_loss: 20565.5039 - kl_loss: 277.8111 - ArithmeticError: 36665806.3333
# Epoch 29/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36681822.0000 - reconstruction_loss: 21075.3008 - kl_loss: 236.8112 - ArithmeticError: 36660714.7500
# Epoch 30/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36676868.0000 - reconstruction_loss: 21902.4219 - kl_loss: 200.0492 - ArithmeticError: 36655096.0000
# Epoch 31/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36671292.0000 - reconstruction_loss: 22438.6406 - kl_loss: 177.7707 - ArithmeticError: 36648987.0000
# Epoch 32/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36665506.0833 - reconstruction_loss: 23044.0488 - kl_loss: 154.6738 - ArithmeticError: 36642519.5000
# Epoch 33/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36659260.8333 - reconstruction_loss: 23666.5078 - kl_loss: 131.4343 - ArithmeticError: 36635727.6667
# Epoch 34/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36652613.5000 - reconstruction_loss: 24403.3555 - kl_loss: 111.9375 - ArithmeticError: 36628364.7500
# Epoch 35/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36645488.8333 - reconstruction_loss: 25120.4102 - kl_loss: 97.2685 - ArithmeticError: 36620705.5833
# Epoch 36/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36637780.0833 - reconstruction_loss: 25622.3242 - kl_loss: 87.5144 - ArithmeticError: 36612156.5000
# Epoch 37/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36629756.0833 - reconstruction_loss: 26469.0020 - kl_loss: 72.6529 - ArithmeticError: 36603665.0833
# Epoch 38/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36621065.8333 - reconstruction_loss: 26864.5742 - kl_loss: 64.1207 - ArithmeticError: 36594316.3333
# Epoch 39/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36611825.8333 - reconstruction_loss: 27721.8613 - kl_loss: 52.7596 - ArithmeticError: 36584590.8333
# Epoch 40/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 36602030.7500 - reconstruction_loss: 28282.2344 - kl_loss: 47.7724 - ArithmeticError: 36573751.5000
# Epoch 41/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36591801.9167 - reconstruction_loss: 29025.9512 - kl_loss: 41.5198 - ArithmeticError: 36562965.5000
# Epoch 42/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36581010.0000 - reconstruction_loss: 29635.0234 - kl_loss: 36.5311 - ArithmeticError: 36551699.9167
# Epoch 43/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36569583.3333 - reconstruction_loss: 30366.3906 - kl_loss: 33.0115 - ArithmeticError: 36539382.9167
# Epoch 44/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36557489.0000 - reconstruction_loss: 30821.7227 - kl_loss: 30.0321 - ArithmeticError: 36526854.1667
# Epoch 45/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36544850.5833 - reconstruction_loss: 31424.1855 - kl_loss: 26.3983 - ArithmeticError: 36513662.1667
# Epoch 46/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36531709.6667 - reconstruction_loss: 32156.1777 - kl_loss: 24.1041 - ArithmeticError: 36499583.7500
# Epoch 47/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36517967.3333 - reconstruction_loss: 32757.3555 - kl_loss: 22.1550 - ArithmeticError: 36485340.2500
# Epoch 48/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36503658.5833 - reconstruction_loss: 33268.0430 - kl_loss: 20.2824 - ArithmeticError: 36470505.6667
# Epoch 49/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36488737.7500 - reconstruction_loss: 33919.6719 - kl_loss: 17.7793 - ArithmeticError: 36455370.5000
# Epoch 50/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36473235.3333 - reconstruction_loss: 34312.1719 - kl_loss: 16.2690 - ArithmeticError: 36439272.0833
# Epoch 51/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36457181.1667 - reconstruction_loss: 34913.3008 - kl_loss: 14.6348 - ArithmeticError: 36422448.9167
# Epoch 52/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36440772.0833 - reconstruction_loss: 35327.4297 - kl_loss: 12.7270 - ArithmeticError: 36405865.9167
# Epoch 53/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36423525.1667 - reconstruction_loss: 36116.1211 - kl_loss: 11.2105 - ArithmeticError: 36387603.8333
# Epoch 54/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36405752.1667 - reconstruction_loss: 36237.8203 - kl_loss: 9.9988 - ArithmeticError: 36369860.5000
# Epoch 55/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36387275.8333 - reconstruction_loss: 36761.1250 - kl_loss: 8.3441 - ArithmeticError: 36350484.4167
# Epoch 56/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36368147.1667 - reconstruction_loss: 37621.5547 - kl_loss: 6.7984 - ArithmeticError: 36330764.6667
# Epoch 57/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36348200.3333 - reconstruction_loss: 37865.8711 - kl_loss: 6.2532 - ArithmeticError: 36310343.4167
# Epoch 58/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36327802.0000 - reconstruction_loss: 38148.1367 - kl_loss: 5.3088 - ArithmeticError: 36289663.0833
# Epoch 59/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36306911.7500 - reconstruction_loss: 38780.2891 - kl_loss: 4.1716 - ArithmeticError: 36268511.0000
# Epoch 60/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36285347.5000 - reconstruction_loss: 39227.1445 - kl_loss: 3.3997 - ArithmeticError: 36246458.0000
# Epoch 61/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36263122.2500 - reconstruction_loss: 39814.9375 - kl_loss: 2.8259 - ArithmeticError: 36223488.4167
# Epoch 62/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36240189.5833 - reconstruction_loss: 40514.8477 - kl_loss: 2.5141 - ArithmeticError: 36199662.0000
# Epoch 63/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36216278.0000 - reconstruction_loss: 40733.9727 - kl_loss: 2.1058 - ArithmeticError: 36175790.6667
# Epoch 64/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36191795.5000 - reconstruction_loss: 41220.3984 - kl_loss: 1.7924 - ArithmeticError: 36150664.3333
# Epoch 65/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36166844.1667 - reconstruction_loss: 41789.1641 - kl_loss: 1.4832 - ArithmeticError: 36125463.3333
# Epoch 66/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36141180.1667 - reconstruction_loss: 42172.3359 - kl_loss: 1.2130 - ArithmeticError: 36099238.9167
# Epoch 67/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36114886.5833 - reconstruction_loss: 42513.6953 - kl_loss: 1.0130 - ArithmeticError: 36072579.0833
# Epoch 68/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36087797.8333 - reconstruction_loss: 42907.9297 - kl_loss: 0.7996 - ArithmeticError: 36045241.3333
# Epoch 69/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 36059923.5000 - reconstruction_loss: 43408.7266 - kl_loss: 0.5930 - ArithmeticError: 36016759.5000
# Epoch 70/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36031410.0000 - reconstruction_loss: 44017.5859 - kl_loss: 0.4876 - ArithmeticError: 35987451.5833
# Epoch 71/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 36002368.8333 - reconstruction_loss: 44335.2031 - kl_loss: 0.3908 - ArithmeticError: 35958329.3333
# Epoch 72/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35972595.2500 - reconstruction_loss: 44690.4727 - kl_loss: 0.3270 - ArithmeticError: 35928091.5833
# Epoch 73/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35942145.4167 - reconstruction_loss: 44842.6211 - kl_loss: 0.2619 - ArithmeticError: 35897411.9167
# Epoch 74/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35911167.3333 - reconstruction_loss: 45137.6172 - kl_loss: 0.1779 - ArithmeticError: 35866152.3333
# Epoch 75/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35879420.2500 - reconstruction_loss: 45481.7344 - kl_loss: 0.1332 - ArithmeticError: 35834184.0833
# Epoch 76/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35846530.6667 - reconstruction_loss: 45714.7344 - kl_loss: 0.1099 - ArithmeticError: 35801011.5833
# Epoch 77/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35812781.0000 - reconstruction_loss: 46114.3867 - kl_loss: 0.0868 - ArithmeticError: 35766971.0000
# Epoch 78/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35778509.9167 - reconstruction_loss: 46283.4844 - kl_loss: 0.0765 - ArithmeticError: 35732516.2500
# Epoch 79/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35743435.0000 - reconstruction_loss: 46397.2695 - kl_loss: 0.0705 - ArithmeticError: 35697125.0000
# Epoch 80/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35707780.0833 - reconstruction_loss: 46843.8516 - kl_loss: 0.0626 - ArithmeticError: 35661136.6667
# Epoch 81/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35671391.3333 - reconstruction_loss: 46854.7109 - kl_loss: 0.0643 - ArithmeticError: 35624696.9167
# Epoch 82/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35634162.4167 - reconstruction_loss: 47490.3242 - kl_loss: 0.0638 - ArithmeticError: 35586866.5833
# Epoch 83/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35596128.0000 - reconstruction_loss: 47770.5117 - kl_loss: 0.0671 - ArithmeticError: 35548490.5833
# Epoch 84/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35556441.7500 - reconstruction_loss: 47952.2109 - kl_loss: 0.0707 - ArithmeticError: 35508666.6667
# Epoch 85/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35515765.9167 - reconstruction_loss: 47997.8672 - kl_loss: 0.0819 - ArithmeticError: 35467745.1667
# Epoch 86/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35474574.0833 - reconstruction_loss: 48589.2188 - kl_loss: 0.0939 - ArithmeticError: 35426216.2500
# Epoch 87/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35432815.5833 - reconstruction_loss: 48648.0898 - kl_loss: 0.1065 - ArithmeticError: 35384399.0833
# Epoch 88/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35390175.1667 - reconstruction_loss: 49086.8125 - kl_loss: 0.1128 - ArithmeticError: 35341409.2500
# Epoch 89/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35346921.5833 - reconstruction_loss: 49298.8711 - kl_loss: 0.1261 - ArithmeticError: 35297978.3333
# Epoch 90/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35302955.7500 - reconstruction_loss: 49382.9297 - kl_loss: 0.1351 - ArithmeticError: 35254006.8333
# Epoch 91/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35257912.0000 - reconstruction_loss: 49678.0586 - kl_loss: 0.1502 - ArithmeticError: 35208385.9167
# Epoch 92/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35212275.7500 - reconstruction_loss: 49801.4023 - kl_loss: 0.1771 - ArithmeticError: 35162481.7500
# Epoch 93/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35165842.4167 - reconstruction_loss: 50252.1328 - kl_loss: 0.2139 - ArithmeticError: 35115799.2500
# Epoch 94/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 35118656.4167 - reconstruction_loss: 50337.6016 - kl_loss: 0.2766 - ArithmeticError: 35068406.5000
# Epoch 95/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35070707.5000 - reconstruction_loss: 50514.0000 - kl_loss: 0.3459 - ArithmeticError: 35020512.1667
# Epoch 96/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 35021017.3333 - reconstruction_loss: 51017.5039 - kl_loss: 0.4019 - ArithmeticError: 34970112.5000
# Epoch 97/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34970878.9167 - reconstruction_loss: 51284.3945 - kl_loss: 0.4987 - ArithmeticError: 34919730.5833
# Epoch 98/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 34919754.6667 - reconstruction_loss: 51618.8047 - kl_loss: 0.6136 - ArithmeticError: 34868090.0833
# Epoch 99/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34868107.8333 - reconstruction_loss: 51952.8516 - kl_loss: 0.7404 - ArithmeticError: 34816263.9167
# Epoch 100/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 34815657.0000 - reconstruction_loss: 52183.2891 - kl_loss: 0.8609 - ArithmeticError: 34763774.7500
# Epoch 101/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34762487.5000 - reconstruction_loss: 52282.7891 - kl_loss: 1.0530 - ArithmeticError: 34710583.1667
# Epoch 102/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34707991.5000 - reconstruction_loss: 52950.0117 - kl_loss: 1.2938 - ArithmeticError: 34655361.1667
# Epoch 103/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34653079.7500 - reconstruction_loss: 53184.2461 - kl_loss: 1.5469 - ArithmeticError: 34600306.0000
# Epoch 104/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34597093.1667 - reconstruction_loss: 53486.4688 - kl_loss: 1.8833 - ArithmeticError: 34543993.2500
# Epoch 105/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34540241.2500 - reconstruction_loss: 53999.1797 - kl_loss: 2.2748 - ArithmeticError: 34486591.5000
# Epoch 106/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34482751.3333 - reconstruction_loss: 54161.9570 - kl_loss: 2.5304 - ArithmeticError: 34429101.1667
# Epoch 107/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34423870.7500 - reconstruction_loss: 54731.5859 - kl_loss: 2.9296 - ArithmeticError: 34369216.9167
# Epoch 108/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34364645.4167 - reconstruction_loss: 54783.5430 - kl_loss: 3.3656 - ArithmeticError: 34310161.5833
# Epoch 109/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 34304373.1667 - reconstruction_loss: 55139.2383 - kl_loss: 3.8907 - ArithmeticError: 34249497.6667
# Epoch 110/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34243033.6667 - reconstruction_loss: 55861.4609 - kl_loss: 4.6571 - ArithmeticError: 34187464.5833
# Epoch 111/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34181024.5833 - reconstruction_loss: 55911.5703 - kl_loss: 5.1542 - ArithmeticError: 34125252.5833
# Epoch 112/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34118111.7500 - reconstruction_loss: 56347.7656 - kl_loss: 5.7514 - ArithmeticError: 34061960.2500
# Epoch 113/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 34054264.8333 - reconstruction_loss: 56649.2109 - kl_loss: 6.1710 - ArithmeticError: 33997730.8333
# Epoch 114/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33989710.2500 - reconstruction_loss: 56910.7383 - kl_loss: 6.6677 - ArithmeticError: 33933220.7500
# Epoch 115/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33923972.3333 - reconstruction_loss: 57390.1367 - kl_loss: 7.4215 - ArithmeticError: 33866720.2500
# Epoch 116/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33857477.5833 - reconstruction_loss: 57789.6914 - kl_loss: 8.3731 - ArithmeticError: 33800007.8333
# Epoch 117/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 33790220.3333 - reconstruction_loss: 58084.1953 - kl_loss: 8.8926 - ArithmeticError: 33732565.5000
# Epoch 118/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33721796.5000 - reconstruction_loss: 58472.6328 - kl_loss: 9.2683 - ArithmeticError: 33663730.1667
# Epoch 119/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33652585.0833 - reconstruction_loss: 58766.6367 - kl_loss: 9.7287 - ArithmeticError: 33594023.2500
# Epoch 120/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33582514.9167 - reconstruction_loss: 58941.3945 - kl_loss: 10.2835 - ArithmeticError: 33523767.6667
# Epoch 121/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33511460.3750 - reconstruction_loss: 59282.5977 - kl_loss: 11.4141 - ArithmeticError: 33452344.0833
# Epoch 122/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33439693.4583 - reconstruction_loss: 59037.7617 - kl_loss: 12.1911 - ArithmeticError: 33380838.4167
# Epoch 123/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33366821.6250 - reconstruction_loss: 59628.0156 - kl_loss: 13.1743 - ArithmeticError: 33307493.9167
# Epoch 124/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33292973.5833 - reconstruction_loss: 60127.0859 - kl_loss: 13.7112 - ArithmeticError: 33232906.3750
# Epoch 125/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 33218589.3333 - reconstruction_loss: 59781.4219 - kl_loss: 14.2096 - ArithmeticError: 33159043.7083
# Epoch 126/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 33142959.2500 - reconstruction_loss: 60453.2695 - kl_loss: 14.9934 - ArithmeticError: 33082859.9583
# Epoch 127/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 33066467.5417 - reconstruction_loss: 60756.8203 - kl_loss: 15.3644 - ArithmeticError: 33005919.7917
# Epoch 128/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 32989179.2917 - reconstruction_loss: 60880.0039 - kl_loss: 15.8683 - ArithmeticError: 32928674.1667
# Epoch 129/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32910856.1667 - reconstruction_loss: 61223.1133 - kl_loss: 17.0089 - ArithmeticError: 32849916.3333
# Epoch 130/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 32831704.0000 - reconstruction_loss: 61219.2031 - kl_loss: 18.2395 - ArithmeticError: 32770696.7500
# Epoch 131/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 32751597.1250 - reconstruction_loss: 61756.6016 - kl_loss: 19.4857 - ArithmeticError: 32690176.2500
# Epoch 132/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32670491.4167 - reconstruction_loss: 62075.9883 - kl_loss: 20.4511 - ArithmeticError: 32608675.2083
# Epoch 133/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32588522.7500 - reconstruction_loss: 62100.2969 - kl_loss: 21.4874 - ArithmeticError: 32526526.0000
# Epoch 134/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32505736.0417 - reconstruction_loss: 62182.3203 - kl_loss: 22.1203 - ArithmeticError: 32443728.3333
# Epoch 135/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32421896.2500 - reconstruction_loss: 62467.7969 - kl_loss: 23.2329 - ArithmeticError: 32359680.5417
# Epoch 136/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32337188.8750 - reconstruction_loss: 62610.5312 - kl_loss: 24.0920 - ArithmeticError: 32274722.8333
# Epoch 137/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32251479.6250 - reconstruction_loss: 63196.0156 - kl_loss: 25.6218 - ArithmeticError: 32188533.6667
# Epoch 138/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32164880.2917 - reconstruction_loss: 63106.8516 - kl_loss: 27.3728 - ArithmeticError: 32101911.2917
# Epoch 139/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 32077393.5417 - reconstruction_loss: 63231.9961 - kl_loss: 29.0505 - ArithmeticError: 32014294.3750
# Epoch 140/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 31988954.3750 - reconstruction_loss: 63404.0781 - kl_loss: 30.9823 - ArithmeticError: 31925701.7083
# Epoch 141/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31899555.0000 - reconstruction_loss: 63708.2070 - kl_loss: 32.2881 - ArithmeticError: 31835994.9583
# Epoch 142/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31809305.8333 - reconstruction_loss: 63978.7812 - kl_loss: 33.1850 - ArithmeticError: 31745638.6667
# Epoch 143/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 31718039.0000 - reconstruction_loss: 64129.1797 - kl_loss: 34.4484 - ArithmeticError: 31653917.3333
# Epoch 144/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31625973.4167 - reconstruction_loss: 64333.2695 - kl_loss: 35.4532 - ArithmeticError: 31561860.0833
# Epoch 145/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31532772.5000 - reconstruction_loss: 64732.6602 - kl_loss: 36.1546 - ArithmeticError: 31468312.9167
# Epoch 146/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31437201.9167 - reconstruction_loss: 64760.3359 - kl_loss: 37.4745 - ArithmeticError: 31372633.3333
# Epoch 147/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31340905.0833 - reconstruction_loss: 65091.3047 - kl_loss: 38.9761 - ArithmeticError: 31276087.2083
# Epoch 148/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 31243975.0833 - reconstruction_loss: 64909.7891 - kl_loss: 40.5289 - ArithmeticError: 31179216.7083
# Epoch 149/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31146160.0417 - reconstruction_loss: 65125.5898 - kl_loss: 42.0270 - ArithmeticError: 31081205.6667
# Epoch 150/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 31047575.3750 - reconstruction_loss: 65165.3477 - kl_loss: 43.3367 - ArithmeticError: 30982566.1250
# Epoch 151/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 30947997.5833 - reconstruction_loss: 65396.4688 - kl_loss: 44.7958 - ArithmeticError: 30882658.0417
# Epoch 152/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 30847531.5417 - reconstruction_loss: 65487.1602 - kl_loss: 46.3146 - ArithmeticError: 30782152.8750
# Epoch 153/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 30746162.5000 - reconstruction_loss: 66017.4922 - kl_loss: 46.9914 - ArithmeticError: 30680536.4583
# Epoch 154/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 30643899.2083 - reconstruction_loss: 65647.7344 - kl_loss: 48.5651 - ArithmeticError: 30578375.4167
# Epoch 155/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 30540673.8333 - reconstruction_loss: 66111.6094 - kl_loss: 49.3860 - ArithmeticError: 30474853.9167
# Epoch 156/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 30436539.1250 - reconstruction_loss: 66366.9062 - kl_loss: 51.0437 - ArithmeticError: 30370410.5000
# Epoch 157/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 30331513.1667 - reconstruction_loss: 66476.4219 - kl_loss: 52.9618 - ArithmeticError: 30265215.3333
# Epoch 158/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 30225521.2083 - reconstruction_loss: 66603.8516 - kl_loss: 54.4905 - ArithmeticError: 30159080.4167
# Epoch 159/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 30118704.0833 - reconstruction_loss: 66647.5781 - kl_loss: 56.2516 - ArithmeticError: 30052333.2917
# Epoch 160/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 30010982.5417 - reconstruction_loss: 66804.3672 - kl_loss: 57.8630 - ArithmeticError: 29944405.0417
# Epoch 161/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 29902240.9167 - reconstruction_loss: 66918.9062 - kl_loss: 59.5589 - ArithmeticError: 29835446.2917
# Epoch 162/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 29792661.2500 - reconstruction_loss: 66920.6719 - kl_loss: 60.5886 - ArithmeticError: 29725830.5417
# Epoch 163/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 29682178.9583 - reconstruction_loss: 67277.4219 - kl_loss: 61.6120 - ArithmeticError: 29614937.1667
# Epoch 164/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 29570793.5000 - reconstruction_loss: 67333.4688 - kl_loss: 62.9830 - ArithmeticError: 29503566.0417
# Epoch 165/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 29458520.7500 - reconstruction_loss: 67519.0938 - kl_loss: 63.9186 - ArithmeticError: 29391191.8750
# Epoch 166/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 29345386.2083 - reconstruction_loss: 67637.0312 - kl_loss: 64.7538 - ArithmeticError: 29278065.1667
# Epoch 167/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 29231330.7917 - reconstruction_loss: 67763.3516 - kl_loss: 65.5457 - ArithmeticError: 29163766.7500
# Epoch 168/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 29116331.4167 - reconstruction_loss: 67952.5547 - kl_loss: 66.3857 - ArithmeticError: 29048458.2083
# Epoch 169/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 29000580.1667 - reconstruction_loss: 67817.6406 - kl_loss: 67.8342 - ArithmeticError: 28932863.7500
# Epoch 170/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 28883894.6250 - reconstruction_loss: 68028.1797 - kl_loss: 68.5251 - ArithmeticError: 28816068.2917
# Epoch 171/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 28766276.9167 - reconstruction_loss: 68187.1641 - kl_loss: 69.5638 - ArithmeticError: 28698107.5833
# Epoch 172/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 28647958.5833 - reconstruction_loss: 68148.6406 - kl_loss: 70.3669 - ArithmeticError: 28580048.3750
# Epoch 173/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 28528638.8333 - reconstruction_loss: 68442.0391 - kl_loss: 70.6609 - ArithmeticError: 28460263.0417
# Epoch 174/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 28408527.9167 - reconstruction_loss: 68437.3594 - kl_loss: 71.3515 - ArithmeticError: 28340363.4583
# Epoch 175/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 28287494.3750 - reconstruction_loss: 68567.0625 - kl_loss: 72.1153 - ArithmeticError: 28219094.2917
# Epoch 176/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 28165645.7500 - reconstruction_loss: 68598.0391 - kl_loss: 72.8913 - ArithmeticError: 28097115.8750
# Epoch 177/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 28043015.9583 - reconstruction_loss: 68756.0312 - kl_loss: 73.6043 - ArithmeticError: 27974498.0000
# Epoch 178/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 27919469.3750 - reconstruction_loss: 69061.8594 - kl_loss: 74.2929 - ArithmeticError: 27850488.6667
# Epoch 179/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 27795180.2500 - reconstruction_loss: 69186.2812 - kl_loss: 74.8618 - ArithmeticError: 27726155.5417
# Epoch 180/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 27670028.2083 - reconstruction_loss: 69067.5391 - kl_loss: 75.6017 - ArithmeticError: 27600984.4583
# Epoch 181/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 27544087.6667 - reconstruction_loss: 69192.3203 - kl_loss: 75.7739 - ArithmeticError: 27474987.5000
# Epoch 182/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 27416914.8333 - reconstruction_loss: 69347.3594 - kl_loss: 76.1136 - ArithmeticError: 27347793.7500
# Epoch 183/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 27286073.8750 - reconstruction_loss: 69613.1875 - kl_loss: 76.6061 - ArithmeticError: 27216568.6250
# Epoch 184/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 27155229.0833 - reconstruction_loss: 69540.2734 - kl_loss: 76.9877 - ArithmeticError: 27085905.3333
# Epoch 185/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 27023998.1250 - reconstruction_loss: 69782.8984 - kl_loss: 77.3064 - ArithmeticError: 26954381.2083
# Epoch 186/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 26892142.9583 - reconstruction_loss: 69937.1094 - kl_loss: 77.3782 - ArithmeticError: 26822470.2500
# Epoch 187/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 26759699.9583 - reconstruction_loss: 69825.9297 - kl_loss: 77.9979 - ArithmeticError: 26689870.5833
# Epoch 188/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 26626670.5833 - reconstruction_loss: 69966.6953 - kl_loss: 78.1337 - ArithmeticError: 26557017.0417
# Epoch 189/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 26492780.2917 - reconstruction_loss: 70101.4219 - kl_loss: 79.1034 - ArithmeticError: 26422799.0833
# Epoch 190/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 26358306.5000 - reconstruction_loss: 70392.0703 - kl_loss: 80.1362 - ArithmeticError: 26288134.8750
# Epoch 191/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 26223071.0833 - reconstruction_loss: 70110.0156 - kl_loss: 81.2303 - ArithmeticError: 26153080.6667
# Epoch 192/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 26087181.5417 - reconstruction_loss: 70271.1250 - kl_loss: 81.8016 - ArithmeticError: 26016861.8333
# Epoch 193/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 25950634.1667 - reconstruction_loss: 70603.1094 - kl_loss: 81.6703 - ArithmeticError: 25880234.4583
# Epoch 194/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 25813293.9167 - reconstruction_loss: 70580.3516 - kl_loss: 82.3088 - ArithmeticError: 25742706.5417
# Epoch 195/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 25675336.1250 - reconstruction_loss: 70711.8906 - kl_loss: 82.7088 - ArithmeticError: 25604776.8333
# Epoch 196/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 25536693.9167 - reconstruction_loss: 70845.3750 - kl_loss: 82.8154 - ArithmeticError: 25465874.7917
# Epoch 197/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 25396272.8750 - reconstruction_loss: 70883.2812 - kl_loss: 82.9524 - ArithmeticError: 25325568.4167
# Epoch 198/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 25251626.5000 - reconstruction_loss: 71011.4766 - kl_loss: 83.6448 - ArithmeticError: 25180874.1667
# Epoch 199/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 25107578.9167 - reconstruction_loss: 71011.0312 - kl_loss: 84.3929 - ArithmeticError: 25036542.9167
# Epoch 200/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 24963441.7917 - reconstruction_loss: 71000.7109 - kl_loss: 85.0209 - ArithmeticError: 24892377.9167
# Epoch 201/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 24819007.0417 - reconstruction_loss: 71260.3750 - kl_loss: 85.3371 - ArithmeticError: 24747855.1250
# Epoch 202/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 24673973.8333 - reconstruction_loss: 71356.7734 - kl_loss: 85.4394 - ArithmeticError: 24602713.4167
# Epoch 203/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 24528508.7500 - reconstruction_loss: 71654.8203 - kl_loss: 86.1589 - ArithmeticError: 24456896.5000
# Epoch 204/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 24382573.9583 - reconstruction_loss: 71708.5547 - kl_loss: 87.0573 - ArithmeticError: 24311051.7500
# Epoch 205/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 24236046.8333 - reconstruction_loss: 71712.4453 - kl_loss: 87.4669 - ArithmeticError: 24164456.6250
# Epoch 206/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 24089053.0833 - reconstruction_loss: 71818.3203 - kl_loss: 87.8927 - ArithmeticError: 24017436.9167
# Epoch 207/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 23941384.9167 - reconstruction_loss: 71886.4922 - kl_loss: 88.4499 - ArithmeticError: 23869710.7500
# Epoch 208/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 23791426.5833 - reconstruction_loss: 71857.7734 - kl_loss: 89.2103 - ArithmeticError: 23719556.0833
# Epoch 209/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 23639062.3750 - reconstruction_loss: 71844.9766 - kl_loss: 89.4077 - ArithmeticError: 23567377.5417
# Epoch 210/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 23487157.2917 - reconstruction_loss: 71979.6484 - kl_loss: 89.9065 - ArithmeticError: 23415351.9583
# Epoch 211/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 23335216.4167 - reconstruction_loss: 72234.9062 - kl_loss: 90.1947 - ArithmeticError: 23263238.9167
# Epoch 212/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 23182870.0417 - reconstruction_loss: 72432.7734 - kl_loss: 90.5293 - ArithmeticError: 23110491.6250
# Epoch 213/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 23030224.0000 - reconstruction_loss: 72320.3125 - kl_loss: 90.9640 - ArithmeticError: 22957835.5417
# Epoch 214/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 22877231.0417 - reconstruction_loss: 72372.8047 - kl_loss: 91.1902 - ArithmeticError: 22804987.5000
# Epoch 215/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 22723798.0833 - reconstruction_loss: 72496.1406 - kl_loss: 91.9119 - ArithmeticError: 22651430.2500
# Epoch 216/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 22569939.2917 - reconstruction_loss: 72621.3984 - kl_loss: 92.1634 - ArithmeticError: 22497479.0833
# Epoch 217/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 22415657.9583 - reconstruction_loss: 72657.8438 - kl_loss: 92.5839 - ArithmeticError: 22343101.7500
# Epoch 218/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 22261055.2500 - reconstruction_loss: 72758.4922 - kl_loss: 93.0585 - ArithmeticError: 22188397.2083
# Epoch 219/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 22106077.6667 - reconstruction_loss: 72755.7344 - kl_loss: 93.3631 - ArithmeticError: 22033506.6250
# Epoch 220/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 21950670.0833 - reconstruction_loss: 73086.5703 - kl_loss: 93.1416 - ArithmeticError: 21877723.5833
# Epoch 221/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 21795020.5417 - reconstruction_loss: 72931.5859 - kl_loss: 94.0419 - ArithmeticError: 21722193.0417
# Epoch 222/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 21638960.3750 - reconstruction_loss: 73097.0547 - kl_loss: 94.2910 - ArithmeticError: 21566036.8333
# Epoch 223/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 21482499.0833 - reconstruction_loss: 73114.9297 - kl_loss: 94.8332 - ArithmeticError: 21409478.0833
# Epoch 224/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 21324268.2500 - reconstruction_loss: 73133.9922 - kl_loss: 95.1872 - ArithmeticError: 21251181.7500
# Epoch 225/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 21165433.1667 - reconstruction_loss: 73294.7500 - kl_loss: 95.5779 - ArithmeticError: 21092296.6250
# Epoch 226/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 21006714.4583 - reconstruction_loss: 73200.6797 - kl_loss: 96.0756 - ArithmeticError: 20933630.1250
# Epoch 227/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 20847888.7917 - reconstruction_loss: 73224.5312 - kl_loss: 96.4423 - ArithmeticError: 20774832.4583
# Epoch 228/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 20688834.3333 - reconstruction_loss: 73551.6953 - kl_loss: 96.4362 - ArithmeticError: 20615329.2917
# Epoch 229/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 20529677.8333 - reconstruction_loss: 73443.7734 - kl_loss: 96.9511 - ArithmeticError: 20456347.9167
# Epoch 230/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 20370218.3333 - reconstruction_loss: 73592.6094 - kl_loss: 97.1618 - ArithmeticError: 20296774.5833
# Epoch 231/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 20210613.3333 - reconstruction_loss: 73755.0859 - kl_loss: 97.4893 - ArithmeticError: 20136989.2500
# Epoch 232/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 20050722.5000 - reconstruction_loss: 73768.0938 - kl_loss: 97.9708 - ArithmeticError: 19977093.2083
# Epoch 233/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 19890697.5000 - reconstruction_loss: 73728.4375 - kl_loss: 98.3910 - ArithmeticError: 19817027.7917
# Epoch 234/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 19730521.2083 - reconstruction_loss: 73760.5078 - kl_loss: 98.7369 - ArithmeticError: 19657043.6250
# Epoch 235/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 19570030.9167 - reconstruction_loss: 73928.0391 - kl_loss: 98.8692 - ArithmeticError: 19496253.5833
# Epoch 236/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 19409438.6667 - reconstruction_loss: 73884.0781 - kl_loss: 99.6128 - ArithmeticError: 19335750.6667
# Epoch 237/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 19248655.4583 - reconstruction_loss: 73931.2422 - kl_loss: 100.2152 - ArithmeticError: 19174760.1667
# Epoch 238/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 19087792.0833 - reconstruction_loss: 74093.2734 - kl_loss: 100.4847 - ArithmeticError: 19013957.4583
# Epoch 239/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 18926694.8750 - reconstruction_loss: 74086.2266 - kl_loss: 101.0864 - ArithmeticError: 18852797.8333
# Epoch 240/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 18765482.7917 - reconstruction_loss: 74145.3984 - kl_loss: 101.1553 - ArithmeticError: 18691407.6667
# Epoch 241/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 18604142.5000 - reconstruction_loss: 74207.3828 - kl_loss: 101.6494 - ArithmeticError: 18530104.2083
# Epoch 242/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 18442585.3750 - reconstruction_loss: 74386.1719 - kl_loss: 102.6859 - ArithmeticError: 18368241.7083
# Epoch 243/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 18281051.8750 - reconstruction_loss: 74354.2344 - kl_loss: 103.0389 - ArithmeticError: 18206911.7917
# Epoch 244/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 18119294.5000 - reconstruction_loss: 74512.2031 - kl_loss: 103.8755 - ArithmeticError: 18044903.0000
# Epoch 245/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 17957455.2500 - reconstruction_loss: 74454.8281 - kl_loss: 104.9956 - ArithmeticError: 17883060.3750
# Epoch 246/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 17795508.9167 - reconstruction_loss: 74589.1875 - kl_loss: 105.2851 - ArithmeticError: 17721099.0000
# Epoch 247/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 17633476.5833 - reconstruction_loss: 74436.9141 - kl_loss: 105.3427 - ArithmeticError: 17559095.6250
# Epoch 248/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 17471306.8750 - reconstruction_loss: 74657.2734 - kl_loss: 105.2239 - ArithmeticError: 17396715.7500
# Epoch 249/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 17309004.3333 - reconstruction_loss: 74766.3828 - kl_loss: 105.4268 - ArithmeticError: 17234349.0833
# Epoch 250/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 17146665.0000 - reconstruction_loss: 74628.5703 - kl_loss: 105.7550 - ArithmeticError: 17072097.5417
# Epoch 251/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 16984176.8750 - reconstruction_loss: 74717.1094 - kl_loss: 106.4269 - ArithmeticError: 16909635.9583
# Epoch 252/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 16821530.2917 - reconstruction_loss: 74916.8359 - kl_loss: 106.7713 - ArithmeticError: 16746773.3750
# Epoch 253/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 16658848.2500 - reconstruction_loss: 74869.4688 - kl_loss: 107.0096 - ArithmeticError: 16584042.1250
# Epoch 254/2000
# 47/47 [==============================] - 6s 124ms/step - loss: 16496060.3958 - reconstruction_loss: 74717.7891 - kl_loss: 107.5289 - ArithmeticError: 16421309.1250
# Epoch 255/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 16333240.9792 - reconstruction_loss: 74832.2344 - kl_loss: 107.4447 - ArithmeticError: 16258747.8958
# Epoch 256/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 16170197.8750 - reconstruction_loss: 75010.7891 - kl_loss: 107.9790 - ArithmeticError: 16095320.4792
# Epoch 257/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 16007120.9375 - reconstruction_loss: 74956.4609 - kl_loss: 108.7658 - ArithmeticError: 15932350.6875
# Epoch 258/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 15843967.0208 - reconstruction_loss: 75125.6406 - kl_loss: 108.5862 - ArithmeticError: 15769031.4583
# Epoch 259/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 15680729.6667 - reconstruction_loss: 75166.3438 - kl_loss: 108.6428 - ArithmeticError: 15605627.5625
# Epoch 260/2000
# ...
# 47/47 [==============================] - 6s 125ms/step - loss: 44850.7664 - reconstruction_loss: 12470.8613 - kl_loss: 558.4205 - ArithmeticError: 31799.5090
# Epoch 1910/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 45006.8214 - reconstruction_loss: 12472.5996 - kl_loss: 558.3769 - ArithmeticError: 31952.7314
# Epoch 1911/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44620.2246 - reconstruction_loss: 12471.9551 - kl_loss: 558.3020 - ArithmeticError: 31570.7106
# Epoch 1912/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44550.9074 - reconstruction_loss: 12465.7471 - kl_loss: 557.4956 - ArithmeticError: 31508.5303
# Epoch 1913/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44978.8667 - reconstruction_loss: 12470.7100 - kl_loss: 557.5479 - ArithmeticError: 31933.6368
# Epoch 1914/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44402.4079 - reconstruction_loss: 12467.8340 - kl_loss: 556.2536 - ArithmeticError: 31360.8434
# Epoch 1915/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44636.0662 - reconstruction_loss: 12463.2910 - kl_loss: 554.6673 - ArithmeticError: 31597.1484
# Epoch 1916/2000
# 47/47 [==============================] - 6s 127ms/step - loss: 44657.5030 - reconstruction_loss: 12463.7012 - kl_loss: 554.3975 - ArithmeticError: 31622.3801
# Epoch 1917/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 44120.8903 - reconstruction_loss: 12461.0518 - kl_loss: 554.9086 - ArithmeticError: 31089.1457
# Epoch 1918/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44186.0123 - reconstruction_loss: 12456.8057 - kl_loss: 554.5831 - ArithmeticError: 31160.8639
# Epoch 1919/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44205.2313 - reconstruction_loss: 12454.7939 - kl_loss: 552.8652 - ArithmeticError: 31183.3365
# Epoch 1920/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44176.5706 - reconstruction_loss: 12455.1406 - kl_loss: 552.3122 - ArithmeticError: 31157.8765
# Epoch 1921/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 43938.8569 - reconstruction_loss: 12446.8389 - kl_loss: 548.6106 - ArithmeticError: 30931.1383
# Epoch 1922/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43392.7235 - reconstruction_loss: 12446.0957 - kl_loss: 548.4381 - ArithmeticError: 30387.1942
# Epoch 1923/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43421.4466 - reconstruction_loss: 12451.1797 - kl_loss: 548.6180 - ArithmeticError: 30409.9201
# Epoch 1924/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43536.3600 - reconstruction_loss: 12448.8936 - kl_loss: 548.4326 - ArithmeticError: 30527.9547
# Epoch 1925/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43504.5946 - reconstruction_loss: 12451.7500 - kl_loss: 547.8347 - ArithmeticError: 30496.5152
# Epoch 1926/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43336.5468 - reconstruction_loss: 12443.1953 - kl_loss: 547.4047 - ArithmeticError: 30336.9997
# Epoch 1927/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43265.8823 - reconstruction_loss: 12443.4365 - kl_loss: 547.9807 - ArithmeticError: 30264.3798
# Epoch 1928/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43590.0758 - reconstruction_loss: 12450.4092 - kl_loss: 548.0422 - ArithmeticError: 30580.5623
# Epoch 1929/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 43126.3349 - reconstruction_loss: 12444.8115 - kl_loss: 547.6962 - ArithmeticError: 30126.6849
# Epoch 1930/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43418.3351 - reconstruction_loss: 12443.5723 - kl_loss: 547.3394 - ArithmeticError: 30422.3243
# Epoch 1931/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43498.8999 - reconstruction_loss: 12431.5283 - kl_loss: 546.1213 - ArithmeticError: 30518.9974
# Epoch 1932/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43135.9168 - reconstruction_loss: 12429.7646 - kl_loss: 545.9236 - ArithmeticError: 30157.5321
# Epoch 1933/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 43601.2808 - reconstruction_loss: 12435.1650 - kl_loss: 545.2766 - ArithmeticError: 30615.5648
# Epoch 1934/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43133.8254 - reconstruction_loss: 12434.9619 - kl_loss: 544.9286 - ArithmeticError: 30154.9699
# Epoch 1935/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43592.8009 - reconstruction_loss: 12431.1328 - kl_loss: 543.1207 - ArithmeticError: 30614.3832
# Epoch 1936/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43224.5199 - reconstruction_loss: 12427.9531 - kl_loss: 543.7493 - ArithmeticError: 30250.3749
# Epoch 1937/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44198.6418 - reconstruction_loss: 12437.2607 - kl_loss: 543.2287 - ArithmeticError: 31222.1725
# Epoch 1938/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 44057.1293 - reconstruction_loss: 12433.9365 - kl_loss: 542.7510 - ArithmeticError: 31087.1289
# Epoch 1939/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43889.6314 - reconstruction_loss: 12426.9004 - kl_loss: 543.8068 - ArithmeticError: 30928.5576
# Epoch 1940/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44173.0148 - reconstruction_loss: 12424.7363 - kl_loss: 541.3269 - ArithmeticError: 31204.0293
# Epoch 1941/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 44846.2978 - reconstruction_loss: 12435.1885 - kl_loss: 541.7128 - ArithmeticError: 31880.6169
# Epoch 1942/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 45629.0045 - reconstruction_loss: 12431.3301 - kl_loss: 543.5331 - ArithmeticError: 32667.0933
# Epoch 1943/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 46467.9667 - reconstruction_loss: 12439.7197 - kl_loss: 546.1953 - ArithmeticError: 33490.6618
# Epoch 1944/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 45850.8822 - reconstruction_loss: 12427.1514 - kl_loss: 546.9600 - ArithmeticError: 32885.7227
# Epoch 1945/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 48072.9181 - reconstruction_loss: 12429.8242 - kl_loss: 545.4877 - ArithmeticError: 35115.2188
# Epoch 1946/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 48259.4474 - reconstruction_loss: 12425.4863 - kl_loss: 546.1142 - ArithmeticError: 35304.2728
# Epoch 1947/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 50257.9548 - reconstruction_loss: 12433.2900 - kl_loss: 543.5403 - ArithmeticError: 37293.2423
# Epoch 1948/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 50861.2425 - reconstruction_loss: 12423.5996 - kl_loss: 541.1321 - ArithmeticError: 37904.4508
# Epoch 1949/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 50764.7749 - reconstruction_loss: 12426.3994 - kl_loss: 540.3770 - ArithmeticError: 37795.0696
# Epoch 1950/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 52304.5546 - reconstruction_loss: 12416.2402 - kl_loss: 538.9300 - ArithmeticError: 39336.7882
# Epoch 1951/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 49729.2123 - reconstruction_loss: 12412.5635 - kl_loss: 537.4088 - ArithmeticError: 36763.7502
# Epoch 1952/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 48844.7166 - reconstruction_loss: 12408.5908 - kl_loss: 537.1193 - ArithmeticError: 35879.2637
# Epoch 1953/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 47075.5099 - reconstruction_loss: 12402.1064 - kl_loss: 535.2935 - ArithmeticError: 34117.1617
# Epoch 1954/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 45045.3814 - reconstruction_loss: 12396.5879 - kl_loss: 533.7022 - ArithmeticError: 32098.6132
# Epoch 1955/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 44387.4282 - reconstruction_loss: 12397.4756 - kl_loss: 533.1766 - ArithmeticError: 31439.8124
# Epoch 1956/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 43088.2763 - reconstruction_loss: 12399.5781 - kl_loss: 532.5889 - ArithmeticError: 30142.7942
# Epoch 1957/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 42882.0675 - reconstruction_loss: 12401.4922 - kl_loss: 532.2251 - ArithmeticError: 29936.4712
# Epoch 1958/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 42762.6157 - reconstruction_loss: 12401.9229 - kl_loss: 531.4247 - ArithmeticError: 29820.6891
# Epoch 1959/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 42886.3907 - reconstruction_loss: 12401.4824 - kl_loss: 531.0928 - ArithmeticError: 29945.9240
# Epoch 1960/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43068.1243 - reconstruction_loss: 12402.8389 - kl_loss: 531.6597 - ArithmeticError: 30126.5133
# Epoch 1961/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43198.6951 - reconstruction_loss: 12403.2471 - kl_loss: 530.9825 - ArithmeticError: 30259.5441
# Epoch 1962/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 43552.2490 - reconstruction_loss: 12401.5996 - kl_loss: 530.3425 - ArithmeticError: 30614.6306
# Epoch 1963/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 43187.7160 - reconstruction_loss: 12398.5742 - kl_loss: 529.6129 - ArithmeticError: 30254.2037
# Epoch 1964/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 43182.3507 - reconstruction_loss: 12396.4111 - kl_loss: 528.3156 - ArithmeticError: 30249.3837
# Epoch 1965/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 42694.8299 - reconstruction_loss: 12394.0244 - kl_loss: 527.5406 - ArithmeticError: 29764.9207
# Epoch 1966/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 42415.9365 - reconstruction_loss: 12391.1221 - kl_loss: 526.7634 - ArithmeticError: 29489.1292
# Epoch 1967/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 42264.3583 - reconstruction_loss: 12390.8848 - kl_loss: 526.6364 - ArithmeticError: 29336.4881
# Epoch 1968/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 41963.7080 - reconstruction_loss: 12390.4707 - kl_loss: 526.1232 - ArithmeticError: 29036.4214
# Epoch 1969/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 41772.3988 - reconstruction_loss: 12389.9180 - kl_loss: 525.6281 - ArithmeticError: 28847.1567
# Epoch 1970/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 41578.6881 - reconstruction_loss: 12390.7979 - kl_loss: 525.0966 - ArithmeticError: 28652.6833
# Epoch 1971/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 41492.7750 - reconstruction_loss: 12390.2207 - kl_loss: 523.9030 - ArithmeticError: 28568.1507
# Epoch 1972/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 41321.1933 - reconstruction_loss: 12389.1777 - kl_loss: 523.6041 - ArithmeticError: 28398.7906
# Epoch 1973/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 41219.0411 - reconstruction_loss: 12391.2275 - kl_loss: 523.4122 - ArithmeticError: 28295.5479
# Epoch 1974/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40942.7756 - reconstruction_loss: 12390.6699 - kl_loss: 522.8453 - ArithmeticError: 28021.0817
# Epoch 1975/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40874.8457 - reconstruction_loss: 12391.3164 - kl_loss: 522.6992 - ArithmeticError: 27953.5703
# Epoch 1976/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40734.6903 - reconstruction_loss: 12391.0840 - kl_loss: 522.0750 - ArithmeticError: 27814.0233
# Epoch 1977/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40684.6657 - reconstruction_loss: 12392.0068 - kl_loss: 520.4966 - ArithmeticError: 27765.4095
# Epoch 1978/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40562.5420 - reconstruction_loss: 12393.1240 - kl_loss: 520.0992 - ArithmeticError: 27645.6323
# Epoch 1979/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40540.0598 - reconstruction_loss: 12393.8818 - kl_loss: 520.3037 - ArithmeticError: 27621.8856
# Epoch 1980/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 40321.9586 - reconstruction_loss: 12393.9814 - kl_loss: 519.9509 - ArithmeticError: 27405.7664
# Epoch 1981/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40359.6774 - reconstruction_loss: 12396.1094 - kl_loss: 519.9894 - ArithmeticError: 27443.3936
# Epoch 1982/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40368.2956 - reconstruction_loss: 12396.4473 - kl_loss: 519.4034 - ArithmeticError: 27455.3081
# Epoch 1983/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 40357.5245 - reconstruction_loss: 12397.6680 - kl_loss: 519.6230 - ArithmeticError: 27444.6398
# Epoch 1984/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40121.5423 - reconstruction_loss: 12396.0879 - kl_loss: 519.7503 - ArithmeticError: 27209.4690
# Epoch 1985/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40098.8158 - reconstruction_loss: 12397.9346 - kl_loss: 519.0787 - ArithmeticError: 27185.2601
# Epoch 1986/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39976.8042 - reconstruction_loss: 12400.1426 - kl_loss: 519.7708 - ArithmeticError: 27060.7935
# Epoch 1987/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40077.6646 - reconstruction_loss: 12400.2168 - kl_loss: 518.8528 - ArithmeticError: 27163.6635
# Epoch 1988/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39929.1071 - reconstruction_loss: 12397.6924 - kl_loss: 517.5097 - ArithmeticError: 27020.1313
# Epoch 1989/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 40037.0675 - reconstruction_loss: 12397.3672 - kl_loss: 517.3514 - ArithmeticError: 27128.5484
# Epoch 1990/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39773.0011 - reconstruction_loss: 12397.2275 - kl_loss: 516.6230 - ArithmeticError: 26866.7011
# Epoch 1991/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 39868.3265 - reconstruction_loss: 12396.3086 - kl_loss: 515.5496 - ArithmeticError: 26964.1294
# Epoch 1992/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39810.4369 - reconstruction_loss: 12397.2207 - kl_loss: 515.2894 - ArithmeticError: 26904.9738
# Epoch 1993/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39872.5298 - reconstruction_loss: 12395.1436 - kl_loss: 516.2966 - ArithmeticError: 26969.5347
# Epoch 1994/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39749.4793 - reconstruction_loss: 12395.2695 - kl_loss: 515.8666 - ArithmeticError: 26847.2674
# Epoch 1995/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39948.1600 - reconstruction_loss: 12393.8564 - kl_loss: 516.0381 - ArithmeticError: 27046.1004
# Epoch 1996/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39811.0475 - reconstruction_loss: 12391.3008 - kl_loss: 515.2475 - ArithmeticError: 26913.3640
# Epoch 1997/2000
# 47/47 [==============================] - 6s 126ms/step - loss: 39846.8956 - reconstruction_loss: 12391.5283 - kl_loss: 514.6500 - ArithmeticError: 26950.7611
# Epoch 1998/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39737.7249 - reconstruction_loss: 12392.3389 - kl_loss: 514.7065 - ArithmeticError: 26841.2561
# Epoch 1999/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39814.4852 - reconstruction_loss: 12390.1582 - kl_loss: 514.5976 - ArithmeticError: 26916.2047
# Epoch 2000/2000
# 47/47 [==============================] - 6s 125ms/step - loss: 39678.4439 - reconstruction_loss: 12393.3125 - kl_loss: 513.8486 - ArithmeticError: 26780.1799

# %%
### Guardar modelohttps://www.tensorflow.org/guide/saved_model?hl=es-419
vae.encoder.save('Models/weakly2_GVAE_encoder_DRY_1_32.h5')
vae.decoder.save('Models/weakly2_GVAE_decoder_DRY_1_32.h5')
vae.regressor.save('Models/weakly2_GVAE_regressor_DRY_1_32.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2024-01-24 03:50:05.150831: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.

# %% [markdown]
# ### Entrenar para una sola variable

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class VAE(keras.Model):
    def __init__(self, encoder, decoder, regressor, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.regressor = regressor
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")        
        self.estimation_loss_tracker = keras.metrics.Mean(name="estimation_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.estimation_loss_tracker,            
        ]

    def train_step(self, data,property):
        with tf.GradientTape() as tape:
            ## Valores estimados por el encoder
            z_mean, z_log_var, z = self.encoder(data[0])
            
            ## Valores geométricos asociados a los datos
            geometrics_features = data[2]

            ## Reconstrucción del embebido del encoder
            reconstruction = self.decoder(z)            

            ## Reducción de la reconstrucción
            reconstruction /= tf.reduce_max(reconstruction)

            ## Valores estimados apartir del regresor
            estimation = self.regressor(reconstruction)
            
            ## Error de reconstrucción
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data[0], reconstruction), axis=(1, 2)
                )
            )

            '''
            reconstruction_loss =tf.reduce_mean(
                tf.reduce_sum( tf.keras.losses.MeanSquaredError()(data, reconstruction)
                             )
            )
            '''
            
            ## Error de estimación de valores geométricos
            estimation_loss = tf.reduce_mean(tf.keras.losses.MeanSquaredError()(geometrics_features[property], estimation))
            
            
            ## Error de divergencia KL
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))   

            ## Error total          
            total_loss = reconstruction_loss + kl_loss + estimation_loss
        
        ## Actualización de los gradientes
        grads = tape.gradient(total_loss, self.trainable_weights)

        ## Actualización de lA RECONSTRUCCIÓN
        self.reconstruction = reconstruction

        ### Actualización de los pesos
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)   
        self.estimation_loss_tracker.update_state(estimation_loss)    
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(), 
            "ArithmeticError": self.estimation_loss_tracker.result(),        
        }

# %%
###_____________________________ENCODER________________________##
latent_dim = 32

nx, ny = 128, 128

encoder_inputs = keras.Input(shape=(nx, ny,1))

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E1')(encoder_inputs)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(1024, (3, 3), activation='relu', padding='same',name='layer_E2')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same',name='layer_E3')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same',name='layer_E4')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_E6')(x)
x = layers.Flatten()(x)



z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(inputs=encoder_inputs, outputs=[z_mean, z_log_var, z], name="encoder")
encoder.summary()

# %%
## Entrada Z
latent_inputs = keras.Input(shape=(latent_dim,))

##dimensiones
ndim = 16
nfilts = 128

## anti-flatten de la última capa convolucional
x = layers.Dense(ndim * ndim * nfilts, activation="relu")(latent_inputs)

## Reshape para reconstruir la última convolucional
x = layers.Reshape((ndim,ndim, nfilts))(x)

## Capas convolucionales
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D1')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_D2')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_D4')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same',name='layer_D6')(x)

decoder_outputs = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='layer_D7')(x)

## Construcción del decoder
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

# %%
### Estimador de valores geométricos

## Input layer
regressor_inputs = keras.Input(shape=(128,128,1))

## Hidden layers
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same',name='layer_R1')(regressor_inputs)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R2')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same',name='layer_R3')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R4')(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same',name='layer_R5')(x)
x = layers.MaxPooling2D((2, 2), padding='same',name='layer_R6')(x)
x = layers.BatchNormalization()(x)

## Output layer
flatten = layers.Flatten()(x)
regressor_outputs = layers.Dense(4, activation="relu")(flatten)

## regressor model
regressor = keras.Model(regressor_inputs, regressor_outputs, name="regressor")
regressor.summary()

# %%
vae = VAE(encoder, decoder,regressor)
opt = tf.optimizers.Adam(learning_rate = 0.000001)
#nll = lambda x , rv_x: -rv_x.log_prob(x)
vae.compile(optimizer=opt)


vae.fit(dataset.batch(16), epochs=2000, 
                batch_size=16,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=100)])

# %%
### Guardar modelohttps://www.tensorflow.org/guide/saved_model?hl=es-419
vae.encoder.save('Models/weakly2_GVAE_encoder_DRY_1_32_p1.h5')
vae.decoder.save('Models/weakly2_GVAE_decoder_DRY_1_32_p1.h5')
vae.regressor.save('Models/weakly2_GVAE_regressor_DRY_1_32_p1.h5')
